# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Câu hỏi 1: Sự thay đổi của Attributes và nơi ở như thế nào?
#
# - Sự thay đổi của Attributes theo continent
# - Sự thay đổi của Attributes theo Subcontinent
# - Sự thay đổi của Attributes theo biome
# - Sự thay đổi của Attributes theo climate
#
# Ý nghĩa: Biết được cách sinh sống, các thuộc tính của động vật theo nơi ở thì sẽ giúp ích cho việc tìm kiếm, chăm sóc, theo dõi, săn bắt động vật dễ dàng hơn.

# %%
data_df = pd.read_csv("../kham_pha_du_lieu/animals_split_info.csv", index_col = 0)
# Out:
# /tmp/ipykernel_99/2748818031.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv("../kham_pha_du_lieu/animals_split_info.csv", index_col = 0)

# %%
data_df.head(5)
# Out:
#            Name   Kingdom    Phylum   Subphylum     Class         Order  \
# 0     Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 1         Tiger  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 2    Brown Bear  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 3    Blue Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
# 4  Killer Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
#
#      Suborder           Family         Genus                Species  \
# 0  Caniformia          Canidae         Canis            Canis lupus
# 1  Feliformia          Felidae      Panthera        Panthera tigris
# 2  Caniformia          Ursidae         Ursus           Ursus arctos
# 3         NaN  Balaenopteridae  Balaenoptera  Balaenoptera musculus
# 4         NaN      Delphinidae       Orcinus           Orcinus orca
#
#   Population size      Life span  Top speed      Weight     Height  \
# 0         400,000   (10.0, 20.0)       75.0    16-60 kg   80-85 cm
# 1     2,154-3,159   (10.0, 15.0)       96.0   65-306 kg        NaN
# 2         200,000   (20.0, 50.0)       56.0  100-635 kg  70-153 cm
# 3      10-25 Thou   (80.0, 90.0)       20.0   100-160 t        NaN
# 4          50,000  (30.0, 100.0)       45.0       3-6 t        NaN
#
#        Length                                              Biome  \
# 0  105-160 cm  ['Wetlands ', 'Shrubland', 'Forest', 'Mountain...
# 1  200-390 cm  ['Forest', 'Rainforest', 'Montane forest', 'Ri...
# 2   1.4-2.8 m                             ['Forest', 'Woodland']
# 3     25-30 m  ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
# 4       6-9 m  ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
#
#                                       Climate Mating behavior  \
# 0  ['Temperate', 'Cold', 'Polar', 'Tropical']        Monogamy
# 1                   ['Tropical', 'Temperate']        Polygyny
# 2              ['Temperate', 'Cold', 'Polar']   Polygynandry,
# 3  ['Tropical', 'Temperate', 'Cold', 'Polar']        Monogamy
# 4  ['Tropical', 'Temperate', 'Cold', 'Polar']    Polygynandry
#
#              Reproduction season Pregnancy duration Baby carrying  \
# 0                  January-April         60-63 days     1-14 pups
# 1                 November-April           103 days      1-7 cubs
# 2                       May-July            8 weeks      1-4 cubs
# 3         winter or early spring             1 year        1 calf
# 4  year-round, usually in summer       15-18 months        1 calf
#
#   Independent age Female name Male name   Baby name Incubation period  \
# 0         45 days       bitch       dog  pup, whelp               NaN
# 1    18 mos-3 yrs         NaN       NaN         cub               NaN
# 2       2-4 years         sow      boar         cub               NaN
# 3        8 months         cow      bull        calf               NaN
# 4         2 years         cow      bull        calf               NaN
#
#   Population trend   Population status  \
# 0           Stable  Least concern (LC)
# 1       Decreasing     Endangered (EN)
# 2           Stable  Least concern (LC)
# 3       Increasing     Endangered (EN)
# 4              NaN                 NaN
#
#                                           Attributes  \
# 0  ['Nocturnal', 'Carnivore', 'Scavenger', 'Terre...
# 1  ['Nocturnal', 'Carnivore', 'Cursorial', 'Terre...
# 2  ['Crepuscular', 'Omnivore', 'Terrestrial', 'Al...
# 3  ['Carnivore', 'Piscivores', 'Aquatic', 'Precoc...
# 4  ['Diurnal', 'Carnivore', 'Aquatic', 'Precocial...
#
#                                           Continents  \
# 0   ['Asia', ' Europe', ' North America', ' Africa']
# 1                                           ['Asia']
# 2              ['Asia', ' Europe', ' North America']
# 3  ['Africa', ' South America', ' Oceania', ' Nor...
# 4  ['Africa', ' Oceania', ' Antarctica', ' North ...
#
#                                        Subcontinents  \
# 0  ['South Asia', ' Western Asia', ' Southeast As...
# 1    ['South Asia', ' Southeast Asia', ' East Asia']
# 2  ['South Asia', ' Western Asia', ' East Asia', ...
# 3  ['Sub-Saharan Africa', ' Caribbean Islands', '...
# 4  ['North Africa', ' Caribbean Islands', ' South...
#
#                                            Countries  \
# 0  ['Albania', ' Armenia', ' Azerbaijan', ' Belar...
# 1  ['Bangladesh', ' Bhutan', ' China', '', ' Indi...
# 2  ['Albania', ' Armenia', ' Austria', ' Azerbaij...
# 3  ['Angola', ' Argentina', ' Australia', ' Baham...
# 4  ['Algeria', ' Antigua', 'Barbuda', ' Argentina...
#
#                                              Regions  \
# 0  ['Czech Republic', ' Estonia', ' Finland', ' F...
# 1                                       ['Thailand']
# 2                                                 []
# 3  ['Chile', ' China', ' Colombia', ' Comoros', '...
# 4  ['Brunei', ' Cambodia', ' Cameroon', ' Canada'...
#
#                                           Wwf biomes  \
# 0  ['Nearctic', ' Palearctic', ' Indomalayan', ' ...
# 1                     ['Palearctic', ' Indomalayan']
# 2        ['Nearctic', ' Palearctic', ' Indomalayan']
# 3                                                 []
# 4                                                 []
#
#                                     Group name  \
# 0                  ['pack', ' route', ' rout']
# 1                                           []
# 2                         ['sloth', ' sleuth']
# 3  ['pod', ' gam', ' herd', ' school', ' mod']
# 4  ['pod', ' gam', ' herd', ' school', ' mod']
#
#                               Diet  \
# 0   ['Carnivore', '', 'Scavenger']
# 1                    ['Carnivore']
# 2                     ['Omnivore']
# 3  ['Carnivore', '', 'Piscivores']
# 4                    ['Carnivore']
#
#                               Biogeographical realms  \
# 0                                      ['Greenland']
# 1                               ['Tibet', ' Yunnan']
# 2  ['Estonia', ' Finland', ' France', ' Georgia',...
# 3               ['Atlantic Ocean', ' Pacific Ocean']
# 4  ['Arctic Ocean', ' Atlantic Ocean', ' Pacific ...
#
#                                            Lifestyle  \
# 0  ['Terrestrial', ' Cursorial', ' Altricial', ' ...
# 1  ['Cursorial', ' Terrestrial', ' Ambush predato...
# 2  ['Terrestrial', ' Altricial', ' Nomadic', ' Te...
# 3  ['Aquatic', ' Precocial', ' Natatorial', ' Viv...
# 4  ['Aquatic', ' Precocial', ' Cosmopolitan', ' N...
#
#                Seasonal behavior
# 0              ['Not a migrant']
# 1              ['Not a migrant']
# 2  ['Hibernating', ' Migrating']
# 3                  ['Migrating']
# 4            ['Partial Migrant']

# %% [markdown]
# Chuyển các cột nên có dạng list sang kiểu list

# %%
def to_list(x):
    if pd.isna(x): 
        return []
    x = literal_eval(x)
    x = [st.strip() for st in x if st != '']
    return x

# %%
#Chỉ quan tâm những cột có liên quan đến câu hỏi
list_columns = ['Lifestyle', 'Diet', 'Climate', 'Continents', 'Subcontinents', 'Biome', 'Attributes']
for column in list_columns:
    data_df[column] = data_df[column].apply(to_list)

# %% [markdown]
# Xem thử 1 với mỗi cột dạng list thì có những giá trị nào:

# %%
def list_column_view(col):
    count = pd.Series(data_df.explode(col).groupby([col]).size().sort_values(ascending=False))
    total = data_df[col].apply(lambda x: 0 if len(x) == 0 else 1).sum()
    return pd.DataFrame(data = {'count': count, 'ratio': (count / total * 100).round(2)})

# %%
#list_column_view('Diet')
#list_column_view('Lifestyle')
#list_column_view('Subcontinents')
#list_column_view('Continents')
#list_column_view('Biome')
#list_column_view('Climate')
#list_column_view('Attributes')

# %% [markdown]
# Vì có quá nhiều thuộc tính, nên ta chọn các thuộc tính sau (các thuôc tính liên quan nhau thì đặt gần nhau):
#
# Ta quan tâm 14 thuộc tính được chia làm 5 nhóm
# - Social (sống theo bầy đàn) và Solitary (đơn độc)
# - Diurnal (sống ban ngày) và Nocturnal (sống ban đêm)
# - Carnivore (ăn thịt), Hebivore (ăn lá), Insectivores (ăn côn trùng), Omnivore (ăn tạp)
# - Migrating (động vật di cư)
# - Precocial (mới đẻ ra cần chăm sóc) và Altricial (mới đẻ ra có thể tự đi lại) (Thường cho lớp chim)
# - Nomadci (du mục), Arboreal( sống trên cây) và Territorial (Lãnh thổ)

# %%
attributes = ['Social', 'Solitary', 'Diurnal', 'Nocturnal', 'Carnivore', 'Herbivore','Insectivores', 'Omnivore', 
               'Migrating', 'Precocial', 'Altricial', 'Nomadic', 'Arboreal', 'Territorial']

# %%
#Vì chỉ xét các attributes ở trên nên loại bớt các attributes không có
ques1_df = data_df.explode('Attributes')
ques1_df = ques1_df[ques1_df['Attributes'].isin(attributes)]
#ques1_df.head(100)

# %%
def explode_by(col, num_row):
    #Chỉ lấy num_row dòng
    attributes_explode = ques1_df.explode(col)
    rows = attributes_explode.groupby(col).size().sort_values(ascending = False).index[:num_row]
    attributes_explode = attributes_explode[attributes_explode[col].isin(rows)]

    # Tính số động vật của mỗi loại trong col
    col_count = attributes_explode.drop_duplicates(subset = ['Name', col]).groupby(col).size()
   # return col_count
    # Bảng đếm số lượng động vật của mỗi loại trong col ứng với mỗi attributes
    attributes_explode = attributes_explode.groupby([col, 'Attributes']).size()
    attributes_explode= attributes_explode.unstack()
    #Tính % của mỗi attribute trong mỗi loại trong col
    attributes_explode = (attributes_explode.loc[:,"Altricial":"Territorial"].div(col_count, axis=0)*100).round(1)
    
    sns.heatmap(attributes_explode)
    return attributes_explode

# %% [markdown]
# ### Sự thay đổi của attributes theo Continent

# %%
table = explode_by('Continents', 7)
table.head(100)
# Out:
# Attributes     Altricial  Arboreal  Carnivore  Diurnal  Herbivore  \
# Continents
# Africa              30.8      27.5       34.3     44.4       35.5
# Antarctica          37.2      23.3       34.9     44.2       27.9
# Asia                31.7      31.0       34.8     45.1       34.2
# Europe              46.9      37.7       43.4     52.2       35.5
# North America       27.6      24.9       29.9     38.6       23.3
# Oceania             46.2      28.3       37.7     52.8       41.5
# South America       17.8      20.4       20.7     30.1       18.8
#
# Attributes     Insectivores  Migrating  Nocturnal  Nomadic  Omnivore  \
# Continents
# Africa                 15.7       27.0       36.8      8.6      16.9
# Antarctica              9.3       46.5       23.3     11.6      11.6
# Asia                   16.2       27.2       35.9      9.6      19.4
# Europe                 17.5       27.6       33.8      8.8      21.9
# North America          13.1       40.7       22.2      9.8      15.9
# Oceania                 8.5       12.3       56.6     14.2      27.4
# South America          10.3       50.5       16.3      9.5      12.8
#
# Attributes     Precocial  Social  Solitary  Territorial
# Continents
# Africa              17.0    54.0      28.2         28.6
# Antarctica          23.3    65.1      11.6         23.3
# Asia                17.7    51.0      31.3         31.5
# Europe              18.0    55.3      32.5         39.9
# North America       13.5    53.9      20.5         24.0
# Oceania             28.3    55.7      34.9         31.1
# South America        8.8    49.1      13.0         18.3

# %% [markdown]
# ### Sự thay đổi của attributes theo Subcontinents

# %%
table = explode_by('Subcontinents', 9)
table.head(100)
# Out:
# Attributes          Altricial  Arboreal  Carnivore  Diurnal  Herbivore  \
# Subcontinents
# Caribbean Islands        54.8      32.3       45.2     61.3       25.8
# Central America          44.3      32.8       41.0     50.8       37.7
# Central Asia             55.4      32.3       41.5     60.0       38.5
# East Asia                54.4      27.2       40.8     52.8       40.0
# North Africa             58.6      34.5       39.7     56.9       43.1
# South Asia               52.5      28.7       40.6     55.4       38.6
# Southeast Asia           50.4      29.9       34.2     60.7       47.0
# Sub-Saharan Africa       46.4      24.5       37.2     52.0       45.4
# Western Asia             53.7      24.4       32.9     61.0       45.1
#
# Attributes          Insectivores  Migrating  Nocturnal  Nomadic  Omnivore  \
# Subcontinents
# Caribbean Islands            9.7       16.1       45.2     19.4      35.5
# Central America              8.2       19.7       47.5     18.0      24.6
# Central Asia                12.3       23.1       38.5     16.9      26.2
# East Asia                   12.0       18.4       44.8     16.0      24.8
# North Africa                13.8       19.0       41.4     15.5      25.9
# South Asia                  13.9       15.8       48.5     20.8      26.7
# Southeast Asia              12.8       14.5       42.7     18.8      22.2
# Sub-Saharan Africa          12.2       17.9       49.0     11.7      21.9
# Western Asia                 9.8       17.1       40.2     14.6      26.8
#
# Attributes          Precocial  Social  Solitary  Territorial
# Subcontinents
# Caribbean Islands        22.6    64.5      35.5         41.9
# Central America          26.2    59.0      41.0         44.3
# Central Asia             30.8    60.0      32.3         40.0
# East Asia                27.2    53.6      40.8         39.2
# North Africa             25.9    63.8      32.8         43.1
# South Asia               29.7    48.5      44.6         39.6
# Southeast Asia           32.5    54.7      43.6         37.6
# Sub-Saharan Africa       29.1    61.2      32.7         35.2
# Western Asia             29.3    59.8      34.1         40.2

# %% [markdown]
# ### Sự thay đổi của attributes theo biome

# %%
table = explode_by('Biome', 17)
table.head(100)
# Out:
# Attributes            Altricial  Arboreal  Carnivore  Diurnal  Herbivore  \
# Biome
# Agricultural               36.0      29.0       38.1     39.9       31.8
# Anthropogenic biome        18.9      22.4       29.7     34.6       20.2
# Coastal                    31.4      32.7       33.2     48.2       22.7
# Forest                     16.7      21.1       28.9     32.3       22.3
# Freshwater                 19.2      22.0       34.5     38.9       12.9
# Grassland                  24.1      24.5       31.2     38.7       27.7
# Intertidal zone            31.3      34.0       31.3     46.9       21.4
# Marine                     25.9      29.6       32.0     43.9       18.8
# Mountains                  40.8      26.5       33.8     46.0       42.6
# Neritic zone               28.5      30.0       32.3     46.7       21.9
# Oceanic pelagic zone       28.9      28.9       32.0     43.3       23.2
# Rainforest                 31.3      27.1       35.1     46.0       42.4
# Riparian                   38.1      30.7       37.0     55.6       37.6
# Rocky areas                23.9      24.6       37.1     34.5       29.7
# Savanna                    20.3      23.0       28.5     35.8       21.8
# Shrubland                  19.6      22.0       28.7     34.9       23.5
# Wetlands                   22.6      24.2       33.4     39.9       20.5
#
# Attributes            Insectivores  Migrating  Nocturnal  Nomadic  Omnivore  \
# Biome
# Agricultural                  12.2       23.1       40.6      8.4      19.9
# Anthropogenic biome           14.3       43.7       20.2      7.9      11.5
# Coastal                       15.1       42.1       18.9     11.0      16.6
# Forest                        14.4       39.0       25.2      7.4      12.1
# Freshwater                    17.3       49.5       14.0      8.5      10.8
# Grassland                     12.7       34.7       28.0      8.6      14.8
# Intertidal zone               17.3       46.3       15.6      9.2      16.7
# Marine                        14.5       48.6       15.5      9.0      14.3
# Mountains                     11.4       17.6       45.6     12.5      22.8
# Neritic zone                  15.0       45.0       17.0      9.2      16.1
# Oceanic pelagic zone          13.9       42.8       26.3      9.3      20.6
# Rainforest                    12.7       15.2       42.9      9.0      18.1
# Riparian                      12.2       23.8       32.8     10.1      16.4
# Rocky areas                   16.0       26.9       35.0      9.1      10.2
# Savanna                       11.8       40.7       23.4      7.9      13.6
# Shrubland                     12.1       39.9       24.4      8.1      12.7
# Wetlands                      16.7       42.5       19.5      8.1      12.1
#
# Attributes            Precocial  Social  Solitary  Territorial
# Biome
# Agricultural               21.0    50.7      33.9         29.7
# Anthropogenic biome        13.0    46.0      20.0         20.0
# Coastal                    15.8    55.9      19.6         24.0
# Forest                     12.7    44.9      21.7         19.7
# Freshwater                 12.0    46.7      18.2         19.4
# Grassland                  16.7    50.8      25.4         23.6
# Intertidal zone            12.2    58.8      16.0         24.1
# Marine                     11.8    58.4      14.3         23.1
# Mountains                  24.3    56.2      32.0         36.4
# Neritic zone               14.7    57.6      17.0         23.1
# Oceanic pelagic zone       17.0    59.3      19.6         24.7
# Rainforest                 20.9    49.9      36.7         27.1
# Riparian                   23.8    54.5      35.4         32.3
# Rocky areas                18.3    45.2      29.7         24.1
# Savanna                    14.1    48.8      19.8         22.2
# Shrubland                  15.5    47.5      22.6         21.1
# Wetlands                   13.5    47.7      21.5         20.7

# %% [markdown]
# ### Sự thay đổi của attributes theo climate

# %%
table = explode_by('Climate', 5)
table.head(100)
