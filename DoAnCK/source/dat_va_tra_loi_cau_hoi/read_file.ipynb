# %%
import pandas as pd
import numpy as np
from ast import literal_eval
pd.set_option('display.max_columns', None)

# %%
data_df = pd.read_csv("../kham_pha_du_lieu/animals_split_info.csv", index_col = 0)
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df.head()
# Out:
#            Name   Kingdom    Phylum   Subphylum     Class         Order  \
# 0     Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 1         Tiger  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 2    Brown Bear  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 3    Blue Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
# 4  Killer Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
#
#      Suborder           Family         Genus                Species  \
# 0  Caniformia          Canidae         Canis            Canis lupus
# 1  Feliformia          Felidae      Panthera        Panthera tigris
# 2  Caniformia          Ursidae         Ursus           Ursus arctos
# 3         NaN  Balaenopteridae  Balaenoptera  Balaenoptera musculus
# 4         NaN      Delphinidae       Orcinus           Orcinus orca
#
#   Population size   Life span Top speed      Weight     Height      Length  \
# 0         400,000   10-20 yrs   75 km/h    16-60 kg   80-85 cm  105-160 cm
# 1     2,154-3,159   10-15 yrs   96 km/h   65-306 kg        NaN  200-390 cm
# 2         200,000   20-50 yrs   56 km/h  100-635 kg  70-153 cm   1.4-2.8 m
# 3      10-25 Thou   80-90 yrs   20 km/h   100-160 t        NaN     25-30 m
# 4          50,000  30-100 yrs   45 km/h       3-6 t        NaN       6-9 m
#
#   Introduced countries Seas Islands  \
# 0                  NaN  NaN     NaN
# 1                  NaN  NaN     NaN
# 2                  NaN  NaN     NaN
# 3                  NaN  NaN     NaN
# 4                  NaN  NaN     NaN
#
#                                                Biome  \
# 0  ['Wetlands ', 'Shrubland', 'Forest', 'Mountain...
# 1  ['Forest', 'Rainforest', 'Montane forest', 'Ri...
# 2                             ['Forest', 'Woodland']
# 3  ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
# 4  ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
#
#                                       Climate       Seasonal behavior  \
# 0  ['Temperate', 'Cold', 'Polar', 'Tropical']           Not a migrant
# 1                   ['Tropical', 'Temperate']           Not a migrant
# 2              ['Temperate', 'Cold', 'Polar']  Hibernating, Migrating
# 3  ['Tropical', 'Temperate', 'Cold', 'Polar']               Migrating
# 4  ['Tropical', 'Temperate', 'Cold', 'Polar']         Partial Migrant
#
#   Predators Bird's call Mating behavior            Reproduction season  \
# 0       NaN         NaN        Monogamy                  January-April
# 1       NaN         NaN        Polygyny                 November-April
# 2       NaN         NaN   Polygynandry,                       May-July
# 3       NaN         NaN        Monogamy         winter or early spring
# 4       NaN         NaN    Polygynandry  year-round, usually in summer
#
#   Pregnancy duration Baby carrying Independent age Female name Male name  \
# 0         60-63 days     1-14 pups         45 days       bitch       dog
# 1           103 days      1-7 cubs    18 mos-3 yrs         NaN       NaN
# 2            8 weeks      1-4 cubs       2-4 years         sow      boar
# 3             1 year        1 calf        8 months         cow      bull
# 4       15-18 months        1 calf         2 years         cow      bull
#
#     Baby name Incubation period Population trend   Population status  \
# 0  pup, whelp               NaN           Stable  Least concern (LC)
# 1         cub               NaN       Decreasing     Endangered (EN)
# 2         cub               NaN           Stable  Least concern (LC)
# 3        calf               NaN       Increasing     Endangered (EN)
# 4        calf               NaN              NaN                 NaN
#
#                                           Attributes  \
# 0  ['Nocturnal', 'Carnivore', 'Scavenger', 'Terre...
# 1  ['Nocturnal', 'Carnivore', 'Cursorial', 'Terre...
# 2  ['Crepuscular', 'Omnivore', 'Terrestrial', 'Al...
# 3  ['Carnivore', 'Piscivores', 'Aquatic', 'Precoc...
# 4  ['Diurnal', 'Carnivore', 'Aquatic', 'Precocial...
#
#                                           Continents  \
# 0   ['Asia', ' Europe', ' North America', ' Africa']
# 1                                           ['Asia']
# 2              ['Asia', ' Europe', ' North America']
# 3  ['Africa', ' South America', ' Oceania', ' Nor...
# 4  ['Africa', ' Oceania', ' Antarctica', ' North ...
#
#                                        Subcontinents  \
# 0  ['South Asia', ' Western Asia', ' Southeast As...
# 1    ['South Asia', ' Southeast Asia', ' East Asia']
# 2  ['South Asia', ' Western Asia', ' East Asia', ...
# 3  ['Sub-Saharan Africa', ' Caribbean Islands', '...
# 4  ['North Africa', ' Caribbean Islands', ' South...
#
#                                            Countries  \
# 0  ['Albania', ' Armenia', ' Azerbaijan', ' Belar...
# 1  ['Bangladesh', ' Bhutan', ' China', '   India'...
# 2  ['Albania', ' Armenia', ' Austria', ' Azerbaij...
# 3  ['Angola', ' Argentina', ' Australia', ' Baham...
# 4  ['Algeria', ' Antigua and Barbuda', ' Argentin...
#
#                                              Regions  \
# 0  ['Czech Republic', ' Estonia', ' Finland', ' F...
# 1                                       ['Thailand']
# 2                                                 []
# 3  ['Chile', ' China', ' Colombia', ' Comoros', '...
# 4  ['Brunei', ' Cambodia', ' Cameroon', ' Canada'...
#
#                                           Wwf biomes  \
# 0  ['Nearctic', ' Palearctic', ' Indomalayan', ' ...
# 1                     ['Palearctic', ' Indomalayan']
# 2        ['Nearctic', ' Palearctic', ' Indomalayan']
# 3                                                 []
# 4                                                 []
#
#                                     Group name  \
# 0                  ['pack', ' route', ' rout']
# 1                                           []
# 2                         ['sloth', ' sleuth']
# 3  ['pod', ' gam', ' herd', ' school', ' mod']
# 4  ['pod', ' gam', ' herd', ' school', ' mod']
#
#                               Diet  \
# 0   ['Carnivore', '', 'Scavenger']
# 1                    ['Carnivore']
# 2                     ['Omnivore']
# 3  ['Carnivore', '', 'Piscivores']
# 4                    ['Carnivore']
#
#                               Biogeographical realms  \
# 0                                      ['Greenland']
# 1                               ['Tibet', ' Yunnan']
# 2  ['Estonia', ' Finland', ' France', ' Georgia',...
# 3               ['Atlantic Ocean', ' Pacific Ocean']
# 4  ['Arctic Ocean', ' Atlantic Ocean', ' Pacific ...
#
#                                            Lifestyle  \
# 0  ['Terrestrial', ' Cursorial', ' Altricial', ' ...
# 1  ['Cursorial', ' Terrestrial', ' Ambush predato...
# 2  ['Terrestrial', ' Altricial', ' Nomadic', ' Te...
# 3  ['Aquatic', ' Precocial', ' Natatorial', ' Viv...
# 4  ['Aquatic', ' Precocial', ' Cosmopolitan', ' N...
#
#                                       Oceans
# 0                                         []
# 1                                         []
# 2                                         []
# 3                ['Greenland', ' Kamchatka']
# 4  ['Newfoundland', ' Hawaii', ' Greenland']

# %%
for i in data_df:
    if type(data_df[i][0]) == str and data_df[i][0][0] == "[":
        data_df[i] = data_df[i].apply(literal_eval)

# %%
def stat_list_col(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.hstack(temp)
    temp = list(map(str.strip, temp)) # Xử lý các dấu cách đầu và cuối mỗi chuỗi
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

# %%
list_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in data_df:
    if type(data_df[i][0]) == list:
        list_col_info_df[i] = stat_list_col(i, data_df)
list_col_info_df
# Out:
#                                                            Biome  \
# missing_ratio                                                0.0
# num_values                                                    43
# value          Abyssal zone               4
# Agricultural     ...
#
#                                                          Climate  \
# missing_ratio                                                0.0
# num_values                                                     6
# value          Arid          304
# Cold          309
# Libya     ...
#
#                                                       Attributes  \
# missing_ratio                                                0.0
# num_values                                                   139
# value          Aestivation              71
# Algivore          ...
#
#                                                       Continents  \
# missing_ratio                                                0.0
# num_values                                                    76
# value                                  3
# Africa              ...
#
#                                                    Subcontinents  \
# missing_ratio                                                0.0
# num_values                                                    89
# value                                       12
# Afghanistan   ...
#
#                                                        Countries  \
# missing_ratio                                                0.0
# num_values                                                   251
# value                            884
# Afghanistan        66
# Af...
#
#                                                          Regions  \
# missing_ratio                                                0.0
# num_values                                                   394
# value                          65
# Acre             2
# Afghanis...
#
#                                                       Wwf biomes  \
# missing_ratio                                                0.0
# num_values                                                   249
# value                                                        ...
#
#                                                       Group name  \
# missing_ratio                                                0.0
# num_values                                                   402
# value                            1
# "bind"            1
# "littl...
#
#                                                             Diet  \
# missing_ratio                                                0.0
# num_values                                                    30
# value                            2941
# Algivore            16
# ...
#
#                                           Biogeographical realms  \
# missing_ratio                                                0.0
# num_values                                                   391
# value                                                       3...
#
#                                                        Lifestyle  \
# missing_ratio                                                0.0
# num_values                                                    51
# value                                              1784
# Aesti...
#
#                                                           Oceans
# missing_ratio                                                0.0
# num_values                                                   253
# value                               10
# Afghanistan           ...
