# %%
import pandas as pd
import numpy as np
from ast import literal_eval
pd.set_option('display.max_columns', None)

# %%
data_df = pd.read_csv("../kham_pha_du_lieu/animals_split_info.csv", index_col = 0)
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df
# Out:
# /home/lexua/miniconda3/envs/min_ds-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3139: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0                        Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                            Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                       Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                       Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                     Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                            ...       ...       ...         ...       ...
# 29350            Córdoba cinclodes  Animalia  Chordata         NaN      Aves
# 29351          Western hemispingus  Animalia  Chordata         NaN      Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata         NaN      Aves
# 29355        McConnell's spinetail  Animalia  Chordata         NaN      Aves
# 29356              Junín canastero  Animalia  Chordata         NaN      Aves
#
#                Order    Suborder           Family         Genus  \
# 0          Carnivora  Caniformia          Canidae         Canis
# 1          Carnivora  Feliformia          Felidae      Panthera
# 2          Carnivora  Caniformia          Ursidae         Ursus
# 3       Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4       Artiodactyla         NaN      Delphinidae       Orcinus
# ...              ...         ...              ...           ...
# 29350  Passeriformes         NaN      Furnariidae     Cinclodes
# 29351  Passeriformes         NaN       Thraupidae    Sphenopsis
# 29352  Passeriformes         NaN      Furnariidae   Cranioleuca
# 29355  Passeriformes         NaN      Furnariidae    Synallaxis
# 29356  Passeriformes         NaN      Furnariidae      Asthenes
#
#                          Species Population size      Life span  Top speed  \
# 0                    Canis lupus         400,000   (10.0, 20.0)       75.0
# 1                Panthera tigris     2,154-3,159   (10.0, 15.0)       96.0
# 2                   Ursus arctos         200,000   (20.0, 50.0)       56.0
# 3          Balaenoptera musculus      10-25 Thou   (80.0, 90.0)       20.0
# 4                   Orcinus orca          50,000  (30.0, 100.0)       45.0
# ...                          ...             ...            ...        ...
# 29350    Cinclodes comechingonus             NaN     (nan, nan)        NaN
# 29351        Sphenopsis ochracea             NaN     (nan, nan)        NaN
# 29352  Limnoctites sulphuriferus             NaN     (nan, nan)        NaN
# 29355     Synallaxis macconnelli             NaN     (nan, nan)        NaN
# 29356           Asthenes virgata             NaN     (nan, nan)        NaN
#
#            Weight     Height      Length  \
# 0        16-60 kg   80-85 cm  105-160 cm
# 1       65-306 kg        NaN  200-390 cm
# 2      100-635 kg  70-153 cm   1.4-2.8 m
# 3       100-160 t        NaN     25-30 m
# 4           3-6 t        NaN       6-9 m
# ...           ...        ...         ...
# 29350         NaN        NaN         NaN
# 29351         NaN        NaN         NaN
# 29352         NaN        NaN         NaN
# 29355         NaN        NaN         NaN
# 29356         NaN        NaN         NaN
#
#                                                    Biome  \
# 0      ['Wetlands ', 'Shrubland', 'Forest', 'Mountain...
# 1      ['Forest', 'Rainforest', 'Montane forest', 'Ri...
# 2                                 ['Forest', 'Woodland']
# 3      ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
# 4      ['Oceanic pelagic zone', 'Marine', 'Neritic zo...
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                                NaN
# 29356                                                NaN
#
#                                           Climate Mating behavior  \
# 0      ['Temperate', 'Cold', 'Polar', 'Tropical']        Monogamy
# 1                       ['Tropical', 'Temperate']        Polygyny
# 2                  ['Temperate', 'Cold', 'Polar']   Polygynandry,
# 3      ['Tropical', 'Temperate', 'Cold', 'Polar']        Monogamy
# 4      ['Tropical', 'Temperate', 'Cold', 'Polar']    Polygynandry
# ...                                           ...             ...
# 29350                                         NaN             NaN
# 29351                                         NaN             NaN
# 29352                                         NaN             NaN
# 29355                                         NaN             NaN
# 29356                                         NaN             NaN
#
#                  Reproduction season Pregnancy duration Baby carrying  \
# 0                      January-April         60-63 days     1-14 pups
# 1                     November-April           103 days      1-7 cubs
# 2                           May-July            8 weeks      1-4 cubs
# 3             winter or early spring             1 year        1 calf
# 4      year-round, usually in summer       15-18 months        1 calf
# ...                              ...                ...           ...
# 29350                            NaN                NaN           NaN
# 29351                            NaN                NaN           NaN
# 29352                            NaN                NaN           NaN
# 29355                            NaN                NaN           NaN
# 29356                            NaN                NaN           NaN
#
#       Independent age Female name Male name   Baby name Incubation period  \
# 0             45 days       bitch       dog  pup, whelp               NaN
# 1        18 mos-3 yrs         NaN       NaN         cub               NaN
# 2           2-4 years         sow      boar         cub               NaN
# 3            8 months         cow      bull        calf               NaN
# 4             2 years         cow      bull        calf               NaN
# ...               ...         ...       ...         ...               ...
# 29350             NaN         NaN       NaN         NaN               NaN
# 29351             NaN         NaN       NaN         NaN               NaN
# 29352             NaN         NaN       NaN         NaN               NaN
# 29355             NaN         NaN       NaN         NaN               NaN
# 29356             NaN         NaN       NaN         NaN               NaN
#
#       Population trend   Population status  \
# 0               Stable  Least concern (LC)
# 1           Decreasing     Endangered (EN)
# 2               Stable  Least concern (LC)
# 3           Increasing     Endangered (EN)
# 4                  NaN                 NaN
# ...                ...                 ...
# 29350              NaN                 NaN
# 29351              NaN                 NaN
# 29352              NaN                 NaN
# 29355              NaN                 NaN
# 29356              NaN                 NaN
#
#                                               Attributes  \
# 0      ['Nocturnal', 'Carnivore', 'Scavenger', 'Terre...
# 1      ['Nocturnal', 'Carnivore', 'Cursorial', 'Terre...
# 2      ['Crepuscular', 'Omnivore', 'Terrestrial', 'Al...
# 3      ['Carnivore', 'Piscivores', 'Aquatic', 'Precoc...
# 4      ['Diurnal', 'Carnivore', 'Aquatic', 'Precocial...
# ...                                                  ...
# 29350        ['Terrestrial', 'Migrating', 'starts with']
# 29351    ['Terrestrial', 'Not a migrant', 'starts with']
# 29352        ['Terrestrial', 'Migrating', 'starts with']
# 29355    ['Terrestrial', 'Not a migrant', 'starts with']
# 29356    ['Terrestrial', 'Not a migrant', 'starts with']
#
#                                               Continents  \
# 0       ['Asia', ' Europe', ' North America', ' Africa']
# 1                                               ['Asia']
# 2                  ['Asia', ' Europe', ' North America']
# 3      ['Africa', ' South America', ' Oceania', ' Nor...
# 4      ['Africa', ' Oceania', ' Antarctica', ' North ...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                            Subcontinents  \
# 0      ['South Asia', ' Western Asia', ' Southeast As...
# 1        ['South Asia', ' Southeast Asia', ' East Asia']
# 2      ['South Asia', ' Western Asia', ' East Asia', ...
# 3      ['Sub-Saharan Africa', ' Caribbean Islands', '...
# 4      ['North Africa', ' Caribbean Islands', ' South...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                                Countries  \
# 0      ['Albania', ' Armenia', ' Azerbaijan', ' Belar...
# 1      ['Bangladesh', ' Bhutan', ' China', '', ' Indi...
# 2      ['Albania', ' Armenia', ' Austria', ' Azerbaij...
# 3      ['Angola', ' Argentina', ' Australia', ' Baham...
# 4      ['Algeria', ' Antigua', 'Barbuda', ' Argentina...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                                  Regions  \
# 0      ['Czech Republic', ' Estonia', ' Finland', ' F...
# 1                                           ['Thailand']
# 2                                                     []
# 3      ['Chile', ' China', ' Colombia', ' Comoros', '...
# 4      ['Brunei', ' Cambodia', ' Cameroon', ' Canada'...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                               Wwf biomes  \
# 0      ['Nearctic', ' Palearctic', ' Indomalayan', ' ...
# 1                         ['Palearctic', ' Indomalayan']
# 2            ['Nearctic', ' Palearctic', ' Indomalayan']
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                         Group name  \
# 0                      ['pack', ' route', ' rout']
# 1                                               []
# 2                             ['sloth', ' sleuth']
# 3      ['pod', ' gam', ' herd', ' school', ' mod']
# 4      ['pod', ' gam', ' herd', ' school', ' mod']
# ...                                            ...
# 29350                                           []
# 29351                                           []
# 29352                                           []
# 29355                                           []
# 29356                                           []
#
#                                   Diet  \
# 0       ['Carnivore', '', 'Scavenger']
# 1                        ['Carnivore']
# 2                         ['Omnivore']
# 3      ['Carnivore', '', 'Piscivores']
# 4                        ['Carnivore']
# ...                                ...
# 29350                               []
# 29351                               []
# 29352                               []
# 29355                               []
# 29356                               []
#
#                                   Biogeographical realms  \
# 0                                          ['Greenland']
# 1                                   ['Tibet', ' Yunnan']
# 2      ['Estonia', ' Finland', ' France', ' Georgia',...
# 3                   ['Atlantic Ocean', ' Pacific Ocean']
# 4      ['Arctic Ocean', ' Atlantic Ocean', ' Pacific ...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                                Lifestyle  \
# 0      ['Terrestrial', ' Cursorial', ' Altricial', ' ...
# 1      ['Cursorial', ' Terrestrial', ' Ambush predato...
# 2      ['Terrestrial', ' Altricial', ' Nomadic', ' Te...
# 3      ['Aquatic', ' Precocial', ' Natatorial', ' Viv...
# 4      ['Aquatic', ' Precocial', ' Cosmopolitan', ' N...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                    Seasonal behavior
# 0                  ['Not a migrant']
# 1                  ['Not a migrant']
# 2      ['Hibernating', ' Migrating']
# 3                      ['Migrating']
# 4                ['Partial Migrant']
# ...                              ...
# 29350                             []
# 29351                             []
# 29352                             []
# 29355                             []
# 29356                             []
#
# [28525 rows x 40 columns]

# %%
for i in data_df:
    if type(data_df[i][0]) == str and data_df[i][0][0] == "[":
        data_df[i] = data_df[i].apply(literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 3
#       1 for i in data_df:
#       2     if type(data_df[i][0]) == str and data_df[i][0][0] == "[":
# ----> 3         data_df[i] = data_df[i].apply(literal_eval)
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/site-packages/pandas/core/series.py:4138, in Series.apply(self, func, convert_dtype, args, **kwds)
#    4136     else:
#    4137         values = self.astype(object)._values
# -> 4138         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4140 if len(mapped) and isinstance(mapped[0], Series):
#    4141     # GH 25959 use pd.array instead of tolist
#    4142     # so extension arrays can be used
#    4143     return self._constructor_expanddim(pd_array(mapped), index=self.index)
#
# File pandas/_libs/lib.pyx:2467, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/ast.py:99, in literal_eval(node_or_string)
#      97                 return left - right
#      98     return _convert_signed_num(node)
# ---> 99 return _convert(node_or_string)
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/ast.py:98, in literal_eval.<locals>._convert(node)
#      96         else:
#      97             return left - right
# ---> 98 return _convert_signed_num(node)
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/ast.py:75, in literal_eval.<locals>._convert_signed_num(node)
#      73     else:
#      74         return - operand
# ---> 75 return _convert_num(node)
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/ast.py:66, in literal_eval.<locals>._convert_num(node)
#      64 def _convert_num(node):
#      65     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 66         _raise_malformed_node(node)
#      67     return node.value
#
# File ~/miniconda3/envs/min_ds-env/lib/python3.8/ast.py:63, in literal_eval.<locals>._raise_malformed_node(node)
#      62 def _raise_malformed_node(node):
# ---> 63     raise ValueError(f'malformed node or string: {node!r}')
#
# ValueError: malformed node or string: nan

# %%
def stat_list_col(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.hstack(temp)
    temp = list(map(str.strip, temp)) # Xử lý các dấu cách đầu và cuối mỗi chuỗi
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

# %%
list_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in data_df:
    if type(data_df[i][0]) == list:
        list_col_info_df[i] = stat_list_col(i, data_df)
list_col_info_df
# Out:
#                                                            Biome  \
# missing_ratio                                                0.0
# num_values                                                    43
# value          Abyssal zone               4
# Agricultural     ...
#
#                                                          Climate  \
# missing_ratio                                                0.0
# num_values                                                     6
# value          Arid          304
# Cold          309
# Libya     ...
#
#                                                       Attributes  \
# missing_ratio                                                0.0
# num_values                                                   139
# value          Aestivation              71
# Algivore          ...
#
#                                                       Continents  \
# missing_ratio                                                0.0
# num_values                                                    76
# value                                  3
# Africa              ...
#
#                                                    Subcontinents  \
# missing_ratio                                                0.0
# num_values                                                    89
# value                                       12
# Afghanistan   ...
#
#                                                        Countries  \
# missing_ratio                                                0.0
# num_values                                                   251
# value                            884
# Afghanistan        66
# Af...
#
#                                                          Regions  \
# missing_ratio                                                0.0
# num_values                                                   394
# value                          65
# Acre             2
# Afghanis...
#
#                                                       Wwf biomes  \
# missing_ratio                                                0.0
# num_values                                                   249
# value                                                        ...
#
#                                                       Group name  \
# missing_ratio                                                0.0
# num_values                                                   402
# value                            1
# "bind"            1
# "littl...
#
#                                                             Diet  \
# missing_ratio                                                0.0
# num_values                                                    30
# value                            2941
# Algivore            16
# ...
#
#                                           Biogeographical realms  \
# missing_ratio                                                0.0
# num_values                                                   391
# value                                                       3...
#
#                                                        Lifestyle  \
# missing_ratio                                                0.0
# num_values                                                    51
# value                                              1784
# Aesti...
#
#                                                           Oceans
# missing_ratio                                                0.0
# num_values                                                   253
# value                               10
# Afghanistan           ...
