# %% [markdown]
# # Khám phá dữ liệu

# %% [markdown]
# Notebook này để khám phá dữ liệu.

# %% [markdown]
# ## Import những thư viện cần thiết

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Đọc dữ liệu từ file

# %% [markdown]
# File dữ liệu của đồ án sau bước thu thập dữ liệu đang nằm tại địa chỉ '../thu_thap_du_lieu/animal_crawler/animal_info.csv'. Ta sẽ tiến hành đọc dữ liệu đã thu thập và lưu vào DataFrame `animal_df`

# %%
animal_df = pd.read_csv('../thu_thap_du_lieu/animal_crawler/animals_info.csv')

# %% [markdown]
# Hiển thị 5 dòng đầu tiên trong dữ liệu để xem thử đã đọc đúng hay chưa

# %%
animal_df.head(5)
# Out:
#            Name   Kingdom    Phylum   Subphylum     Class         Order  \
# 0     Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 1         Tiger  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 2    Brown Bear  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 3    Blue Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
# 4  Killer Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
#
#      Suborder           Family         Genus                Species  ...  \
# 0  Caniformia          Canidae         Canis            Canis lupus  ...
# 1  Feliformia          Felidae      Panthera        Panthera tigris  ...
# 2  Caniformia          Ursidae         Ursus           Ursus arctos  ...
# 3         NaN  Balaenopteridae  Balaenoptera  Balaenoptera musculus  ...
# 4         NaN      Delphinidae       Orcinus           Orcinus orca  ...
#
#   Top speed      Weight     Height      Length  \
# 0   75 km/h    16-60 kg   80-85 cm  105-160 cm
# 1   96 km/h   65-306 kg        NaN  200-390 cm
# 2   56 km/h  100-635 kg  70-153 cm   1.4-2.8 m
# 3   20 km/h   100-160 t        NaN     25-30 m
# 4   45 km/h       3-6 t        NaN       6-9 m
#
#                                           Attributes  \
# 0  Nocturnal,Carnivore,Scavenger,Terrestrial,Curs...
# 1  Nocturnal,Carnivore,Cursorial,Terrestrial,Ambu...
# 2  Crepuscular,Omnivore,Terrestrial,Altricial,Nom...
# 3  Carnivore,Piscivores,Aquatic,Precocial,Natator...
# 4  Diurnal,Carnivore,Aquatic,Precocial,Cosmopolit...
#
#                                         Distribution  \
# 0  {'Geography': {'Continents': 'Asia, Europe, No...
# 1  {'Geography': {'Continents': 'Asia', 'Subconti...
# 2  {'Geography': {'Continents': 'Asia, Europe, No...
# 3  {'Geography': {'Continents': 'Africa, South Am...
# 4  {'Geography': {'Continents': 'Africa, Oceania,...
#
#                                               Habits                   Diet  \
# 0  {'Group name': 'pack, route, rout', 'Lifestyle...   Carnivore,,Scavenger
# 1  {'Lifestyle': 'Cursorial, Terrestrial, Ambush ...              Carnivore
# 2  {'Group name': 'sloth, sleuth', 'Lifestyle': '...               Omnivore
# 3  {'Group name': 'pod, gam, herd, school, mod', ...  Carnivore,,Piscivores
# 4  {'Group name': 'pod, gam, herd, school, mod', ...              Carnivore
#
#                                        Mating_Habits  \
# 0  {'Mating behavior': 'Monogamy', 'Reproduction ...
# 1  {'Mating behavior': 'Polygyny', 'Reproduction ...
# 2  {'Mating behavior': 'Polygynandry,', 'Reproduc...
# 3  {'Mating behavior': 'Monogamy', 'Reproduction ...
# 4  {'Mating behavior': 'Polygynandry', 'Reproduct...
#
#                                           Population
# 0  {'Population trend': 'Stable', 'Population sta...
# 1  {'Population trend': 'Decreasing', 'Population...
# 2  {'Population trend': 'Stable', 'Population sta...
# 3  {'Population trend': 'Increasing', 'Population...
# 4       {'Population status': 'Data deficient (DD)'}
#
# [5 rows x 22 columns]

# %% [markdown]
# Xem xét dữ liệu trên thì thấy một số dòng bị lỗi, cần loại bỏ.
# Cụ thể ở đây là thu thập dữ liệu về thú nhưng có một số dòng có giá trị cột 'Kingdom' không phải là 'Animalia'. Ở đây ta sẽ xóa luôn những dòng như thế, vì dữ liệu khá lớn nên xóa bớt một vài dòng có lẽ sẽ không có ảnh hưởng nhiều.

# %%
animal_df = animal_df[animal_df['Kingdom'] == 'Animalia']

# %% [markdown]
# ## Dữ liệu có bao nhiêu dòng, bao nhiêu cột?

# %%
animal_df.shape
# Out:
# (28525, 22)

# %% [markdown]
# ## Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng cho chúng ta biết các thông tin về một con vật, tất cả các dòng đều có cùng ý nghĩa như nhau.

# %% [markdown]
# ## Dữ liệu có các dòng bị lặp không?

# %% [markdown]
# Chúng ta sử dụng hàm 'duplicated' trong pandas để kiểm tra dòng đó có phải bị lặp trong DataFrame hay không. Nếu kết quả là dòng đó bị lặp sẽ trả về giá trị 1, ngược lại sẽ là 0. Kế tiếp chúng ta sử dùng hàm 'sum' để tính tất cả giá trị trả về của hàm 'duplicated'. Nếu kết quả > 0 thì chứng tỏ có tồn tại dòng bị lặp.

# %%
animal_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Vậy là dữ liệu của chúng ta không tồn lại dòng nào bị lặp lại.

# %% [markdown]
# ## Mỗi cột có ý nghĩa gì?

# %% [markdown]
# Sau khi thu thập dữ liệu xong, nhóm em đã tự phân tích ý nghĩa của mỗi trong file dữ liệu vừa thu thập, sau đó viết vào file `col_meaning.xlsx`. Đọc file excel này để biết được ý nghĩa của mỗi cột.

# %%
xlsx = pd.ExcelFile('col_meaning.xlsx')
col_meaning_df =pd.read_excel(xlsx,"Sheet1")
pd.set_option('display.max_colwidth', 0)
col_meaning_df
# Out:
#              Column  \
# 0   Name
# 1   Kingdom
# 2   Phylum
# 3   Subphylum
# 4   Class
# 5   Order
# 6   Suborder
# 7   Family
# 8   Genus
# 9   Species
# 10  Population size
# 11  Life span
# 12  Top speed
# 13  Weight
# 14  Height
# 15  Length
# 16  Attributes
# 17  Distribution
# 18  Habits
# 19  Diet
# 20  Mating_Habits
# 21  Population
#
#                                                                                                                                                   Description
# 0   Name of Animal
# 1   Giới là đơn vị phân loại lớn nhất bao gồm các ngành sinh vật có chung những đặc điểm nhất định.
# 2   Ngành: Một đơn vị phân loại ở cấp dưới giới và trên lớp.
# 3   Phân Ngành: là một bậc phân loại nằm trung gian giữa ngành và lớp hoặc phân thứ ngành hoặc liên lớp
# 4   Lớp: Một mức độ phân loại động vật trong một ngành. Các lớp sau đó được chia nhỏ thành các nhóm khác được gọi là bộ
# 5   Bộ: là một cấp nằm giữa lớp và họ.
# 6   Phân bộ: một nhóm thực vật hoặc động vật có liên quan, có quan hệ gần gũi hơn so với một bộ nhưng ít giống nhau hơn so với một họ.
# 7   Họ: Bộ được chia thành các họ, họ sẽ được chia thành các chi
# 8   Chi: còn gọi là giống là một đơn vị phân loại sinh học dùng để chỉ một hoặc một nhóm loài có kiểu hình tương tự và mối quan hệ tiến hóa gần gũi với nhau.
# 9   Loài: là một nhóm các cá thể sinh vật có những đặc điểm sinh học tương đối giống nhau và có khả năng giao phối với nhau và sinh sản ra thế hệ tương lai.
# 10  Ước tính số cá thể đang sống của loài
# 11  Tuổi thọ
# 12  Tốc độ
# 13  Cân nặng
# 14  Chiều cao
# 15  Chiều dài
# 16  Một số thông tin chính về loài vật
# 17  Phân bổ: Nơi sinh sống
# 18  Thói quen
# 19  Chế độ ăn (ăn cỏ, ăn tạp,…)
# 20  Thói quen giao phối
# 21  Bao gồm xu hướng dân số (tăng, giảm, ổn định) và trạng thái dân số (nguy cấp, bị đe dọa, ít quan tâm,…)

# %% [markdown]
# ## Các cột lúc này đang có kiểu dữ liệu gì?

# %%
animal_df.dtypes
# Out:
# Name               object
# Kingdom            object
# Phylum             object
# Subphylum          object
# Class              object
# Order              object
# Suborder           object
# Family             object
# Genus              object
# Species            object
# Population size    object
# Life span          object
# Top speed          object
# Weight             object
# Height             object
# Length             object
# Attributes         object
# Distribution       object
# Habits             object
# Diet               object
# Mating_Habits      object
# Population         object
# dtype: object

# %% [markdown]
# ## Tính xem tình trạng của mỗi cột dữ liệu hiện tại như thế nào?

# %% [markdown]
# ### Với mỗi cột ta sẽ tính:
# - Tỉ lệ mất mát: missing_ratio
# - Số lượng giá trị khác nhau: num_values
# - Số lần xuất hiện của từng giá trị: value
#
# Viết hàm "col_info" để tính và lưu kết quả vào mảng "cat_col_info_df"

# %%
def col_info(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

# %%
cat_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in animal_df.columns:
    if animal_df[i].dtype not in [float, int]:
        cat_col_info_df[i] = col_info(i, animal_df)

cat_col_info_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                           Name  \
# missing_ratio  0.0
# num_values     28525
# value          ? Nycticebus linglom      1
# AEECL's sportive lemur    1
# Aaadonta angaurana        1
# Aaadonta constricta       1
# Aaadonta fuscozonata      1
#                          ..
# ʻAkohekohe                1
# ʻAnianiau                 1
# ʻApapane                  1
# ʻEua rail                 1
# ʻIʻiwi                    1
# Length: 28525, dtype: int64
#
#                                       Kingdom  \
# missing_ratio  0.0
# num_values     1
# value          Animalia    28525
# dtype: int64
#
#                                                          Phylum  \
# missing_ratio  0.0
# num_values     2
# value          Chordata    23659
# Mollusca    4866
# dtype: int64
#
#                                       Subphylum  \
# missing_ratio  64.4
# num_values     1
# value          Vertebrata    10152
# dtype: int64
#
#                                                                                                                                                                                                                                                                       Class  \
# missing_ratio  0.0
# num_values     10
# value          Amphibia          3393
# Aves              10114
# Bivalvia          515
# Cephalopoda       336
# Gastropoda        3991
# Mammalia          5879
# Polyplacophora    10
# Reptilia          4273
# Scaphopoda        13
# Solenogastres     1
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                 Order  \
# missing_ratio  1.5
# num_values     118
# value          Accipitriformes    255
# Adapedonta         10
# Aegotheliformes    11
# Afrosoricida       56
# Anomalodesmata     18
#                    ..
# Trogoniformes      41
# Tubulidentata      2
# Unionoida          217
# Vampyromorphida    1
# Venerida           89
# Length: 118, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                            Suborder  \
# missing_ratio  91.0
# num_values     13
# value          Alcedini           109
# Caniformia         192
# Cryptodira         212
# Feliformia         100
# Haplorhini         271
# Iguania            324
# Lari               1
# Macropodiformes    2
# Phalangerida       2
# Pleurodira         43
# Ruminantia         54
# Serpentes          1132
# Strepsirrhini      122
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                                      Family  \
# missing_ratio  0.0
# num_values     840
# value          Abrocomidae          10
# Abronicidae          2
# Acanthisittidae      2
# Acanthizidae         59
# Acanthochitonidae    3
#                     ..
# Zebinidae            7
# Zeledoniidae         1
# Ziphiidae            21
# Zonitidae            1
# Zosteropidae         124
# Length: 840, dtype: int64
#
#                                                                                                                                                                                                                                           Genus  \
# missing_ratio  0.0
# num_values     6127
# value          Aaadonta        6
# Abditomys       1
# Abeillia        1
# Abeomelomys     1
# Ablepharus      9
#                ..
# Zosterornis     5
# Zygaspis        8
# Zygodontomys    2
# Zygogeomys      1
# Zyzomys         5
# Length: 6127, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                           Species  \
# missing_ratio  0.0
# num_values     28523
# value          "Calamita" melanorabdotus          1
# "Calamita" quadrilineatus          1
# "Centrolene" acanthidiocephalum    1
# "Centrolene" azulae                1
# "Centrolene" guanacarum            1
#                                   ..
# Zyzomys argurus                    1
# Zyzomys maini                      1
# Zyzomys palatalis                  1
# Zyzomys pedunculatus               1
# Zyzomys woodwardi                  1
# Length: 28523, dtype: int64
#
#                ...  \
# missing_ratio  ...
# num_values     ...
# value          ...
#
#                                                                                                                                                                                                     Top speed  \
# missing_ratio  98.0
# num_values     124
# value          0.24 km/h    1
# 0.26 km/h    1
# 0.27 km/h    1
# 0.5 km/h     4
# 10 km/h      5
#             ..
# 93 km/h      1
# 95 km/h      2
# 96 km/h      4
# 96.6 km/h    2
# 98 km/h      1
# Length: 124, dtype: int64
#
#                                                                                                                                                                                                                                                                Weight  \
# missing_ratio  90.0
# num_values     2232
# value          0-0 kg            3
# 0.010-0.796 g     1
# 0.02-22.5 kg      2
# 0.030-0.067 kg    1
# 0.056-1.65 kg     1
#                  ..
# up to 50 g        1
# up to 50 kg       1
# up to 6 kg        1
# up to 7kg         1
# up to 9 kg        1
# Length: 2232, dtype: int64
#
#                                                                                                                                                                                                                              Height  \
# missing_ratio  98.9
# num_values     245
# value          0.5 m          1
# 0.7-1.3 m      1
# 0.75-1 m       2
# 0.8-1.5 m      1
# 0.9 m          1
#               ..
# 95-130 cm      1
# 97-140 cm      1
# 99-125 cm      1
# over 1 m       1
# up to 80 cm    1
# Length: 245, dtype: int64
#
#                                                                                                                                                                                                                               Length  \
# missing_ratio  89.7
# num_values     2101
# value          0.5 m          2
# 0.5-1.8 m      1
# 0.6-2.43 m     1
# 0.60-0.76 m    1
# 0.7-1.2 m      1
#               ..
# up to 60 cm    2
# up to 65 cm    1
# up to 70 cm    1
# up to 80 cm    1
# up to 99 cm    1
# Length: 2101, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Attributes  \
# missing_ratio  0.0
# num_values     3078
# value          Algivore,Detritivore,Herbivore,Fossorial,Polygynandry,Polygamy,Not a migrant,starts with    1
# Algivore,Detritivore,Herbivore,Polygynandry,Polygamy,Colonial,Not a migrant,starts with     1
# Algivore,Detritivore,Herbivore,Polygynandry,Polygamy,Solitary,Not a migrant,starts with     1
# Algivore,Herbivore,Planktivore,Not a migrant,starts with                                    2
# Algivore,Herbivore,Planktivore,Polygynandry,Polygamy,Solitary,Not a migrant,starts with     1
#                                                                                            ..
# Terrestrial,Viviparous,Arboreal,Altricial,starts with                                       1
# Terrestrial,Viviparous,starts with                                                          1
# Terrestrial,starts with                                                                     8099
# Zoochory,Terrestrial,Monogamy,Not a migrant,starts with                                     1
# starts with                                                                                 6503
# Length: 3078, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Distribution  \
# missing_ratio  0.0
# num_values     8335
# value          {'Geography': {'Biogeographical realms': 'Australasian'}, 'Biome': ['Forest', 'Intertidal zone', 'Rocky areas ', 'Shrubland', 'Coastal', 'Marine'], 'Climate': []}                                                                 1
# {'Geography': {'Biogeographical realms': 'Australasian, Afrotropical, Nearctic, Neotropical, Indomalayan, Palearctic'}, 'Biome': ['Agricultural', 'Anthropogenic biome'], 'Climate': ['Temperate', 'Cold', 'Tropical']}            1
# {'Geography': {'Biogeographical realms': 'Australasian, Afrotropical, Nearctic, Neotropical, Indomalayan, Palearctic'}, 'Biome': ['Agricultural', 'Anthropogenic biome'], 'Climate': ['Tropical', 'Arid', 'Temperate', 'Cold']}    1
# {'Geography': {'Biogeographical realms': 'Australasian, Nearctic, Neotropical, Palearctic'}, 'Biome': ['Agricultural', 'Anthropogenic biome', 'Mountains'], 'Climate': ['Arid', 'Temperate']}                                      1
# {'Geography': {'Biogeographical realms': 'Indomalayan'}, 'Biome': ['Agricultural', 'Anthropogenic biome', 'Forest', 'Grassland', 'Savanna'], 'Climate': ['Tropical']}                                                              1
#                                                                                                                                                                                                                                   ..
# {'Geography': {}, 'Biome': ['Shrubland', 'Wetlands '], 'Climate': []}                                                                                                                                                              1
# {'Geography': {}, 'Biome': ['Shrubland'], 'Climate': []}                                                                                                                                                                           3
# {'Geography': {}, 'Biome': ['Wetlands '], 'Climate': []}                                                                                                                                                                           2
# {'Geography': {}, 'Biome': [], 'Climate': ['Tropical']}                                                                                                                                                                            1
# {'Geography': {}, 'Biome': [], 'Climate': []}                                                                                                                                                                                      2226
# Length: 8335, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Habits  \
# missing_ratio  0.0
# num_values     2143
# value          {'Group name': '"bind", contradiction, fling, hill, "time-step"', 'Lifestyle': 'Terrestrial, Wading birds, Precocial, Territorial, Congregatory,', 'Seasonal behavior': 'Migrating', "Bird's call": 'Your browser does not support the audio element.'}    1
# {'Group name': '"little house", pack', 'Lifestyle': 'Terrestrial, Arboreal, Precocial, Zoochory,', 'Seasonal behavior': 'Not a migrant', "Bird's call": 'Your browser does not support the audio element.'}                                                1
# {'Group name': '"little house", pack', 'Lifestyle': 'Terrestrial, Precocial, Oviparous, Territorial', 'Seasonal behavior': 'Not a migrant', "Bird's call": 'Your browser does not support the audio element.'}                                             1
# {'Group name': 'a development', 'Lifestyle': 'Arboreal, Terrestrial, Altricial, Zoochory, Oviparous', 'Seasonal behavior': 'Partial Migrant', "Bird's call": 'Your browser does not support the audio element.'}                                           1
# {'Group name': 'a drift', 'Lifestyle': 'Terrestrial, Altricial, Territorial,', 'Seasonal behavior': 'Migrating', "Bird's call": 'Your browser does not support the audio element.'}                                                                        1
#                                                                                                                                                                                                                                                           ..
# {'Seasonal behavior': ''}                                                                                                                                                                                                                                  8
# {'Seasonal behavior': 'Migrating'}                                                                                                                                                                                                                         3
# {'Seasonal behavior': 'Not a migrant'}                                                                                                                                                                                                                     24
# {'Seasonal behavior': 'Partial Migrant'}                                                                                                                                                                                                                   1
# {}                                                                                                                                                                                                                                                         18208
# Length: 2143, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Diet  \
# missing_ratio  90.9
# num_values     308
# value          Algivore,,Detritivore,,Herbivore                       3
# Algivore,,Detritivore,,Herbivore,,Planktivore          1
# Algivore,,Folivore,,Granivore,,Herbivore,,Lignivore    1
# Algivore,,Granivore,,Herbivore                         1
# Algivore,,Herbivore                                    1
#                                                       ..
# Scavenger                                              3
# Scavenger,,Carnivore                                   2
# Scavenger,,Hypercarnivore                              1
# Scavenger,,Omnivore                                    1
# Vermivorous,,Carnivore                                 1
# Length: 308, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Mating_Habits  \
# ...
# {'Reproduction season': 'year-round; peaks: July-December, January-February', 'Pregnancy duration': '23-24 days', 'Baby carrying': '2-4 pups', 'Independent age': '3-4 weeks', 'Female name': 'doe', 'Male name': 'buck', 'Baby name': 'pup, pinkie, kit'}    1
# {'Reproduction season': 'year-round; usually early spring and autumn', 'Pregnancy duration': '23-30 days', 'Baby carrying': '7 pups', 'Independent age': '20-25 days', 'Female name': 'doe', 'Male name': 'buck', 'Baby name': 'pup, pinkie, kit'}            1
# {}                                                                                                                                                                                                                                                            25469
# Length: 2682, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Population
# missing_ratio  0.0
# num_values     40
# value          {'Population status': 'Critically endangered (CR)'}                                      54
# {'Population status': 'Data deficient (DD)'}                                             102
# {'Population status': 'Endangered (EN)'}                                                 60
# {'Population status': 'Extinct (EX)'}                                                    160
# {'Population status': 'Extinct in the wild (EW)'}                                        11
# {'Population status': 'Least concern (LC)'}                                              274
# {'Population status': 'Near Threatened (NT)'}                                            61
# {'Population status': 'Not evaluated (NE)'}                                              54
# {'Population status': 'Vulnerable (VU)'}                                                 73
# {'Population trend': 'Decreasing', 'Population status': 'Critically endangered (CR)'}    672
# {'Population trend': 'Decreasing', 'Population status': 'Data deficient (DD)'}           112
# {'Population trend': 'Decreasing', 'Population status': 'Endangered (EN)'}               1314
# {'Population trend': 'Decreasing', 'Population status': 'Extinct in the wild (EW)'}      1
# {'Population trend': 'Decreasing', 'Population status': 'Least concern (LC)'}            3741
# {'Population trend': 'Decreasing', 'Population status': 'Near Threatened (NT)'}          1172
# {'Population trend': 'Decreasing', 'Population status': 'Not evaluated (NE)'}            5
# {'Population trend': 'Decreasing', 'Population status': 'Vulnerable (VU)'}               1361
# {'Population trend': 'Decreasing'}                                                       3
# {'Population trend': 'Increasing', 'Population status': 'Critically endangered (CR)'}    23
# {'Population trend': 'Increasing', 'Population status': 'Data deficient (DD)'}           1
# {'Population trend': 'Increasing', 'Population status': 'Endangered (EN)'}               25
# {'Population trend': 'Increasing', 'Population status': 'Least concern (LC)'}            654
# {'Population trend': 'Increasing', 'Population status': 'Near Threatened (NT)'}          31
# {'Population trend': 'Increasing', 'Population status': 'Not evaluated (NE)'}            2
# {'Population trend': 'Increasing', 'Population status': 'Vulnerable (VU)'}               46
# {'Population trend': 'Stable', 'Population status': 'Critically endangered (CR)'}        33
# {'Population trend': 'Stable', 'Population status': 'Data deficient (DD)'}               24
# {'Population trend': 'Stable', 'Population status': 'Endangered (EN)'}                   58
# {'Population trend': 'Stable', 'Population status': 'Extinct (EX)'}                      1
# {'Population trend': 'Stable', 'Population status': 'Least concern (LC)'}                6867
# {'Population trend': 'Stable', 'Population status': 'Near Threatened (NT)'}              179
# {'Population trend': 'Stable', 'Population status': 'Vulnerable (VU)'}                   188
# {'Population trend': 'Unknown', 'Population status': 'Critically endangered (CR)'}       149
# {'Population trend': 'Unknown', 'Population status': 'Data deficient (DD)'}              1665
# {'Population trend': 'Unknown', 'Population status': 'Endangered (EN)'}                  223
# {'Population trend': 'Unknown', 'Population status': 'Least concern (LC)'}               3359
# {'Population trend': 'Unknown', 'Population status': 'Near Threatened (NT)'}             207
# {'Population trend': 'Unknown', 'Population status': 'Not evaluated (NE)'}               1
# {'Population trend': 'Unknown', 'Population status': 'Vulnerable (VU)'}                  209
# {}                                                                                       5350
# dtype: int64
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Xử lý tách các cột có kiểu dictionary thành nhiều cột

# %% [markdown]
# Đầu tiên các cột dictionary đều có kiểu là string nên ta phải xử lý chuyển các cột trên thành dict

# %%
for i in animal_df:
    if animal_df[i][0].find('{') != -1:
        animal_df[i] = animal_df[i].apply(eval)

# %% [markdown]
# Viết hàm "split_col" để split các cột có kiểu dữ liệu là dict thành nhiều cột

# %%
def split_col(df):
    element = []
    for i in df:
        if type(df[i][0]) == dict: 
            element.append(i)
    df_split_animals_info = pd.DataFrame()
    for i in df:
        if i not in element:
            df_split_animals_info[i] = df[i]
        else:
            temp3 = df[i][0].items()
            temp3 = np.array(list(temp3), dtype = object)
            df_temp2 = pd.DataFrame(columns = temp3[:, 0])
            for rows in df[i]:
                if type(rows) != float:
                    temp3 = rows.items()
                else:
                    temp3 = []
                temp3 = np.array(list(temp3), dtype = object)
                if len(temp3) > 1: 
                    df_temp = pd.DataFrame(index = temp3[:, 0], data = temp3[:, 1]).T
                else:
                    df_temp = pd.DataFrame(columns = df_temp2.columns, index = [0])
                df_temp2 = pd.concat([df_temp2, df_temp], ignore_index=True)
            df_split_animals_info = df_split_animals_info.join(df_temp2)
    return df_split_animals_info

# %%
df_split_animals_info = split_col(animal_df)
pd.set_option('display.max_columns', None)
df_split_animals_info
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0      Grey Wolf                    Animalia  Chordata  Vertebrata  Mammalia
# 1      Tiger                        Animalia  Chordata  Vertebrata  Mammalia
# 2      Brown Bear                   Animalia  Chordata  Vertebrata  Mammalia
# 3      Blue Whale                   Animalia  Chordata  Vertebrata  Mammalia
# 4      Killer Whale                 Animalia  Chordata  Vertebrata  Mammalia
# ...             ...                      ...       ...         ...       ...
# 29350  Córdoba cinclodes            Animalia  Chordata  NaN         Aves
# 29351  Western hemispingus          Animalia  Chordata  NaN         Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata  NaN         Aves
# 29355  McConnell's spinetail        Animalia  Chordata  NaN         Aves
# 29356  Junín canastero              Animalia  Chordata  NaN         Aves
#
#                Order    Suborder           Family         Genus  \
# 0      Carnivora      Caniformia  Canidae          Canis
# 1      Carnivora      Feliformia  Felidae          Panthera
# 2      Carnivora      Caniformia  Ursidae          Ursus
# 3      Artiodactyla   NaN         Balaenopteridae  Balaenoptera
# 4      Artiodactyla   NaN         Delphinidae      Orcinus
# ...             ...   ...                 ...          ...
# 29350  Passeriformes  NaN         Furnariidae      Cinclodes
# 29351  Passeriformes  NaN         Thraupidae       Sphenopsis
# 29352  Passeriformes  NaN         Furnariidae      Cranioleuca
# 29355  Passeriformes  NaN         Furnariidae      Synallaxis
# 29356  Passeriformes  NaN         Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0      Canis lupus                400,000         10-20 yrs   75 km/h
# 1      Panthera tigris            2,154-3,159     10-15 yrs   96 km/h
# 2      Ursus arctos               200,000         20-50 yrs   56 km/h
# 3      Balaenoptera musculus      10-25 Thou      80-90 yrs   20 km/h
# 4      Orcinus orca               50,000          30-100 yrs  45 km/h
# ...             ...                  ...                 ...      ...
# 29350  Cinclodes comechingonus    NaN             NaN         NaN
# 29351  Sphenopsis ochracea        NaN             NaN         NaN
# 29352  Limnoctites sulphuriferus  NaN             NaN         NaN
# 29355  Synallaxis macconnelli     NaN             NaN         NaN
# 29356  Asthenes virgata           NaN             NaN         NaN
#
#            Weight     Height      Length  \
# 0      16-60 kg    80-85 cm   105-160 cm
# 1      65-306 kg   NaN        200-390 cm
# 2      100-635 kg  70-153 cm  1.4-2.8 m
# 3      100-160 t   NaN        25-30 m
# 4      3-6 t       NaN        6-9 m
# ...      ...       ...          ...
# 29350  NaN         NaN        NaN
# 29351  NaN         NaN        NaN
# 29352  NaN         NaN        NaN
# 29355  NaN         NaN        NaN
# 29356  NaN         NaN        NaN
#
#                                                                                                                                                                                                                                                   Attributes  \
# 0      Nocturnal,Carnivore,Scavenger,Terrestrial,Cursorial,Altricial,Pack hunters,Apex predator,Pursuit predator,Nomadic,Territorial,Viviparous,Pack hunters,Ambush predator,Monogamy,Social,Dominance hierarchy,Not a migrant,starts with,Dangerous Animals
# 1      Nocturnal,Carnivore,Cursorial,Terrestrial,Ambush predator,Altricial,Nomadic,Territorial,Viviparous,Apex predator,Polygyny,Solitary,Dominance hierarchy,Not a migrant,starts with,Camouflaged Animals,Dangerous Animals,Giant Animals
# 2      Crepuscular,Omnivore,Terrestrial,Altricial,Nomadic,Territorial,Burrowing,Polygynandry,Serial monogamy,Dangerous,Solitary,Hibernating,Migrating,starts with,Lucky Animals,Canada Province Animals
# 3      Carnivore,Piscivores,Aquatic,Precocial,Natatorial,Viviparous,Cosmopolitan,Pursuit predator,Monogamy,Generally solitary,Migrating,starts with,Giant Animals
# 4      Diurnal,Carnivore,Aquatic,Precocial,Cosmopolitan,Natatorial,Territorial,Viviparous,Apex predator,Pursuit predator,Polygynandry,Highly social,Partial Migrant,starts with,Vicious Animals,Black And White Animals
# ...                                                                                                                                                                                                                 ...
# 29350  Terrestrial,Migrating,starts with
# 29351  Terrestrial,Not a migrant,starts with
# 29352  Terrestrial,Migrating,starts with
# 29355  Terrestrial,Not a migrant,starts with
# 29356  Terrestrial,Not a migrant,starts with
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Geography  \
# 0      {'Continents': 'Asia, Europe, North America, Africa', 'Subcontinents': 'South Asia, Western Asia, Southeast Asia, East Asia, Central Asia, North Africa', 'Countries': 'Albania, Armenia, Azerbaijan, Belarus, Bhutan, Bosnia and Herzegovina, Bulgaria, Canada, China, Croatia,', 'Regions': 'Czech Republic, Estonia, Finland, France, Georgia, Germany, Greece, Hungary, India, Iran,  Iraq, Israel, Italy, Jordan, Kazakhstan, North Korea, South Korea, Kyrgyzstan, Latvia, Libya, Lithuania, Macedonia, Mexico, Moldova, Mongolia, Montenegro, Myanmar, Nepal, Norway, Oman, Pakistan, Poland, Portugal, Romania, Russia, Saudi Arabia, Serbia, Slovakia, Slovenia, Spain, Sweden, Syria, Tajikistan, Turkey, Turkmenistan,  Ukraine, United Arab Emirates, United States, Uzbekistan, Yemen, Bangladesh, Afghanistan', 'Biogeographical realms': 'Greenland', 'Wwf biomes': 'Nearctic, Palearctic, Indomalayan, Afrotropical'}
# 1      {'Continents': 'Asia', 'Subcontinents': 'South Asia, Southeast Asia, East Asia', 'Countries': 'Bangladesh, Bhutan, China,   India, Indonesia, Laos, Malaysia, Myanmar, Nepal, Russia,', 'Regions': 'Thailand', 'Biogeographical realms': 'Tibet, Yunnan', 'Wwf biomes': 'Palearctic, Indomalayan'}
# 2      {'Continents': 'Asia, Europe, North America', 'Subcontinents': 'South Asia, Western Asia, East Asia, Central Asia, Southeast Asia', 'Countries': 'Albania, Armenia, Austria, Azerbaijan, Belarus, Bosnia and Herzegovina, Bulgaria, Canada, China, Croatia,', 'Biogeographical realms': 'Estonia, Finland, France, Georgia, Greece, India, Iran, Iraq, Italy, Japan, Kazakhstan, North Korea, Kyrgyzstan, Latvia, Macedonia, Mongolia, Montenegro,   Nepal, Norway, Pakistan, Poland, Romania, Russia, Serbia, Slovakia, Slovenia, Spain, Sweden, Tajikistan, Turkey, Ukraine, United States, Uzbekistan, Bhutan, Lebanon, Afghanistan', 'Wwf biomes': 'Nearctic, Palearctic, Indomalayan'}
# 3      {'Continents': 'Africa, South America, Oceania, North America, Asia, Europe, Antarctica', 'Subcontinents': 'Sub-Saharan Africa, Caribbean Islands, South Asia, East Asia, Central America, Southeast Asia, Western Asia, North Africa', 'Countries': 'Angola, Argentina, Australia, Bahamas, Bangladesh, Benin, Brazil, Cameroon, Canada, Cape Verde,', 'Regions': 'Chile, China, Colombia, Comoros, Costa Rica, Cote d'Ivoire, Djibouti, Ecuador, El Salvador, Equatorial Guinea, Eritrea, Faroe Islands, France, Gabon, Ghana, Greece, Grenada, Guatemala, Iceland, India, Indonesia, Iran, Iraq, Ireland, Japan, Kenya, Madagascar, Malaysia, Maldives, Marshall Islands, Mauritania, Mauritius, Mexico, Morocco, Mozambique, Myanmar, Namibia, New Zealand, Nicaragua, Nigeria, Norway, Oman, Pakistan, Palau, Panama, Peru, Philippines, Portugal, Russia, Sao Tomé and Principe, Senegal, Seychelles, Somalia, South Africa,  Spain, Sri Lanka, Taiwan, Tanzania, Thailand, Timor-Leste, Togo, United Kingdom, United States, Uruguay, Western Sahara', 'Oceans': 'Greenland, Kamchatka', 'Biogeographical realms': 'Atlantic Ocean, Pacific Ocean'}
# 4      {'Continents': 'Africa, Oceania, Antarctica, North America, South America, Asia, Europe', 'Subcontinents': 'North Africa, Caribbean Islands, South Asia, Central America, Sub-Saharan Africa, Southeast Asia, East Asia, Western Asia', 'Countries': 'Algeria, Antigua and Barbuda, Argentina, Australia, Bahamas, Bangladesh, Barbados, Belize, Benin, Brazil,', 'Regions': 'Brunei, Cambodia, Cameroon, Canada, Cape Verde, Chile, China, Colombia, Comoros, Congo, DR Congo, Costa Rica, Cote d'Ivoire, Cuba, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, El Salvador, Equatorial Guinea, Faroe Islands, Fiji,  France, Gabon, Gambia, Ghana, Grenada, Guadeloupe, Guatemala, Guinea, Guinea-Bissau, Guyana, Honduras, Iceland, India, Indonesia, Iran, Ireland, Israel, Italy, Jamaica, Japan, Kenya, Kiribati, Liberia, Madagascar, Malaysia, Maldives, Marshall Islands, Mauritania, Mexico, Federated States of Micronesia, Monaco, Morocco, Mozambique, Myanmar, Namibia,  Nauru, Netherlands, New Zealand, Nicaragua, Nigeria, Norway, Oman, Pakistan, Palau, Panama, Papua New Guinea, Peru, Philippines, Portugal, Russia, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines, Samoa, Senegal, Sierra Leone, Singapore, Solomon Islands, Somalia, South Africa, Spain, Sri Lanka, Suriname, Taiwan, Tanzania, Thailand, Timor-Leste, Togo, Tonga,  Trinidad and Tobago, Tunisia, United Arab Emirates, United Kingdom, United States, Uruguay, Vanuatu, Venezuela, Viet Nam, Western Sahara, Yemen, Germany', 'Oceans': 'Newfoundland, Hawaii, Greenland', 'Biogeographical realms': 'Arctic Ocean, Atlantic Ocean, Pacific Ocean'}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                                                                                        Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anthropogenic biome, Grassland, Rocky areas , Agricultural]
# 1      [Forest, Rainforest, Montane forest, Riparian, Shrubland, Grassland]
# 2      [Forest, Woodland]
# 3      [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, Estuaries]
# ...                                                        ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                   Climate                   Group name  \
# 0      [Temperate, Cold, Polar, Tropical]  pack, route, rout
# 1      [Tropical, Temperate]               NaN
# 2      [Temperate, Cold, Polar]            sloth, sleuth
# 3      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# 4      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# ...                                   ...                          ...
# 29350  NaN                                 NaN
# 29351  NaN                                 NaN
# 29352  NaN                                 NaN
# 29355  NaN                                 NaN
# 29356  NaN                                 NaN
#
#                                                                                                                                                Lifestyle  \
# 0      Terrestrial, Cursorial, Altricial, Pack hunters, Apex predator, Pursuit predator, Nomadic, Territorial, Viviparous, Pack hunters, Ambush predator
# 1      Cursorial, Terrestrial, Ambush predator, Altricial, Nomadic, Territorial, Viviparous, Apex predator
# 2      Terrestrial, Altricial, Nomadic, Territorial, Burrowing
# 3      Aquatic, Precocial, Natatorial, Viviparous, Cosmopolitan, Pursuit predator
# 4      Aquatic, Precocial, Cosmopolitan, Natatorial, Territorial, Viviparous, Apex predator, Pursuit predator
# ...                                                                                                       ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#             Seasonal behavior Predators Bird's call                   Diet  \
# 0      Not a migrant           NaN       NaN         Carnivore,,Scavenger
# 1      Not a migrant           NaN       NaN         Carnivore
# 2      Hibernating, Migrating  NaN       NaN         Omnivore
# 3      Migrating               NaN       NaN         Carnivore,,Piscivores
# 4      Partial Migrant         NaN       NaN         Carnivore
# ...                ...         ...       ...               ...
# 29350  NaN                     NaN       NaN         NaN
# 29351  NaN                     NaN       NaN         NaN
# 29352  NaN                     NaN       NaN         NaN
# 29355  NaN                     NaN       NaN         NaN
# 29356  NaN                     NaN       NaN         NaN
#
#       Mating behavior            Reproduction season Pregnancy duration  \
# 0      Monogamy        January-April                  60-63 days
# 1      Polygyny        November-April                 103 days
# 2      Polygynandry,   May-July                       8 weeks
# 3      Monogamy        winter or early spring         1 year
# 4      Polygynandry    year-round, usually in summer  15-18 months
# ...             ...                              ...           ...
# 29350  NaN             NaN                            NaN
# 29351  NaN             NaN                            NaN
# 29352  NaN             NaN                            NaN
# 29355  NaN             NaN                            NaN
# 29356  NaN             NaN                            NaN
#
#       Baby carrying Independent age Female name Male name   Baby name  \
# 0      1-14 pups     45 days         bitch       dog       pup, whelp
# 1      1-7 cubs      18 mos-3 yrs    NaN         NaN       cub
# 2      1-4 cubs      2-4 years       sow         boar      cub
# 3      1 calf        8 months        cow         bull      calf
# 4      1 calf        2 years         cow         bull      calf
# ...       ...            ...         ...          ...       ...
# 29350  NaN           NaN             NaN         NaN       NaN
# 29351  NaN           NaN             NaN         NaN       NaN
# 29352  NaN           NaN             NaN         NaN       NaN
# 29355  NaN           NaN             NaN         NaN       NaN
# 29356  NaN           NaN             NaN         NaN       NaN
#
#       Incubation period Population trend   Population status
# 0      NaN               Stable           Least concern (LC)
# 1      NaN               Decreasing       Endangered (EN)
# 2      NaN               Stable           Least concern (LC)
# 3      NaN               Increasing       Endangered (EN)
# 4      NaN               NaN              NaN
# ...    ...               ...              ...
# 29350  NaN               NaN              NaN
# 29351  NaN               NaN              NaN
# 29352  NaN               NaN              NaN
# 29355  NaN               NaN              NaN
# 29356  NaN               NaN              NaN
#
# [28525 rows x 37 columns]

# %% [markdown]
# Sau khi split dữ liệu có số dòng là 3237 và số cột là 37, tăng lên 15 cột
#
# Nhưng nhìn lại dữ liệu vẫn còn cột là dictionary như "Geograpy", như vậy ta phải split thêm 1 lần nữa

# %%
df_split_animals_info = split_col(df_split_animals_info)
df_split_animals_info
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0      Grey Wolf                    Animalia  Chordata  Vertebrata  Mammalia
# 1      Tiger                        Animalia  Chordata  Vertebrata  Mammalia
# 2      Brown Bear                   Animalia  Chordata  Vertebrata  Mammalia
# 3      Blue Whale                   Animalia  Chordata  Vertebrata  Mammalia
# 4      Killer Whale                 Animalia  Chordata  Vertebrata  Mammalia
# ...             ...                      ...       ...         ...       ...
# 29350  Córdoba cinclodes            Animalia  Chordata  NaN         Aves
# 29351  Western hemispingus          Animalia  Chordata  NaN         Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata  NaN         Aves
# 29355  McConnell's spinetail        Animalia  Chordata  NaN         Aves
# 29356  Junín canastero              Animalia  Chordata  NaN         Aves
#
#                Order    Suborder           Family         Genus  \
# 0      Carnivora      Caniformia  Canidae          Canis
# 1      Carnivora      Feliformia  Felidae          Panthera
# 2      Carnivora      Caniformia  Ursidae          Ursus
# 3      Artiodactyla   NaN         Balaenopteridae  Balaenoptera
# 4      Artiodactyla   NaN         Delphinidae      Orcinus
# ...             ...   ...                 ...          ...
# 29350  Passeriformes  NaN         Furnariidae      Cinclodes
# 29351  Passeriformes  NaN         Thraupidae       Sphenopsis
# 29352  Passeriformes  NaN         Furnariidae      Cranioleuca
# 29355  Passeriformes  NaN         Furnariidae      Synallaxis
# 29356  Passeriformes  NaN         Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0      Canis lupus                400,000         10-20 yrs   75 km/h
# 1      Panthera tigris            2,154-3,159     10-15 yrs   96 km/h
# 2      Ursus arctos               200,000         20-50 yrs   56 km/h
# 3      Balaenoptera musculus      10-25 Thou      80-90 yrs   20 km/h
# 4      Orcinus orca               50,000          30-100 yrs  45 km/h
# ...             ...                  ...                 ...      ...
# 29350  Cinclodes comechingonus    NaN             NaN         NaN
# 29351  Sphenopsis ochracea        NaN             NaN         NaN
# 29352  Limnoctites sulphuriferus  NaN             NaN         NaN
# 29355  Synallaxis macconnelli     NaN             NaN         NaN
# 29356  Asthenes virgata           NaN             NaN         NaN
#
#            Weight     Height      Length  \
# 0      16-60 kg    80-85 cm   105-160 cm
# 1      65-306 kg   NaN        200-390 cm
# 2      100-635 kg  70-153 cm  1.4-2.8 m
# 3      100-160 t   NaN        25-30 m
# 4      3-6 t       NaN        6-9 m
# ...      ...       ...          ...
# 29350  NaN         NaN        NaN
# 29351  NaN         NaN        NaN
# 29352  NaN         NaN        NaN
# 29355  NaN         NaN        NaN
# 29356  NaN         NaN        NaN
#
#                                                                                                                                                                                                                                                   Attributes  \
# 0      Nocturnal,Carnivore,Scavenger,Terrestrial,Cursorial,Altricial,Pack hunters,Apex predator,Pursuit predator,Nomadic,Territorial,Viviparous,Pack hunters,Ambush predator,Monogamy,Social,Dominance hierarchy,Not a migrant,starts with,Dangerous Animals
# 1      Nocturnal,Carnivore,Cursorial,Terrestrial,Ambush predator,Altricial,Nomadic,Territorial,Viviparous,Apex predator,Polygyny,Solitary,Dominance hierarchy,Not a migrant,starts with,Camouflaged Animals,Dangerous Animals,Giant Animals
# 2      Crepuscular,Omnivore,Terrestrial,Altricial,Nomadic,Territorial,Burrowing,Polygynandry,Serial monogamy,Dangerous,Solitary,Hibernating,Migrating,starts with,Lucky Animals,Canada Province Animals
# 3      Carnivore,Piscivores,Aquatic,Precocial,Natatorial,Viviparous,Cosmopolitan,Pursuit predator,Monogamy,Generally solitary,Migrating,starts with,Giant Animals
# 4      Diurnal,Carnivore,Aquatic,Precocial,Cosmopolitan,Natatorial,Territorial,Viviparous,Apex predator,Pursuit predator,Polygynandry,Highly social,Partial Migrant,starts with,Vicious Animals,Black And White Animals
# ...                                                                                                                                                                                                                 ...
# 29350  Terrestrial,Migrating,starts with
# 29351  Terrestrial,Not a migrant,starts with
# 29352  Terrestrial,Migrating,starts with
# 29355  Terrestrial,Not a migrant,starts with
# 29356  Terrestrial,Not a migrant,starts with
#
#                                                                     Continents  \
# 0      Asia, Europe, North America, Africa
# 1      Asia
# 2      Asia, Europe, North America
# 3      Africa, South America, Oceania, North America, Asia, Europe, Antarctica
# 4      Africa, Oceania, Antarctica, North America, South America, Asia, Europe
# ...                                                                        ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                                                                                                    Subcontinents  \
# 0      South Asia, Western Asia, Southeast Asia, East Asia, Central Asia, North Africa
# 1      South Asia, Southeast Asia, East Asia
# 2      South Asia, Western Asia, East Asia, Central Asia, Southeast Asia
# 3      Sub-Saharan Africa, Caribbean Islands, South Asia, East Asia, Central America, Southeast Asia, Western Asia, North Africa
# 4      North Africa, Caribbean Islands, South Asia, Central America, Sub-Saharan Africa, Southeast Asia, East Asia, Western Asia
# ...                                                                                                                          ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                                                                                        Countries  \
# 0      Albania, Armenia, Azerbaijan, Belarus, Bhutan, Bosnia and Herzegovina, Bulgaria, Canada, China, Croatia,
# 1      Bangladesh, Bhutan, China,   India, Indonesia, Laos, Malaysia, Myanmar, Nepal, Russia,
# 2      Albania, Armenia, Austria, Azerbaijan, Belarus, Bosnia and Herzegovina, Bulgaria, Canada, China, Croatia,
# 3      Angola, Argentina, Australia, Bahamas, Bangladesh, Benin, Brazil, Cameroon, Canada, Cape Verde,
# 4      Algeria, Antigua and Barbuda, Argentina, Australia, Bahamas, Bangladesh, Barbados, Belize, Benin, Brazil,
# ...                                                                                                          ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Regions  \
# 0      Czech Republic, Estonia, Finland, France, Georgia, Germany, Greece, Hungary, India, Iran,  Iraq, Israel, Italy, Jordan, Kazakhstan, North Korea, South Korea, Kyrgyzstan, Latvia, Libya, Lithuania, Macedonia, Mexico, Moldova, Mongolia, Montenegro, Myanmar, Nepal, Norway, Oman, Pakistan, Poland, Portugal, Romania, Russia, Saudi Arabia, Serbia, Slovakia, Slovenia, Spain, Sweden, Syria, Tajikistan, Turkey, Turkmenistan,  Ukraine, United Arab Emirates, United States, Uzbekistan, Yemen, Bangladesh, Afghanistan
# 1      Thailand
# 2      NaN
# 3      Chile, China, Colombia, Comoros, Costa Rica, Cote d'Ivoire, Djibouti, Ecuador, El Salvador, Equatorial Guinea, Eritrea, Faroe Islands, France, Gabon, Ghana, Greece, Grenada, Guatemala, Iceland, India, Indonesia, Iran, Iraq, Ireland, Japan, Kenya, Madagascar, Malaysia, Maldives, Marshall Islands, Mauritania, Mauritius, Mexico, Morocco, Mozambique, Myanmar, Namibia, New Zealand, Nicaragua, Nigeria, Norway, Oman, Pakistan, Palau, Panama, Peru, Philippines, Portugal, Russia, Sao Tomé and Principe, Senegal, Seychelles, Somalia, South Africa,  Spain, Sri Lanka, Taiwan, Tanzania, Thailand, Timor-Leste, Togo, United Kingdom, United States, Uruguay, Western Sahara
# 4      Brunei, Cambodia, Cameroon, Canada, Cape Verde, Chile, China, Colombia, Comoros, Congo, DR Congo, Costa Rica, Cote d'Ivoire, Cuba, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, El Salvador, Equatorial Guinea, Faroe Islands, Fiji,  France, Gabon, Gambia, Ghana, Grenada, Guadeloupe, Guatemala, Guinea, Guinea-Bissau, Guyana, Honduras, Iceland, India, Indonesia, Iran, Ireland, Israel, Italy, Jamaica, Japan, Kenya, Kiribati, Liberia, Madagascar, Malaysia, Maldives, Marshall Islands, Mauritania, Mexico, Federated States of Micronesia, Monaco, Morocco, Mozambique, Myanmar, Namibia,  Nauru, Netherlands, New Zealand, Nicaragua, Nigeria, Norway, Oman, Pakistan, Palau, Panama, Papua New Guinea, Peru, Philippines, Portugal, Russia, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines, Samoa, Senegal, Sierra Leone, Singapore, Solomon Islands, Somalia, South Africa, Spain, Sri Lanka, Suriname, Taiwan, Tanzania, Thailand, Timor-Leste, Togo, Tonga,  Trinidad and Tobago, Tunisia, United Arab Emirates, United Kingdom, United States, Uruguay, Vanuatu, Venezuela, Viet Nam, Western Sahara, Yemen, Germany
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                                                                                                                                                                                                                                                                                                               Biogeographical realms  \
# 0      Greenland
# 1      Tibet, Yunnan
# 2      Estonia, Finland, France, Georgia, Greece, India, Iran, Iraq, Italy, Japan, Kazakhstan, North Korea, Kyrgyzstan, Latvia, Macedonia, Mongolia, Montenegro,   Nepal, Norway, Pakistan, Poland, Romania, Russia, Serbia, Slovakia, Slovenia, Spain, Sweden, Tajikistan, Turkey, Ukraine, United States, Uzbekistan, Bhutan, Lebanon, Afghanistan
# 3      Atlantic Ocean, Pacific Ocean
# 4      Arctic Ocean, Atlantic Ocean, Pacific Ocean
# ...                                            ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                             Wwf biomes  \
# 0      Nearctic, Palearctic, Indomalayan, Afrotropical
# 1      Palearctic, Indomalayan
# 2      Nearctic, Palearctic, Indomalayan
# 3      NaN
# 4      NaN
# ...    ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                 Oceans Introduced countries Islands Seas  \
# 0      NaN                              NaN                  NaN     NaN
# 1      NaN                              NaN                  NaN     NaN
# 2      NaN                              NaN                  NaN     NaN
# 3      Greenland, Kamchatka             NaN                  NaN     NaN
# 4      Newfoundland, Hawaii, Greenland  NaN                  NaN     NaN
# ...                                ...  ...                  ...     ...
# 29350  NaN                              NaN                  NaN     NaN
# 29351  NaN                              NaN                  NaN     NaN
# 29352  NaN                              NaN                  NaN     NaN
# 29355  NaN                              NaN                  NaN     NaN
# 29356  NaN                              NaN                  NaN     NaN
#
#                                                                                                        Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anthropogenic biome, Grassland, Rocky areas , Agricultural]
# 1      [Forest, Rainforest, Montane forest, Riparian, Shrubland, Grassland]
# 2      [Forest, Woodland]
# 3      [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, Estuaries]
# ...                                                        ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#                                   Climate                   Group name  \
# 0      [Temperate, Cold, Polar, Tropical]  pack, route, rout
# 1      [Tropical, Temperate]               NaN
# 2      [Temperate, Cold, Polar]            sloth, sleuth
# 3      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# 4      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# ...                                   ...                          ...
# 29350  NaN                                 NaN
# 29351  NaN                                 NaN
# 29352  NaN                                 NaN
# 29355  NaN                                 NaN
# 29356  NaN                                 NaN
#
#                                                                                                                                                Lifestyle  \
# 0      Terrestrial, Cursorial, Altricial, Pack hunters, Apex predator, Pursuit predator, Nomadic, Territorial, Viviparous, Pack hunters, Ambush predator
# 1      Cursorial, Terrestrial, Ambush predator, Altricial, Nomadic, Territorial, Viviparous, Apex predator
# 2      Terrestrial, Altricial, Nomadic, Territorial, Burrowing
# 3      Aquatic, Precocial, Natatorial, Viviparous, Cosmopolitan, Pursuit predator
# 4      Aquatic, Precocial, Cosmopolitan, Natatorial, Territorial, Viviparous, Apex predator, Pursuit predator
# ...                                                                                                       ...
# 29350  NaN
# 29351  NaN
# 29352  NaN
# 29355  NaN
# 29356  NaN
#
#             Seasonal behavior Predators Bird's call                   Diet  \
# 0      Not a migrant           NaN       NaN         Carnivore,,Scavenger
# 1      Not a migrant           NaN       NaN         Carnivore
# 2      Hibernating, Migrating  NaN       NaN         Omnivore
# 3      Migrating               NaN       NaN         Carnivore,,Piscivores
# 4      Partial Migrant         NaN       NaN         Carnivore
# ...                ...         ...       ...               ...
# 29350  NaN                     NaN       NaN         NaN
# 29351  NaN                     NaN       NaN         NaN
# 29352  NaN                     NaN       NaN         NaN
# 29355  NaN                     NaN       NaN         NaN
# 29356  NaN                     NaN       NaN         NaN
#
#       Mating behavior            Reproduction season Pregnancy duration  \
# 0      Monogamy        January-April                  60-63 days
# 1      Polygyny        November-April                 103 days
# 2      Polygynandry,   May-July                       8 weeks
# 3      Monogamy        winter or early spring         1 year
# 4      Polygynandry    year-round, usually in summer  15-18 months
# ...             ...                              ...           ...
# 29350  NaN             NaN                            NaN
# 29351  NaN             NaN                            NaN
# 29352  NaN             NaN                            NaN
# 29355  NaN             NaN                            NaN
# 29356  NaN             NaN                            NaN
#
#       Baby carrying Independent age Female name Male name   Baby name  \
# 0      1-14 pups     45 days         bitch       dog       pup, whelp
# 1      1-7 cubs      18 mos-3 yrs    NaN         NaN       cub
# 2      1-4 cubs      2-4 years       sow         boar      cub
# 3      1 calf        8 months        cow         bull      calf
# 4      1 calf        2 years         cow         bull      calf
# ...       ...            ...         ...          ...       ...
# 29350  NaN           NaN             NaN         NaN       NaN
# 29351  NaN           NaN             NaN         NaN       NaN
# 29352  NaN           NaN             NaN         NaN       NaN
# 29355  NaN           NaN             NaN         NaN       NaN
# 29356  NaN           NaN             NaN         NaN       NaN
#
#       Incubation period Population trend   Population status
# 0      NaN               Stable           Least concern (LC)
# 1      NaN               Decreasing       Endangered (EN)
# 2      NaN               Stable           Least concern (LC)
# 3      NaN               Increasing       Endangered (EN)
# 4      NaN               NaN              NaN
# ...    ...               ...              ...
# 29350  NaN               NaN              NaN
# 29351  NaN               NaN              NaN
# 29352  NaN               NaN              NaN
# 29355  NaN               NaN              NaN
# 29356  NaN               NaN              NaN
#
# [28525 rows x 46 columns]

# %% [markdown]
# Sau khi split dữ liệu tăng thêm 9 cột
#
# Lúc này ta tính lại missing_ratio xem các cột sau khi split như thế nào nhé

# %%
cat_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in df_split_animals_info.columns:
    if df_split_animals_info[i].dtype not in [float, int]:
        cat_col_info_df[i] = col_info(i, df_split_animals_info)

cat_col_info_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                           Name  \
# missing_ratio  0.0
# num_values     28525
# value          ? Nycticebus linglom      1
# AEECL's sportive lemur    1
# Aaadonta angaurana        1
# Aaadonta constricta       1
# Aaadonta fuscozonata      1
#                          ..
# ʻAkohekohe                1
# ʻAnianiau                 1
# ʻApapane                  1
# ʻEua rail                 1
# ʻIʻiwi                    1
# Length: 28525, dtype: int64
#
#                                       Kingdom  \
# missing_ratio  0.0
# num_values     1
# value          Animalia    28525
# dtype: int64
#
#                                                          Phylum  \
# missing_ratio  0.0
# num_values     2
# value          Chordata    23659
# Mollusca    4866
# dtype: int64
#
#                                       Subphylum  \
# missing_ratio  64.4
# num_values     1
# value          Vertebrata    10152
# dtype: int64
#
#                                                                                                                                                                                                                                                                       Class  \
# missing_ratio  0.0
# num_values     10
# value          Amphibia          3393
# Aves              10114
# Bivalvia          515
# Cephalopoda       336
# Gastropoda        3991
# Mammalia          5879
# Polyplacophora    10
# Reptilia          4273
# Scaphopoda        13
# Solenogastres     1
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                 Order  \
# missing_ratio  1.5
# num_values     118
# value          Accipitriformes    255
# Adapedonta         10
# Aegotheliformes    11
# Afrosoricida       56
# Anomalodesmata     18
#                    ..
# Trogoniformes      41
# Tubulidentata      2
# Unionoida          217
# Vampyromorphida    1
# Venerida           89
# Length: 118, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                            Suborder  \
# missing_ratio  91.0
# num_values     13
# value          Alcedini           109
# Caniformia         192
# Cryptodira         212
# Feliformia         100
# Haplorhini         271
# Iguania            324
# Lari               1
# Macropodiformes    2
# Phalangerida       2
# Pleurodira         43
# Ruminantia         54
# Serpentes          1132
# Strepsirrhini      122
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                                      Family  \
# missing_ratio  0.0
# num_values     840
# value          Abrocomidae          10
# Abronicidae          2
# Acanthisittidae      2
# Acanthizidae         59
# Acanthochitonidae    3
#                     ..
# Zebinidae            7
# Zeledoniidae         1
# Ziphiidae            21
# Zonitidae            1
# Zosteropidae         124
# Length: 840, dtype: int64
#
#                                                                                                                                                                                                                                           Genus  \
# missing_ratio  0.0
# num_values     6127
# value          Aaadonta        6
# Abditomys       1
# Abeillia        1
# Abeomelomys     1
# Ablepharus      9
#                ..
# Zosterornis     5
# Zygaspis        8
# Zygodontomys    2
# Zygogeomys      1
# Zyzomys         5
# Length: 6127, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                           Species  \
# missing_ratio  0.0
# num_values     28523
# value          "Calamita" melanorabdotus          1
# "Calamita" quadrilineatus          1
# "Centrolene" acanthidiocephalum    1
# "Centrolene" azulae                1
# "Centrolene" guanacarum            1
#                                   ..
# Zyzomys argurus                    1
# Zyzomys maini                      1
# Zyzomys palatalis                  1
# Zyzomys pedunculatus               1
# Zyzomys woodwardi                  1
# Length: 28523, dtype: int64
#
#                                                                                                                                                                                                                                Population size  \
# missing_ratio  93.7
# num_values     638
# value          0.45-1 M        1
# 1 Mln           2
# 1,000           5
# 1,000,000       1
# 1,000-10,000    4
#                ..
# over 225,000    1
# over 340,000    1
# over 4 mln      1
# over 400,000    1
# over 975        1
# Length: 638, dtype: int64
#
#                                                                                                                                                                                                                                      Life span  \
# missing_ratio  93.6
# num_values     581
# value          1 yr            2
# 1-10 yrs        2
# 1-12.5 yrs      1
# 1-13 yrs        1
# 1-19 yrs        1
#                ..
# up to 25 yrs    1
# up to 29 yrs    1
# up to 30 yrs    3
# up to 5 yrs     1
# up to 8 yrs     1
# Length: 581, dtype: int64
#
#                                                                                                                                                                                                     Top speed  \
# missing_ratio  98.0
# num_values     124
# value          0.24 km/h    1
# 0.26 km/h    1
# 0.27 km/h    1
# 0.5 km/h     4
# 10 km/h      5
#             ..
# 93 km/h      1
# 95 km/h      2
# 96 km/h      4
# 96.6 km/h    2
# 98 km/h      1
# Length: 124, dtype: int64
#
#                                                                                                                                                                                                                                                                Weight  \
# missing_ratio  90.0
# num_values     2232
# value          0-0 kg            3
# 0.010-0.796 g     1
# 0.02-22.5 kg      2
# 0.030-0.067 kg    1
# 0.056-1.65 kg     1
#                  ..
# up to 50 g        1
# up to 50 kg       1
# up to 6 kg        1
# up to 7kg         1
# up to 9 kg        1
# Length: 2232, dtype: int64
#
#                                                                                                                                                                                                                              Height  \
# missing_ratio  98.9
# num_values     245
# value          0.5 m          1
# 0.7-1.3 m      1
# 0.75-1 m       2
# 0.8-1.5 m      1
# 0.9 m          1
#               ..
# 95-130 cm      1
# 97-140 cm      1
# 99-125 cm      1
# over 1 m       1
# up to 80 cm    1
# Length: 245, dtype: int64
#
#                                                                                                                                                                                                                               Length  \
# missing_ratio  89.7
# num_values     2101
# value          0.5 m          2
# 0.5-1.8 m      1
# 0.6-2.43 m     1
# 0.60-0.76 m    1
# 0.7-1.2 m      1
#               ..
# up to 60 cm    2
# up to 65 cm    1
# up to 70 cm    1
# up to 80 cm    1
# up to 99 cm    1
# Length: 2101, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Attributes  \
# missing_ratio  0.0
# num_values     3078
# value          Algivore,Detritivore,Herbivore,Fossorial,Polygynandry,Polygamy,Not a migrant,starts with    1
# Algivore,Detritivore,Herbivore,Polygynandry,Polygamy,Colonial,Not a migrant,starts with     1
# Algivore,Detritivore,Herbivore,Polygynandry,Polygamy,Solitary,Not a migrant,starts with     1
# Algivore,Herbivore,Planktivore,Not a migrant,starts with                                    2
# Algivore,Herbivore,Planktivore,Polygynandry,Polygamy,Solitary,Not a migrant,starts with     1
#                                                                                            ..
# Terrestrial,Viviparous,Arboreal,Altricial,starts with                                       1
# Terrestrial,Viviparous,starts with                                                          1
# Terrestrial,starts with                                                                     8099
# Zoochory,Terrestrial,Monogamy,Not a migrant,starts with                                     1
# starts with                                                                                 6503
# Length: 3078, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Continents  \
# missing_ratio  70.6
# num_values     252
# value          Africa                                                                                                1135
# Africa  Benin, Burkina Faso, Cameroon, Gambia, Ghana, Guinea, Guinea-Bissau, Mali, Niger, Nigeria,    1
# Africa  DR Congo                                                                                      1
# Africa  DR Congo, South Sudan, Sudan, Uganda                                                          1
# Africa  Madagascar                                                                                    1
#                                                                                                      ..
# South America, North America, Asia                                                                    1
# South America, North America, Asia, Africa                                                            1
# South America, Oceania, Africa                                                                        1
# South America, Oceania, Antarctica                                                                    1
# South America, Oceania, Antarctica, Africa                                                            1
# Length: 252, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Subcontinents  \
# missing_ratio  96.5
# num_values     224
# value          Angola, Botswana, Burundi, DR Congo, Kenya, Malawi, Mozambique, Namibia, Rwanda, South Africa,                    1
# Argentina, Belize, Bolivia, Brazil, Colombia, Costa Rica, Ecuador, El Salvador, Guatemala, Guyana,                1
# Bangladesh, Brunei, Cambodia, China, India, Indonesia, Laos, Malaysia, Maldives, Myanmar,                         1
# Bangladesh, Myanmar, Cambodia, China, Hong Kong, India, Bhutan, Indonesia, Laos, Malaysia,                        1
# Bhutan, China, India, Myanmar                                                                                     1
#                                                                                                                  ..
# Western Asia, South Asia                                                                                          3
# Western Asia, South Asia, Central Asia                                                                            3
# Western Asia, South Asia, Southeast Asia                                                                          1
# Western Asia, South Asia, Southeast Asia, North Africa, Sub-Saharan Africa, Central America, Caribbean Islands    1
# Western Asia, Sub-Saharan Africa                                                                                  1
# Length: 224, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Countries  \
# missing_ratio  68.9
# num_values     3106
# value                                                                                                                               36
# Afghanistan, Albania, Algeria,  Andorra, Armenia, Austria, Azerbaijan, Bangladesh, Belarus, Belgium,                 1
# Afghanistan, Albania, Algeria, Andorra, Armenia, Austria, Azerbaijan, Bangladesh, Bhutan, Bosnia and Herzegovina,    1
# Afghanistan, Albania, Algeria, Andorra, Armenia, Austria, Azerbaijan, Belarus, Belgium, Bhutan,                      1
# Afghanistan, Albania, Algeria, Armenia, Austria, Azerbaijan, Belarus, Belgium, Bosnia and Herzegovina, Bulgaria,     1
#                                                                                                                     ..
# Yemen, Iran, Iraq, Israel, Jordan, Kuwait, Oman, Qatar, Saudi Arabia, United Arab Emirates                           1
# Yemen, Oman                                                                                                          2
# Yemen, Oman, United Arab Emirates                                                                                    1
# Yemen, Saudi Arabia                                                                                                  1
# Zambia                                                                                                               5
# Length: 3106, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Regions  \
# missing_ratio  92.9
# num_values     934
# value                                                                                                                                  22
# ,                                                                                                                       1
# Afghanistan,  Pakistan                                                                                                  1
# Afrotropical                                                                                                            4
# Alabama                                                                                                                 2
#                                                                                                                        ..
# Yukon, Newfoundland, Alberta, Québec, British Columbia, New Brunswick, Nova Scotia, Saskatchewan, Ontario, Labrador,    1
# Yukon, Northwest Territories, British Columbia, Alberta, Washington, Montana, Idaho, Alaska                             1
# Yunnan                                                                                                                  27
# Zambia, Zimbabwe                                                                                                        4
# Zimbabwe                                                                                                                1
# Length: 934, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Biogeographical realms  \
# missing_ratio  69.8
# ...
# value          26-35 days                                                    1
# April                                                         3
# April or May; August-December                                 1
# April to late July/early August                               1
# April, June                                                   2
#                                                              ..
# year-round; peak in October-February                          1
# year-round; peak in autumn and winter                         1
# year-round; peaks: July-December, January-February            1
# year-round; usually early spring and autumn                   1
# year-round; usually in late spring-early fall in the North    1
# Length: 612, dtype: int64
#
#                                                                                                                                                                                                                                                                         Pregnancy duration  \
# missing_ratio  95.4
# num_values     680
# value          0 to 0.01 months    1
# 1                   3
# 1 month             5
# 1 months            2
# 1 to 1              1
#                    ..
# 95-174 days         1
# 98 days             1
# About 53 day        1
# over 6 mos          1
# unknown minutes     1
# Length: 680, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                Baby carrying  \
# missing_ratio  92.2
# num_values     652
# value          0 to 1                  2
# 0 to 2                  1
# 1                       124
# 1 baby                  5
# 1 calf                  122
#                        ...
# 9-50 young              1
# 94 to 800               1
# Hundreds to Millions    1
# several dozen           1
# twins                   1
# Length: 652, dtype: int64
#
#                                                                                                                                                                                                                                                                                                             Independent age  \
# missing_ratio  94.2
# num_values     560
# value          &gt;2 weeks          1
# 0 days               6
# 0 minutes            19
# 0 to 0 days          1
# 0 to 0 minutes       5
#                     ..
# at birth             172
# immediate            1
# immediate minutes    3
# several hours        1
# several weeks        1
# Length: 560, dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Female name  \
# missing_ratio  96.6
# num_values     33
# value          angeline            1
# bitch               7
# bitch, doe, jill    5
# cow                 144
# cowb                1
# dae, hind           1
# doe                 139
# doe, hind           16
# doe, hind, cow      3
# doe, jill           1
# doe, nanny          11
# duck                27
# ewe, dam            6
# falcon              7
# female              336
# female, zed         3
# goose               11
# hembra              1
# hen                 117
# jenny, jennet       3
# jill                10
# jill, roo           21
# leopardess          4
# lioness             1
# mare                3
# mare, dam           1
# nanny               2
# peahen              2
# pen                 6
# queen               18
# sow                 62
# velvet, sow         2
# vixen               11
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Male name  \
# missing_ratio  96.6
# num_values     38
# value          billy               2
# boar                61
# boar, bull          2
# buck                129
# buck, billy         11
# buck, jack          1
# buck, ram           6
# buck, stag          25
# buck, stag, bull    3
# bull                146
# cob                 6
# cock                102
# dog                 6
# dog, buck, jack     5
# dog, hob, jack      1
# dog, sire           1
# drake               27
# gander              11
# gemsbok             2
# hob                 5
# jack                4
# jack, boomer        21
# jack, jackass       3
# leopard             4
# lion                1
# macho               1
# male                337
# male, lister        3
# peacock             2
# reynard, dog        1
# reynard, tod        10
# stag                1
# stallion            3
# stallion, stud      1
# tiercel             19
# tom                 2
# tomcat              18
# wolverine           1
# dtype: int64
#
#                                                                                                                                                                                                                                                                                 Baby name  \
# missing_ratio  94.2
# num_values     80
# value          Fawn, twins         1
# Hatchling           1
# Infant              5
# Joey                2
# Kitten              2
#                    ..
# squab               4
# squab, chick        8
# squab, squeaker     1
# whelp, pup          7
# young, hatchling    1
# Length: 80, dtype: int64
#
#                                                                                                                                                                                                                              Incubation period  \
# missing_ratio  97.4
# num_values     339
# value          1 month        12
# 1-3 months     1
# 1.5 months     1
# 10 days        1
# 10 weeks       2
#               ..
# 90-100 days    4
# 90-125 days    1
# 90-130 days    1
# 90-135 days    1
# 90-240         1
# Length: 339, dtype: int64
#
#                                                                                        Population trend  \
# missing_ratio  24.2
# num_values     4
# value          Decreasing    8097
# Increasing    755
# Stable        7115
# Unknown       5669
# dtype: int64
#
#                                                                                                                                                                                                                                                                                                                                               Population status
# missing_ratio  24.2
# num_values     9
# value          Critically endangered (CR)    847
# Data deficient (DD)           1769
# Endangered (EN)               1546
# Extinct (EX)                  1
# Extinct in the wild (EW)      1
# Least concern (LC)            14194
# Near Threatened (NT)          1548
# Not evaluated (NE)            6
# Vulnerable (VU)               1724
# dtype: int64

# %% [markdown]
# ## Tiếp tục tiền xử lý dữ liệu nhé

# %% [markdown]
# ### Loại bỏ một số cột không cần thiết
#
# Sau khi tách các cột thành dictionary, đã xuất hiện một số cột không cần thiết mà tỷ lệ miss lại khá cao, ta cần vứt bỏ những cột này cho dễ xử lý về sau.

# %%
cols = ['Oceans', 'Introduced countries', 'Seas', 'Islands', 'Predators', "Bird's call"]
for col in cols:
    df_split_animals_info  = df_split_animals_info.drop(columns  = col)
df_split_animals_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2215/1208587496.py in <cell line: 2>()
#       1 cols = ['Oceans', 'Introduced countries', 'Seas', 'Islands', 'Predators', "Bird's call"]
#       2 for col in cols:
# ----> 3     df_split_animals_info  = df_split_animals_info.drop(columns  = col)
#       4 df_split_animals_info
#
# NameError: name 'df_split_animals_info' is not defined

# %% [markdown]
# Tại đây ta sẽ tách các cột có thuộc tính cách nhau bằng dấu phẩy thành 1 list
#
# Luu vào "element" là tên các cột có các thuộc tính phân tách bằng dấu phẩy
#
# Các cột sau khi xử lý sẽ được lưu vào biến "splits"

# %%
element = np.array(['Attributes', 'Continents', 'Subcontinents', 'Countries', 'Regions', 'Wwf biomes', 'Group name', 'Diet', 'Biogeographical realms', 'Lifestyle', 'Oceans', 'Seasonal behavior'])

splits = [df_split_animals_info[col].str.split(pat = ',| and |  ', expand = False) for col in element]
splits = pd.DataFrame(splits).T
# print(splits.shape)
# print(splits.head())

# %% [markdown]
# Sau khi tách xong ta tiến hành ghép 2 dataframe lại thành "data_df"

# %%
df_split_animals_info.drop(element, axis=1, inplace=True)
data_df = pd.concat([df_split_animals_info, splits], axis = 1)
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df
# df_split_animals_info
# Out:
#                           Name   Kingdom    Phylum   Subphylum     Class  \
# 0                    Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                        Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                   Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                   Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                 Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                        ...       ...       ...         ...       ...
# 3232     Yellow-billed cacique  Animalia  Chordata         NaN      Aves
# 3233        Saint Lucia oriole  Animalia  Chordata         NaN      Aves
# 3234        Swynnerton's robin  Animalia  Chordata         NaN      Aves
# 3235  Ochre-bellied flycatcher  Animalia  Chordata         NaN      Aves
# 3236  Magellanic diving petrel  Animalia  Chordata         NaN      Aves
#
#                   Order    Suborder           Family         Genus  \
# 0             Carnivora  Caniformia          Canidae         Canis
# 1             Carnivora  Feliformia          Felidae      Panthera
# 2             Carnivora  Caniformia          Ursidae         Ursus
# 3          Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4          Artiodactyla         NaN      Delphinidae       Orcinus
# ...                 ...         ...              ...           ...
# 3232      Passeriformes         NaN        Icteridae   Amblycercus
# 3233      Passeriformes         NaN        Icteridae       Icterus
# 3234      Passeriformes         NaN     Muscicapidae  Swynnertonia
# 3235      Passeriformes         NaN       Tyrannidae     Mionectes
# 3236  Procellariiformes         NaN   Procellariidae  Pelecanoides
#
#                        Species Population size   Life span Top speed  \
# 0                  Canis lupus         400,000   10-20 yrs   75 km/h
# 1              Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                 Ursus arctos         200,000   20-50 yrs   56 km/h
# 3        Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                 Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                        ...             ...         ...       ...
# 3232  Amblycercus holosericeus             NaN         NaN       NaN
# 3233        Icterus laudabilis             NaN         NaN       NaN
# 3234  Swynnertonia swynnertoni             NaN         NaN       NaN
# 3235      Mionectes oleagineus             NaN         NaN       NaN
# 3236    Pelecanoides magellani             NaN         NaN       NaN
#
#            Weight     Height        Length Introduced countries Seas Islands  \
# 0        16-60 kg   80-85 cm    105-160 cm                  NaN  NaN     NaN
# 1       65-306 kg        NaN    200-390 cm                  NaN  NaN     NaN
# 2      100-635 kg  70-153 cm     1.4-2.8 m                  NaN  NaN     NaN
# 3       100-160 t        NaN       25-30 m                  NaN  NaN     NaN
# 4           3-6 t        NaN         6-9 m                  NaN  NaN     NaN
# ...           ...        ...           ...                  ...  ...     ...
# 3232  56.7-70.9 g        NaN  21.6-25.4 cm                  NaN  NaN     NaN
# 3233       36.9 g        NaN      20-22 cm                  NaN  NaN     NaN
# 3234          NaN        NaN      12-13 cm                  NaN  NaN     NaN
# 3235         13 g        NaN           NaN                  NaN  NaN     NaN
# 3236    145-174 g        NaN         19 cm                  NaN  NaN     NaN
#
#                                                   Biome  \
# 0     [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1     [Forest, Rainforest, Montane forest, Riparian,...
# 2                                    [Forest, Woodland]
# 3          [Oceanic pelagic zone, Marine, Neritic zone]
# 4     [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                 ...
# 3232                                           [Forest]
# 3233  [Agricultural, Anthropogenic biome, Forest, Mo...
# 3234                                [Forest, Mountains]
# 3235  [Forest, Rainforest, Grassland, Freshwater, An...
# 3236  [Coastal, Neritic zone, Oceanic pelagic zone, ...
#
#                                  Climate       Seasonal behavior Predators  \
# 0     [Temperate, Cold, Polar, Tropical]           Not a migrant       NaN
# 1                  [Tropical, Temperate]           Not a migrant       NaN
# 2               [Temperate, Cold, Polar]  Hibernating, Migrating       NaN
# 3     [Tropical, Temperate, Cold, Polar]               Migrating       NaN
# 4     [Tropical, Temperate, Cold, Polar]         Partial Migrant       NaN
# ...                                  ...                     ...       ...
# 3232                          [Tropical]                     NaN       NaN
# 3233                          [Tropical]           Not a migrant       NaN
# 3234                          [Tropical]                     NaN       NaN
# 3235                                  []           Not a migrant       NaN
# 3236                         [Temperate]                     NaN       NaN
#
#                                            Bird's call Mating behavior  \
# 0                                                  NaN        Monogamy
# 1                                                  NaN        Polygyny
# 2                                                  NaN   Polygynandry,
# 3                                                  NaN        Monogamy
# 4                                                  NaN    Polygynandry
# ...                                                ...             ...
# 3232                                               NaN             NaN
# 3233                                                               NaN
# 3234                                               NaN             NaN
# 3235  Your browser does not support the audio element.             NaN
# 3236                                               NaN             NaN
#
#                 Reproduction season Pregnancy duration Baby carrying  \
# 0                     January-April         60-63 days     1-14 pups
# 1                    November-April           103 days      1-7 cubs
# 2                          May-July            8 weeks      1-4 cubs
# 3            winter or early spring             1 year        1 calf
# 4     year-round, usually in summer       15-18 months        1 calf
# ...                             ...                ...           ...
# 3232                            NaN                NaN           NaN
# 3233                            NaN                NaN           NaN
# 3234                            NaN                NaN           NaN
# 3235                            NaN                NaN           NaN
# 3236                            NaN                NaN           NaN
#
#      Independent age Female name Male name   Baby name Incubation period  \
# 0            45 days       bitch       dog  pup, whelp               NaN
# 1       18 mos-3 yrs         NaN       NaN         cub               NaN
# 2          2-4 years         sow      boar         cub               NaN
# 3           8 months         cow      bull        calf               NaN
# 4            2 years         cow      bull        calf               NaN
# ...              ...         ...       ...         ...               ...
# 3232             NaN         NaN       NaN         NaN               NaN
# 3233             NaN         NaN       NaN         NaN               NaN
# 3234             NaN         NaN       NaN         NaN               NaN
# 3235             NaN         NaN       NaN         NaN               NaN
# 3236             NaN         NaN       NaN         NaN               NaN
#
#      Population trend   Population status  \
# 0              Stable  Least concern (LC)
# 1          Decreasing     Endangered (EN)
# 2              Stable  Least concern (LC)
# 3          Increasing     Endangered (EN)
# 4                 NaN                 NaN
# ...               ...                 ...
# 3232       Decreasing  Least concern (LC)
# 3233       Decreasing     Endangered (EN)
# 3234       Decreasing     Vulnerable (VU)
# 3235           Stable  Least concern (LC)
# 3236       Decreasing  Least concern (LC)
#
#                                              Attributes  \
# 0     [Nocturnal, Carnivore, Scavenger, Terrestrial,...
# 1     [Nocturnal, Carnivore, Cursorial, Terrestrial,...
# 2     [Crepuscular, Omnivore, Terrestrial, Altricial...
# 3     [Carnivore, Piscivores, Aquatic, Precocial, Na...
# 4     [Diurnal, Carnivore, Aquatic, Precocial, Cosmo...
# ...                                                 ...
# 3232  [Diurnal, Omnivore, Zoochory, Terrestrial, Mon...
# 3233  [Diurnal, Herbivore, Frugivore, Nectarivore, A...
# 3234  [Diurnal, Carnivore, Insectivores, Terrestrial...
# 3235          [Terrestrial, Not a migrant, starts with]
# 3236  [Diurnal, Nocturnal, Carnivore, Piscivores, Te...
#
#                                              Continents  \
# 0              [Asia,  Europe,  North America,  Africa]
# 1                                                [Asia]
# 2                       [Asia,  Europe,  North America]
# 3     [Africa,  South America,  Oceania,  North Amer...
# 4     [Africa,  Oceania,  Antarctica,  North America...
# ...                                                 ...
# 3232                    [South America,  North America]
# 3233                                    [North America]
# 3234                                                NaN
# 3235                    [South America,  North America]
# 3236                                    [South America]
#
#                                           Subcontinents  \
# 0     [South Asia,  Western Asia,  Southeast Asia,  ...
# 1             [South Asia,  Southeast Asia,  East Asia]
# 2     [South Asia,  Western Asia,  East Asia,  Centr...
# 3     [Sub-Saharan Africa,  Caribbean Islands,  Sout...
# 4     [North Africa,  Caribbean Islands,  South Asia...
# ...                                                 ...
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235                                                NaN
# 3236                                                NaN
#
#                                               Countries  \
# 0     [Albania,  Armenia,  Azerbaijan,  Belarus,  Bh...
# 1     [Bangladesh,  Bhutan,  China,    India,  Indon...
# 2     [Albania,  Armenia,  Austria,  Azerbaijan,  Be...
# 3     [Angola,  Argentina,  Australia,  Bahamas,  Ba...
# 4     [Algeria,  Antigua and Barbuda,  Argentina,  A...
# ...                                                 ...
# 3232  [Belize,  Costa Rica,  El Salvador,  Guatemala...
# 3233                                      [Saint Lucia]
# 3234                                                NaN
# 3235  [Trinidad and Tobago,  Belize,  Costa Rica,  E...
# 3236                                [Chile,  Argentina]
#
#                                                 Regions  \
# 0     [Czech Republic,  Estonia,  Finland,  France, ...
# 1                                            [Thailand]
# 2                                                   NaN
# 3     [Chile,  China,  Colombia,  Comoros,  Costa Ri...
# 4     [Brunei,  Cambodia,  Cameroon,  Canada,  Cape ...
# ...                                                 ...
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235  [Bolivia,  Brazil,  Colombia,  Guyana,  Peru, ...
# 3236                                 [Falkland Islands]
#
#                                              Wwf biomes  \
# 0     [Nearctic,  Palearctic,  Indomalayan,  Afrotro...
# 1                            [Palearctic,  Indomalayan]
# 2                 [Nearctic,  Palearctic,  Indomalayan]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3232                                                NaN
# 3233                                                NaN
# 3234                                                NaN
# 3235                                                NaN
# 3236                                                NaN
#
#                              Group name  \
# 0                 [pack,  route,  rout]
# 1                                   NaN
# 2                      [sloth,  sleuth]
# 3     [pod,  gam,  herd,  school,  mod]
# 4     [pod,  gam,  herd,  school,  mod]
# ...                                 ...
# 3232                                NaN
# 3233                                NaN
# 3234                                NaN
# 3235                                NaN
# 3236                                NaN
#
#                                          Diet  \
# 0                    [Carnivore, , Scavenger]
# 1                                 [Carnivore]
# 2                                  [Omnivore]
# 3                   [Carnivore, , Piscivores]
# 4                                 [Carnivore]
# ...                                       ...
# 3232                                      NaN
# 3233  [Herbivore, , Frugivore, , Nectarivore]
# 3234                                      NaN
# 3235                                      NaN
# 3236                                      NaN
#
#                                  Biogeographical realms  \
# 0                                           [Greenland]
# 1                                      [Tibet,  Yunnan]
# 2     [Estonia,  Finland,  France,  Georgia,  Greece...
# 3                      [Atlantic Ocean,  Pacific Ocean]
# 4       [Arctic Ocean,  Atlantic Ocean,  Pacific Ocean]
# ...                                                 ...
# 3232                      [Colombia,  Peru,  Venezuela]
# 3233                                      [Neotropical]
# 3234                                                NaN
# 3235                                    [French Guiana]
# 3236                                      [Neotropical]
#
#                                               Lifestyle  \
# 0     [Terrestrial,  Cursorial,  Altricial,  Pack hu...
# 1     [Cursorial,  Terrestrial,  Ambush predator,  A...
# 2     [Terrestrial,  Altricial,  Nomadic,  Territori...
# 3     [Aquatic,  Precocial,  Natatorial,  Viviparous...
# 4     [Aquatic,  Precocial,  Cosmopolitan,  Natatori...
# ...                                                 ...
# 3232                                                NaN
# 3233  [Arboreal,  Zoochory,  Island endemic,  Terres...
# 3234                                                NaN
# 3235                                    [Terrestrial, ]
# 3236                                                NaN
#
#                                    Oceans
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                 [Greenland,  Kamchatka]
# 4     [Newfoundland,  Hawaii,  Greenland]
# ...                                   ...
# 3232                                  NaN
# 3233                                  NaN
# 3234                                  NaN
# 3235                                  NaN
# 3236     [Atlantic Ocean,  Pacific Ocean]
#
# [3237 rows x 46 columns]

# %% [markdown]
# Xử lý tại các cột list, những giá trị nan sẽ được thay thế thành một list rỗng []

# %%
data_df[element] = data_df[element].fillna(data_df.notna().applymap(lambda x: x or []))
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df
# Out:
#                           Name   Kingdom    Phylum   Subphylum     Class  \
# 0                    Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                        Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                   Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                   Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                 Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                        ...       ...       ...         ...       ...
# 3232     Yellow-billed cacique  Animalia  Chordata         NaN      Aves
# 3233        Saint Lucia oriole  Animalia  Chordata         NaN      Aves
# 3234        Swynnerton's robin  Animalia  Chordata         NaN      Aves
# 3235  Ochre-bellied flycatcher  Animalia  Chordata         NaN      Aves
# 3236  Magellanic diving petrel  Animalia  Chordata         NaN      Aves
#
#                   Order    Suborder           Family         Genus  \
# 0             Carnivora  Caniformia          Canidae         Canis
# 1             Carnivora  Feliformia          Felidae      Panthera
# 2             Carnivora  Caniformia          Ursidae         Ursus
# 3          Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4          Artiodactyla         NaN      Delphinidae       Orcinus
# ...                 ...         ...              ...           ...
# 3232      Passeriformes         NaN        Icteridae   Amblycercus
# 3233      Passeriformes         NaN        Icteridae       Icterus
# 3234      Passeriformes         NaN     Muscicapidae  Swynnertonia
# 3235      Passeriformes         NaN       Tyrannidae     Mionectes
# 3236  Procellariiformes         NaN   Procellariidae  Pelecanoides
#
#                        Species Population size   Life span Top speed  \
# 0                  Canis lupus         400,000   10-20 yrs   75 km/h
# 1              Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                 Ursus arctos         200,000   20-50 yrs   56 km/h
# 3        Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                 Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                        ...             ...         ...       ...
# 3232  Amblycercus holosericeus             NaN         NaN       NaN
# 3233        Icterus laudabilis             NaN         NaN       NaN
# 3234  Swynnertonia swynnertoni             NaN         NaN       NaN
# 3235      Mionectes oleagineus             NaN         NaN       NaN
# 3236    Pelecanoides magellani             NaN         NaN       NaN
#
#            Weight     Height        Length Introduced countries Seas Islands  \
# 0        16-60 kg   80-85 cm    105-160 cm                  NaN  NaN     NaN
# 1       65-306 kg        NaN    200-390 cm                  NaN  NaN     NaN
# 2      100-635 kg  70-153 cm     1.4-2.8 m                  NaN  NaN     NaN
# 3       100-160 t        NaN       25-30 m                  NaN  NaN     NaN
# 4           3-6 t        NaN         6-9 m                  NaN  NaN     NaN
# ...           ...        ...           ...                  ...  ...     ...
# 3232  56.7-70.9 g        NaN  21.6-25.4 cm                  NaN  NaN     NaN
# 3233       36.9 g        NaN      20-22 cm                  NaN  NaN     NaN
# 3234          NaN        NaN      12-13 cm                  NaN  NaN     NaN
# 3235         13 g        NaN           NaN                  NaN  NaN     NaN
# 3236    145-174 g        NaN         19 cm                  NaN  NaN     NaN
#
#                                                   Biome  \
# 0     [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1     [Forest, Rainforest, Montane forest, Riparian,...
# 2                                    [Forest, Woodland]
# 3          [Oceanic pelagic zone, Marine, Neritic zone]
# 4     [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                 ...
# 3232                                           [Forest]
# 3233  [Agricultural, Anthropogenic biome, Forest, Mo...
# 3234                                [Forest, Mountains]
# 3235  [Forest, Rainforest, Grassland, Freshwater, An...
# 3236  [Coastal, Neritic zone, Oceanic pelagic zone, ...
#
#                                  Climate       Seasonal behavior Predators  \
# 0     [Temperate, Cold, Polar, Tropical]           Not a migrant       NaN
# 1                  [Tropical, Temperate]           Not a migrant       NaN
# 2               [Temperate, Cold, Polar]  Hibernating, Migrating       NaN
# 3     [Tropical, Temperate, Cold, Polar]               Migrating       NaN
# 4     [Tropical, Temperate, Cold, Polar]         Partial Migrant       NaN
# ...                                  ...                     ...       ...
# 3232                          [Tropical]                     NaN       NaN
# 3233                          [Tropical]           Not a migrant       NaN
# 3234                          [Tropical]                     NaN       NaN
# 3235                                  []           Not a migrant       NaN
# 3236                         [Temperate]                     NaN       NaN
#
#                                            Bird's call Mating behavior  \
# 0                                                  NaN        Monogamy
# 1                                                  NaN        Polygyny
# 2                                                  NaN   Polygynandry,
# 3                                                  NaN        Monogamy
# 4                                                  NaN    Polygynandry
# ...                                                ...             ...
# 3232                                               NaN             NaN
# 3233                                                               NaN
# 3234                                               NaN             NaN
# 3235  Your browser does not support the audio element.             NaN
# 3236                                               NaN             NaN
#
#                 Reproduction season Pregnancy duration Baby carrying  \
# 0                     January-April         60-63 days     1-14 pups
# 1                    November-April           103 days      1-7 cubs
# 2                          May-July            8 weeks      1-4 cubs
# 3            winter or early spring             1 year        1 calf
# 4     year-round, usually in summer       15-18 months        1 calf
# ...                             ...                ...           ...
# 3232                            NaN                NaN           NaN
# 3233                            NaN                NaN           NaN
# 3234                            NaN                NaN           NaN
# 3235                            NaN                NaN           NaN
# 3236                            NaN                NaN           NaN
#
#      Independent age Female name Male name   Baby name Incubation period  \
# 0            45 days       bitch       dog  pup, whelp               NaN
# 1       18 mos-3 yrs         NaN       NaN         cub               NaN
# 2          2-4 years         sow      boar         cub               NaN
# 3           8 months         cow      bull        calf               NaN
# 4            2 years         cow      bull        calf               NaN
# ...              ...         ...       ...         ...               ...
# 3232             NaN         NaN       NaN         NaN               NaN
# 3233             NaN         NaN       NaN         NaN               NaN
# 3234             NaN         NaN       NaN         NaN               NaN
# 3235             NaN         NaN       NaN         NaN               NaN
# 3236             NaN         NaN       NaN         NaN               NaN
#
#      Population trend   Population status  \
# 0              Stable  Least concern (LC)
# 1          Decreasing     Endangered (EN)
# 2              Stable  Least concern (LC)
# 3          Increasing     Endangered (EN)
# 4                 NaN                 NaN
# ...               ...                 ...
# 3232       Decreasing  Least concern (LC)
# 3233       Decreasing     Endangered (EN)
# 3234       Decreasing     Vulnerable (VU)
# 3235           Stable  Least concern (LC)
# 3236       Decreasing  Least concern (LC)
#
#                                              Attributes  \
# 0     [Nocturnal, Carnivore, Scavenger, Terrestrial,...
# 1     [Nocturnal, Carnivore, Cursorial, Terrestrial,...
# 2     [Crepuscular, Omnivore, Terrestrial, Altricial...
# 3     [Carnivore, Piscivores, Aquatic, Precocial, Na...
# 4     [Diurnal, Carnivore, Aquatic, Precocial, Cosmo...
# ...                                                 ...
# 3232  [Diurnal, Omnivore, Zoochory, Terrestrial, Mon...
# 3233  [Diurnal, Herbivore, Frugivore, Nectarivore, A...
# 3234  [Diurnal, Carnivore, Insectivores, Terrestrial...
# 3235          [Terrestrial, Not a migrant, starts with]
# 3236  [Diurnal, Nocturnal, Carnivore, Piscivores, Te...
#
#                                              Continents  \
# 0              [Asia,  Europe,  North America,  Africa]
# 1                                                [Asia]
# 2                       [Asia,  Europe,  North America]
# 3     [Africa,  South America,  Oceania,  North Amer...
# 4     [Africa,  Oceania,  Antarctica,  North America...
# ...                                                 ...
# 3232                    [South America,  North America]
# 3233                                    [North America]
# 3234                                                 []
# 3235                    [South America,  North America]
# 3236                                    [South America]
#
#                                           Subcontinents  \
# 0     [South Asia,  Western Asia,  Southeast Asia,  ...
# 1             [South Asia,  Southeast Asia,  East Asia]
# 2     [South Asia,  Western Asia,  East Asia,  Centr...
# 3     [Sub-Saharan Africa,  Caribbean Islands,  Sout...
# 4     [North Africa,  Caribbean Islands,  South Asia...
# ...                                                 ...
# 3232                                                 []
# 3233                                                 []
# 3234                                                 []
# 3235                                                 []
# 3236                                                 []
#
#                                               Countries  \
# 0     [Albania,  Armenia,  Azerbaijan,  Belarus,  Bh...
# 1     [Bangladesh,  Bhutan,  China,    India,  Indon...
# 2     [Albania,  Armenia,  Austria,  Azerbaijan,  Be...
# 3     [Angola,  Argentina,  Australia,  Bahamas,  Ba...
# 4     [Algeria,  Antigua and Barbuda,  Argentina,  A...
# ...                                                 ...
# 3232  [Belize,  Costa Rica,  El Salvador,  Guatemala...
# 3233                                      [Saint Lucia]
# 3234                                                 []
# 3235  [Trinidad and Tobago,  Belize,  Costa Rica,  E...
# 3236                                [Chile,  Argentina]
#
#                                                 Regions  \
# 0     [Czech Republic,  Estonia,  Finland,  France, ...
# 1                                            [Thailand]
# 2                                                    []
# 3     [Chile,  China,  Colombia,  Comoros,  Costa Ri...
# 4     [Brunei,  Cambodia,  Cameroon,  Canada,  Cape ...
# ...                                                 ...
# 3232                                                 []
# 3233                                                 []
# 3234                                                 []
# 3235  [Bolivia,  Brazil,  Colombia,  Guyana,  Peru, ...
# 3236                                 [Falkland Islands]
#
#                                              Wwf biomes  \
# 0     [Nearctic,  Palearctic,  Indomalayan,  Afrotro...
# 1                            [Palearctic,  Indomalayan]
# 2                 [Nearctic,  Palearctic,  Indomalayan]
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3232                                                 []
# 3233                                                 []
# 3234                                                 []
# 3235                                                 []
# 3236                                                 []
#
#                              Group name  \
# 0                 [pack,  route,  rout]
# 1                                    []
# 2                      [sloth,  sleuth]
# 3     [pod,  gam,  herd,  school,  mod]
# 4     [pod,  gam,  herd,  school,  mod]
# ...                                 ...
# 3232                                 []
# 3233                                 []
# 3234                                 []
# 3235                                 []
# 3236                                 []
#
#                                          Diet  \
# 0                    [Carnivore, , Scavenger]
# 1                                 [Carnivore]
# 2                                  [Omnivore]
# 3                   [Carnivore, , Piscivores]
# 4                                 [Carnivore]
# ...                                       ...
# 3232                                       []
# 3233  [Herbivore, , Frugivore, , Nectarivore]
# 3234                                       []
# 3235                                       []
# 3236                                       []
#
#                                  Biogeographical realms  \
# 0                                           [Greenland]
# 1                                      [Tibet,  Yunnan]
# 2     [Estonia,  Finland,  France,  Georgia,  Greece...
# 3                      [Atlantic Ocean,  Pacific Ocean]
# 4       [Arctic Ocean,  Atlantic Ocean,  Pacific Ocean]
# ...                                                 ...
# 3232                      [Colombia,  Peru,  Venezuela]
# 3233                                      [Neotropical]
# 3234                                                 []
# 3235                                    [French Guiana]
# 3236                                      [Neotropical]
#
#                                               Lifestyle  \
# 0     [Terrestrial,  Cursorial,  Altricial,  Pack hu...
# 1     [Cursorial,  Terrestrial,  Ambush predator,  A...
# 2     [Terrestrial,  Altricial,  Nomadic,  Territori...
# 3     [Aquatic,  Precocial,  Natatorial,  Viviparous...
# 4     [Aquatic,  Precocial,  Cosmopolitan,  Natatori...
# ...                                                 ...
# 3232                                                 []
# 3233  [Arboreal,  Zoochory,  Island endemic,  Terres...
# 3234                                                 []
# 3235                                    [Terrestrial, ]
# 3236                                                 []
#
#                                    Oceans
# 0                                      []
# 1                                      []
# 2                                      []
# 3                 [Greenland,  Kamchatka]
# 4     [Newfoundland,  Hawaii,  Greenland]
# ...                                   ...
# 3232                                   []
# 3233                                   []
# 3234                                   []
# 3235                                   []
# 3236     [Atlantic Ocean,  Pacific Ocean]
#
# [3237 rows x 46 columns]

# %% [markdown]
# ### Chuyển cột Top speed sang kiểu số

# %%
def trans_speed(speed):
    speed = [speed[:-4].strip(), speed[-4:].strip()]
    if speed[1] == 'km/h':
        x = 1
    elif speed[1] == 'mph':
        x = 1.61
    sp = speed[0].split('-')
    if len(sp) == 1:
        return float(sp[0]) * x
    else:
        return (float(sp[0]) + float(sp[1])) / 2 * x

# %%
data_df['Top speed'] = data_df['Top speed'].dropna().apply(trans_speed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2215/3527003076.py in <cell line: 1>()
# ----> 1 data_df['Top speed'] = data_df['Top speed'].dropna().apply(trans_speed)
#
# NameError: name 'data_df' is not defined

# %%
def to_float(element):
    try:
        return float(element)
    except ValueError:
        return np.nan

# %% [markdown]
# ### Chuyển cột life_span sang float

# %%
def trans_life_span(life):
    life = str(life)
    life = life.upper()
    life = life.replace('UPPER', '')
    life = life.replace('ABOVE', '')
    life = life.replace('OVER','')
    life = life.replace('mos', ' MONTHS ')
    life = life.replace('yr', ' YEARS ')
    life = life.replace('YRS', ' YEARS ')
    life = life.replace('YEARS', ' YEARS ')
    life = life.split('-')
    low = to_float(life[0])
    high = to_float(life[-1].split()[0].strip())
    x = life[-1].split()[-1].strip()
    if np.isnan(low):
        low = high
    t = 1.0
    if x == 'MONTHS':
        t = 1 / 12
    elif x == 'YEARS':
        t = 1.0
    low = low * t
    high = high * t
    return (low, high)

# %%
data_df['Life span'].dropna().apply(trans_life_span)
#data_df['Life span'].dropna()

# %% [markdown]
# ## Thống kê các chỉ số cho các cột có kiểu dữ liệu là list

# %%
def stat_list_col(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.hstack(temp)
    temp = list(map(str.strip, temp)) # Xử lý các dấu cách đầu và cuối mỗi chuỗi
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

#     total = data_df[col].tolist()
#     total = np.hstack(total)
#     value, times = np.unique(total, return_counts = True)

# %%
list_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in data_df:
    if type(data_df[i][0]) == list:
        list_col_info_df[i] = stat_list_col(i, data_df)
list_col_info_df

# %% [markdown]
# ### Lưu dữ liệu đã tiền xử lý vào file 'animals_split_info.csv' để tiếp tục sử dụng trong các phần sau

# %%
data_df.to_csv('animals_split_info.csv')
