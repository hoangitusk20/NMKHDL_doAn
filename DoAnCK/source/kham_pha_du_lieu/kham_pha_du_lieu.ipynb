# %% [markdown]
# # Khám phá dữ liệu

# %% [markdown]
# Notebook này để khám phá dữ liệu.

# %% [markdown]
# ## Import những thư viện cần thiết

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Đọc dữ liệu từ file

# %% [markdown]
# File dữ liệu của đồ án sau bước thu thập dữ liệu đang nằm tại địa chỉ '../thu_thap_du_lieu/animal_crawler/animal_info.csv'. Ta sẽ tiến hành đọc dữ liệu đã thu thập và lưu vào DataFrame `animal_df`

# %%
animal_df = pd.read_csv('../thu_thap_du_lieu/animal_crawler/animals_info.csv')

# %% [markdown]
# Hiển thị 5 dòng đầu tiên trong dữ liệu để xem thử đã đọc đúng hay chưa

# %%
pd.reset_option('display.max_colwidth')
animal_df.head(5)
# Out:
#            Name   Kingdom    Phylum   Subphylum     Class         Order  \
# 0     Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 1         Tiger  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 2    Brown Bear  Animalia  Chordata  Vertebrata  Mammalia     Carnivora
# 3    Blue Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
# 4  Killer Whale  Animalia  Chordata  Vertebrata  Mammalia  Artiodactyla
#
#      Suborder           Family         Genus                Species  ...  \
# 0  Caniformia          Canidae         Canis            Canis lupus  ...
# 1  Feliformia          Felidae      Panthera        Panthera tigris  ...
# 2  Caniformia          Ursidae         Ursus           Ursus arctos  ...
# 3         NaN  Balaenopteridae  Balaenoptera  Balaenoptera musculus  ...
# 4         NaN      Delphinidae       Orcinus           Orcinus orca  ...
#
#   Top speed      Weight     Height      Length  \
# 0   75 km/h    16-60 kg   80-85 cm  105-160 cm
# 1   96 km/h   65-306 kg        NaN  200-390 cm
# 2   56 km/h  100-635 kg  70-153 cm   1.4-2.8 m
# 3   20 km/h   100-160 t        NaN     25-30 m
# 4   45 km/h       3-6 t        NaN       6-9 m
#
#                                           Attributes  \
# 0  Nocturnal,Carnivore,Scavenger,Terrestrial,Curs...
# 1  Nocturnal,Carnivore,Cursorial,Terrestrial,Ambu...
# 2  Crepuscular,Omnivore,Terrestrial,Altricial,Nom...
# 3  Carnivore,Piscivores,Aquatic,Precocial,Natator...
# 4  Diurnal,Carnivore,Aquatic,Precocial,Cosmopolit...
#
#                                         Distribution  \
# 0  {'Geography': {'Continents': 'Asia, Europe, No...
# 1  {'Geography': {'Continents': 'Asia', 'Subconti...
# 2  {'Geography': {'Continents': 'Asia, Europe, No...
# 3  {'Geography': {'Continents': 'Africa, South Am...
# 4  {'Geography': {'Continents': 'Africa, Oceania,...
#
#                                               Habits                   Diet  \
# 0  {'Group name': 'pack, route, rout', 'Lifestyle...   Carnivore,,Scavenger
# 1  {'Lifestyle': 'Cursorial, Terrestrial, Ambush ...              Carnivore
# 2  {'Group name': 'sloth, sleuth', 'Lifestyle': '...               Omnivore
# 3  {'Group name': 'pod, gam, herd, school, mod', ...  Carnivore,,Piscivores
# 4  {'Group name': 'pod, gam, herd, school, mod', ...              Carnivore
#
#                                        Mating_Habits  \
# 0  {'Mating behavior': 'Monogamy', 'Reproduction ...
# 1  {'Mating behavior': 'Polygyny', 'Reproduction ...
# 2  {'Mating behavior': 'Polygynandry,', 'Reproduc...
# 3  {'Mating behavior': 'Monogamy', 'Reproduction ...
# 4  {'Mating behavior': 'Polygynandry', 'Reproduct...
#
#                                           Population
# 0  {'Population trend': 'Stable', 'Population sta...
# 1  {'Population trend': 'Decreasing', 'Population...
# 2  {'Population trend': 'Stable', 'Population sta...
# 3  {'Population trend': 'Increasing', 'Population...
# 4       {'Population status': 'Data deficient (DD)'}
#
# [5 rows x 22 columns]

# %% [markdown]
# Xem xét dữ liệu trên thì thấy một số dòng bị lỗi, cần loại bỏ.
# Cụ thể ở đây là thu thập dữ liệu về thú nhưng có một số dòng có giá trị cột 'Kingdom' không phải là 'Animalia'. Ở đây ta sẽ xóa luôn những dòng như thế, vì dữ liệu khá lớn nên xóa bớt một vài dòng có lẽ sẽ không có ảnh hưởng nhiều.

# %%
animal_df = animal_df[animal_df['Kingdom'] == 'Animalia']

# %% [markdown]
# ## Dữ liệu có bao nhiêu dòng, bao nhiêu cột?

# %%
animal_df.shape
# Out:
# (28525, 22)

# %% [markdown]
# ## Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng cho chúng ta biết các thông tin về một con vật, tất cả các dòng đều có cùng ý nghĩa như nhau.

# %% [markdown]
# ## Dữ liệu có các dòng bị lặp không?

# %% [markdown]
# Chúng ta sử dụng hàm 'duplicated' trong pandas để kiểm tra dòng đó có phải bị lặp trong DataFrame hay không. Nếu kết quả là dòng đó bị lặp sẽ trả về giá trị 1, ngược lại sẽ là 0. Kế tiếp chúng ta sử dùng hàm 'sum' để tính tất cả giá trị trả về của hàm 'duplicated'. Nếu kết quả > 0 thì chứng tỏ có tồn tại dòng bị lặp.

# %%
animal_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Vậy là dữ liệu của chúng ta không tồn lại dòng nào bị lặp lại.

# %% [markdown]
# ## Mỗi cột có ý nghĩa gì?

# %% [markdown]
# Sau khi thu thập dữ liệu xong, nhóm em đã tự phân tích ý nghĩa của mỗi trong file dữ liệu vừa thu thập, sau đó viết vào file `col_meaning.xlsx`. Đọc file excel này để biết được ý nghĩa của mỗi cột.

# %%
xlsx = pd.ExcelFile('col_meaning.xlsx')
col_meaning_df =pd.read_excel(xlsx,"Sheet1")
pd.set_option('display.max_colwidth', 0)
col_meaning_df
# Out:
#              Column  \
# 0   Name
# 1   Kingdom
# 2   Phylum
# 3   Subphylum
# 4   Class
# 5   Order
# 6   Suborder
# 7   Family
# 8   Genus
# 9   Species
# 10  Population size
# 11  Life span
# 12  Top speed
# 13  Weight
# 14  Height
# 15  Length
# 16  Attributes
# 17  Distribution
# 18  Habits
# 19  Diet
# 20  Mating_Habits
# 21  Population
#
#                                                                                                                                                   Description
# 0   Name of Animal
# 1   Giới là đơn vị phân loại lớn nhất bao gồm các ngành sinh vật có chung những đặc điểm nhất định.
# 2   Ngành: Một đơn vị phân loại ở cấp dưới giới và trên lớp.
# 3   Phân Ngành: là một bậc phân loại nằm trung gian giữa ngành và lớp hoặc phân thứ ngành hoặc liên lớp
# 4   Lớp: Một mức độ phân loại động vật trong một ngành. Các lớp sau đó được chia nhỏ thành các nhóm khác được gọi là bộ
# 5   Bộ: là một cấp nằm giữa lớp và họ.
# 6   Phân bộ: một nhóm thực vật hoặc động vật có liên quan, có quan hệ gần gũi hơn so với một bộ nhưng ít giống nhau hơn so với một họ.
# 7   Họ: Bộ được chia thành các họ, họ sẽ được chia thành các chi
# 8   Chi: còn gọi là giống là một đơn vị phân loại sinh học dùng để chỉ một hoặc một nhóm loài có kiểu hình tương tự và mối quan hệ tiến hóa gần gũi với nhau.
# 9   Loài: là một nhóm các cá thể sinh vật có những đặc điểm sinh học tương đối giống nhau và có khả năng giao phối với nhau và sinh sản ra thế hệ tương lai.
# 10  Ước tính số cá thể đang sống của loài
# 11  Tuổi thọ
# 12  Tốc độ
# 13  Cân nặng
# 14  Chiều cao
# 15  Chiều dài
# 16  Một số thông tin chính về loài vật
# 17  Phân bổ: Nơi sinh sống
# 18  Thói quen
# 19  Chế độ ăn (ăn cỏ, ăn tạp,…)
# 20  Thói quen giao phối
# 21  Bao gồm xu hướng dân số (tăng, giảm, ổn định) và trạng thái dân số (nguy cấp, bị đe dọa, ít quan tâm,…)

# %% [markdown]
# ## Các cột lúc này đang có kiểu dữ liệu gì?

# %%
animal_df.dtypes
# Out:
# Name               object
# Kingdom            object
# Phylum             object
# Subphylum          object
# Class              object
# Order              object
# Suborder           object
# Family             object
# Genus              object
# Species            object
# Population size    object
# Life span          object
# Top speed          object
# Weight             object
# Height             object
# Length             object
# Attributes         object
# Distribution       object
# Habits             object
# Diet               object
# Mating_Habits      object
# Population         object
# dtype: object

# %% [markdown]
# ## Tính xem tình trạng của mỗi cột dữ liệu hiện tại như thế nào?

# %% [markdown]
# ### Với mỗi cột ta sẽ tính:
# - Tỉ lệ mất mát: missing_ratio
# - Số lượng giá trị khác nhau: num_values
# - Số lần xuất hiện của từng giá trị: value
#
# Viết hàm "col_info" để tính và lưu kết quả vào mảng "cat_col_info_df"

# %%
def col_info(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

# %%
cat_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in animal_df.columns:
    if animal_df[i].dtype not in [float, int]:
        cat_col_info_df[i] = col_info(i, animal_df)
        
pd.reset_option('display.max_colwidth')
cat_col_info_df
# Out:
#                                                             Name  \
# missing_ratio                                                0.0
# num_values                                                 28525
# value          ? Nycticebus linglom      1
# AEECL's sportive l...
#
#                                       Kingdom  \
# missing_ratio                             0.0
# num_values                                  1
# value          Animalia    28525
# dtype: int64
#
#                                                          Phylum  \
# missing_ratio                                               0.0
# num_values                                                    2
# value          Chordata    23659
# Mollusca     4866
# dtype: int64
#
#                                       Subphylum  \
# missing_ratio                              64.4
# num_values                                    1
# value          Vertebrata    10152
# dtype: int64
#
#                                                            Class  \
# missing_ratio                                                0.0
# num_values                                                    10
# value          Amphibia           3393
# Aves              1011...
#
#                                                            Order  \
# missing_ratio                                                1.5
# num_values                                                   118
# value          Accipitriformes    255
# Adapedonta          10
# ...
#
#                                                         Suborder  \
# missing_ratio                                               91.0
# num_values                                                    13
# value          Alcedini            109
# Caniformia          19...
#
#                                                           Family  \
# missing_ratio                                                0.0
# num_values                                                   840
# value          Abrocomidae           10
# Abronicidae          ...
#
#                                                            Genus  \
# missing_ratio                                                0.0
# num_values                                                  6127
# value          Aaadonta        6
# Abditomys       1
# Abeillia  ...
#
#                                                          Species  ...  \
# missing_ratio                                                0.0  ...
# num_values                                                 28523  ...
# value          "Calamita" melanorabdotus          1
# "Calamita...  ...
#
#                                                        Top speed  \
# missing_ratio                                               98.0
# num_values                                                   124
# value          0.24 km/h    1
# 0.26 km/h    1
# 0.27 km/h    1
# 0...
#
#                                                           Weight  \
# missing_ratio                                               90.0
# num_values                                                  2232
# value          0-0 kg            3
# 0.010-0.796 g     1
# 0.02-2...
#
#                                                           Height  \
# missing_ratio                                               98.9
# num_values                                                   245
# value          0.5 m          1
# 0.7-1.3 m      1
# 0.75-1 m    ...
#
#                                                           Length  \
# missing_ratio                                               89.7
# num_values                                                  2101
# value          0.5 m          2
# 0.5-1.8 m      1
# 0.6-2.43 m  ...
#
#                                                       Attributes  \
# missing_ratio                                                0.0
# num_values                                                  3078
# value          Algivore,Detritivore,Herbivore,Fossorial,Polyg...
#
#                                                     Distribution  \
# missing_ratio                                                0.0
# num_values                                                  8335
# value          {'Geography': {'Biogeographical realms': 'Aust...
#
#                                                           Habits  \
# missing_ratio                                                0.0
# num_values                                                  2143
# value          {'Group name': '"bind", contradiction, fling, ...
#
#                                                             Diet  \
# missing_ratio                                               90.9
# num_values                                                   308
# value          Algivore,,Detritivore,,Herbivore              ...
#
#                                                    Mating_Habits  \
# missing_ratio                                                0.0
# num_values                                                  2682
# value          {'Baby carrying': '1 baby'}                   ...
#
#                                                       Population
# missing_ratio                                                0.0
# num_values                                                    40
# value          {'Population status': 'Critically endangered (...
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Xử lý tách các cột có kiểu dictionary thành nhiều cột

# %% [markdown]
# Đầu tiên các cột dictionary đều có kiểu là string nên ta phải xử lý chuyển các cột trên thành dict

# %%
for i in animal_df:
    if animal_df[i][0].find('{') != -1:
        animal_df[i] = animal_df[i].apply(eval)

# %% [markdown]
# Viết hàm "split_col" để split các cột có kiểu dữ liệu là dict thành nhiều cột

# %%
def split_col(df):
    df_split_animals_info = pd.DataFrame()
    for col in df.columns:
        if type(df[col][0]) == dict:
            df_split_animals_info = pd.concat([df_split_animals_info, df[col].apply(pd.Series, dtype = object)], axis = 1)
        else:
            df_col = pd.DataFrame(df[col])
            df_split_animals_info = pd.concat([df_split_animals_info, df_col], axis = 1)
    return df_split_animals_info

# %%
df_split_animals_info = pd.DataFrame()
a= pd.DataFrame(animal_df['Name'])
df_split_animals_info = pd.concat([df_split_animals_info, a], axis = 1)
df_split_animals_info = pd.concat([df_split_animals_info, a], axis = 1)
df_split_animals_info
# Out:
#                               Name                         Name
# 0                        Grey Wolf                    Grey Wolf
# 1                            Tiger                        Tiger
# 2                       Brown Bear                   Brown Bear
# 3                       Blue Whale                   Blue Whale
# 4                     Killer Whale                 Killer Whale
# ...                            ...                          ...
# 29350            Córdoba cinclodes            Córdoba cinclodes
# 29351          Western hemispingus          Western hemispingus
# 29352  Sulphur-bearded reedhaunter  Sulphur-bearded reedhaunter
# 29355        McConnell's spinetail        McConnell's spinetail
# 29356              Junín canastero              Junín canastero
#
# [28525 rows x 2 columns]

# %%
df_split_animals_info = split_col(animal_df)
pd.set_option('display.max_columns', None)
df_split_animals_info
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0                        Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                            Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                       Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                       Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                     Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                            ...       ...       ...         ...       ...
# 29350            Córdoba cinclodes  Animalia  Chordata         NaN      Aves
# 29351          Western hemispingus  Animalia  Chordata         NaN      Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata         NaN      Aves
# 29355        McConnell's spinetail  Animalia  Chordata         NaN      Aves
# 29356              Junín canastero  Animalia  Chordata         NaN      Aves
#
#                Order    Suborder           Family         Genus  \
# 0          Carnivora  Caniformia          Canidae         Canis
# 1          Carnivora  Feliformia          Felidae      Panthera
# 2          Carnivora  Caniformia          Ursidae         Ursus
# 3       Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4       Artiodactyla         NaN      Delphinidae       Orcinus
# ...              ...         ...              ...           ...
# 29350  Passeriformes         NaN      Furnariidae     Cinclodes
# 29351  Passeriformes         NaN       Thraupidae    Sphenopsis
# 29352  Passeriformes         NaN      Furnariidae   Cranioleuca
# 29355  Passeriformes         NaN      Furnariidae    Synallaxis
# 29356  Passeriformes         NaN      Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0                    Canis lupus         400,000   10-20 yrs   75 km/h
# 1                Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                   Ursus arctos         200,000   20-50 yrs   56 km/h
# 3          Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                   Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                          ...             ...         ...       ...
# 29350    Cinclodes comechingonus             NaN         NaN       NaN
# 29351        Sphenopsis ochracea             NaN         NaN       NaN
# 29352  Limnoctites sulphuriferus             NaN         NaN       NaN
# 29355     Synallaxis macconnelli             NaN         NaN       NaN
# 29356           Asthenes virgata             NaN         NaN       NaN
#
#            Weight     Height      Length  \
# 0        16-60 kg   80-85 cm  105-160 cm
# 1       65-306 kg        NaN  200-390 cm
# 2      100-635 kg  70-153 cm   1.4-2.8 m
# 3       100-160 t        NaN     25-30 m
# 4           3-6 t        NaN       6-9 m
# ...           ...        ...         ...
# 29350         NaN        NaN         NaN
# 29351         NaN        NaN         NaN
# 29352         NaN        NaN         NaN
# 29355         NaN        NaN         NaN
# 29356         NaN        NaN         NaN
#
#                                               Attributes  \
# 0      Nocturnal,Carnivore,Scavenger,Terrestrial,Curs...
# 1      Nocturnal,Carnivore,Cursorial,Terrestrial,Ambu...
# 2      Crepuscular,Omnivore,Terrestrial,Altricial,Nom...
# 3      Carnivore,Piscivores,Aquatic,Precocial,Natator...
# 4      Diurnal,Carnivore,Aquatic,Precocial,Cosmopolit...
# ...                                                  ...
# 29350                  Terrestrial,Migrating,starts with
# 29351              Terrestrial,Not a migrant,starts with
# 29352                  Terrestrial,Migrating,starts with
# 29355              Terrestrial,Not a migrant,starts with
# 29356              Terrestrial,Not a migrant,starts with
#
#                                                Geography  \
# 0      {'Continents': 'Asia, Europe, North America, A...
# 1      {'Continents': 'Asia', 'Subcontinents': 'South...
# 2      {'Continents': 'Asia, Europe, North America', ...
# 3      {'Continents': 'Africa, South America, Oceania...
# 4      {'Continents': 'Africa, Oceania, Antarctica, N...
# ...                                                  ...
# 29350  {'Continents': 'South America', 'Countries': '...
# 29351  {'Continents': 'South America', 'Countries': '...
# 29352  {'Continents': 'South America', 'Countries': '...
# 29355  {'Continents': 'South America', 'Countries': '...
# 29356  {'Continents': 'South America', 'Countries': '...
#
#                                                    Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1      [Forest, Rainforest, Montane forest, Riparian,...
# 2                                     [Forest, Woodland]
# 3           [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                  ...
# 29350                          [Grassland, Rocky areas ]
# 29351                                           [Forest]
# 29352                 [Freshwater, Shrubland, Wetlands ]
# 29355                      [Anthropogenic biome, Forest]
# 29356                             [Grassland, Shrubland]
#
#                                   Climate                   Group name  \
# 0      [Temperate, Cold, Polar, Tropical]            pack, route, rout
# 1                   [Tropical, Temperate]                          NaN
# 2                [Temperate, Cold, Polar]                sloth, sleuth
# 3      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# 4      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# ...                                   ...                          ...
# 29350                                  []                          NaN
# 29351                                  []                          NaN
# 29352                                  []                          NaN
# 29355                                  []                          NaN
# 29356                                  []                          NaN
#
#                                                Lifestyle  \
# 0      Terrestrial, Cursorial, Altricial, Pack hunter...
# 1      Cursorial, Terrestrial, Ambush predator, Altri...
# 2      Terrestrial, Altricial, Nomadic, Territorial, ...
# 3      Aquatic, Precocial, Natatorial, Viviparous, Co...
# 4      Aquatic, Precocial, Cosmopolitan, Natatorial, ...
# ...                                                  ...
# 29350                                                NaN
# 29351                                       Terrestrial,
# 29352                                       Terrestrial,
# 29355                                                NaN
# 29356                                       Terrestrial,
#
#             Seasonal behavior Predators  \
# 0               Not a migrant       NaN
# 1               Not a migrant       NaN
# 2      Hibernating, Migrating       NaN
# 3                   Migrating       NaN
# 4             Partial Migrant       NaN
# ...                       ...       ...
# 29350                     NaN       NaN
# 29351           Not a migrant       NaN
# 29352               Migrating       NaN
# 29355                     NaN       NaN
# 29356           Not a migrant       NaN
#
#                                             Bird's call  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 29350                                               NaN
# 29351                                               NaN
# 29352                                               NaN
# 29355                                               NaN
# 29356  Your browser does not support the audio element.
#
#                         Diet Mating behavior            Reproduction season  \
# 0       Carnivore,,Scavenger        Monogamy                  January-April
# 1                  Carnivore        Polygyny                 November-April
# 2                   Omnivore   Polygynandry,                       May-July
# 3      Carnivore,,Piscivores        Monogamy         winter or early spring
# 4                  Carnivore    Polygynandry  year-round, usually in summer
# ...                      ...             ...                            ...
# 29350                    NaN             NaN                            NaN
# 29351                    NaN             NaN                            NaN
# 29352                    NaN             NaN                            NaN
# 29355                    NaN             NaN                            NaN
# 29356                    NaN             NaN                            NaN
#
#       Pregnancy duration Baby carrying Independent age Female name Male name  \
# 0             60-63 days     1-14 pups         45 days       bitch       dog
# 1               103 days      1-7 cubs    18 mos-3 yrs         NaN       NaN
# 2                8 weeks      1-4 cubs       2-4 years         sow      boar
# 3                 1 year        1 calf        8 months         cow      bull
# 4           15-18 months        1 calf         2 years         cow      bull
# ...                  ...           ...             ...         ...       ...
# 29350                NaN           NaN             NaN         NaN       NaN
# 29351                NaN           NaN             NaN         NaN       NaN
# 29352                NaN           NaN             NaN         NaN       NaN
# 29355                NaN           NaN             NaN         NaN       NaN
# 29356                NaN           NaN             NaN         NaN       NaN
#
#         Baby name Incubation period Population trend    Population status
# 0      pup, whelp               NaN           Stable   Least concern (LC)
# 1             cub               NaN       Decreasing      Endangered (EN)
# 2             cub               NaN           Stable   Least concern (LC)
# 3            calf               NaN       Increasing      Endangered (EN)
# 4            calf               NaN              NaN  Data deficient (DD)
# ...           ...               ...              ...                  ...
# 29350         NaN               NaN       Decreasing   Least concern (LC)
# 29351         NaN               NaN           Stable   Least concern (LC)
# 29352         NaN               NaN       Decreasing   Least concern (LC)
# 29355         NaN               NaN           Stable   Least concern (LC)
# 29356         NaN               NaN          Unknown   Least concern (LC)
#
# [28525 rows x 37 columns]

# %% [markdown]
# Sau khi split dữ liệu có số dòng là 28525 và số cột là 37, tăng lên 15 cột
#
# Nhưng nhìn lại dữ liệu vẫn còn cột là dictionary như "Geograpy", như vậy ta phải split thêm 1 lần nữa

# %%
df_split_animals_info = split_col(df_split_animals_info)
df_split_animals_info.head(100)
# Out:
#                  Name   Kingdom    Phylum   Subphylum     Class  \
# 0           Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1               Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2          Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3          Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4        Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ..                ...       ...       ...         ...       ...
# 106  Black Rhinoceros  Animalia  Chordata  Vertebrata  Mammalia
# 107           Markhor  Animalia  Chordata  Vertebrata  Mammalia
# 109     Eurasian Lynx  Animalia  Chordata  Vertebrata  Mammalia
# 110   Dromedary Camel  Animalia  Chordata  Vertebrata  Mammalia
# 114    Common Warthog  Animalia  Chordata  Vertebrata  Mammalia
#
#               Order    Suborder           Family         Genus  \
# 0         Carnivora  Caniformia          Canidae         Canis
# 1         Carnivora  Feliformia          Felidae      Panthera
# 2         Carnivora  Caniformia          Ursidae         Ursus
# 3      Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4      Artiodactyla         NaN      Delphinidae       Orcinus
# ..              ...         ...              ...           ...
# 106  Perissodactyla         NaN   Rhinocerotidae       Diceros
# 107    Artiodactyla         NaN          Bovidae         Capra
# 109       Carnivora  Feliformia          Felidae          Lynx
# 110    Artiodactyla         NaN        Camelidae       Camelus
# 114    Artiodactyla         NaN           Suidae  Phacochoerus
#
#                     Species Population size   Life span   Top speed  \
# 0               Canis lupus         400,000   10-20 yrs     75 km/h
# 1           Panthera tigris     2,154-3,159   10-15 yrs     96 km/h
# 2              Ursus arctos         200,000   20-50 yrs     56 km/h
# 3     Balaenoptera musculus      10-25 Thou   80-90 yrs     20 km/h
# 4              Orcinus orca          50,000  30-100 yrs     45 km/h
# ..                      ...             ...         ...         ...
# 106        Diceros bicornis     4,880-5,000   30-49 yrs  42-58 km/h
# 107         Capra falconeri           5,754   10-13 yrs     17 km/h
# 109               Lynx lynx      70-80 Thou   13-25 yrs     80 km/h
# 110     Camelus dromedarius             NaN   40-50 yrs     64 km/h
# 114  Phacochoerus africanus         Unknown   12-18 yrs         NaN
#
#            Weight      Height      Length  \
# 0        16-60 kg    80-85 cm  105-160 cm
# 1       65-306 kg         NaN  200-390 cm
# 2      100-635 kg   70-153 cm   1.4-2.8 m
# 3       100-160 t         NaN     25-30 m
# 4           3-6 t         NaN       6-9 m
# ..            ...         ...         ...
# 106  800-1,400 kg  140-180 cm     3-3.8 m
# 107     32-110 kg   65-115 cm  132-186 cm
# 109       8-30 kg    60-75 cm   80-130 cm
# 110    300-600 kg     1.7-2 m       2-3 m
# 114     45-150 kg  63.5-85 cm   0.9-1.5 m
#
#                                             Attributes  \
# 0    Nocturnal,Carnivore,Scavenger,Terrestrial,Curs...
# 1    Nocturnal,Carnivore,Cursorial,Terrestrial,Ambu...
# 2    Crepuscular,Omnivore,Terrestrial,Altricial,Nom...
# 3    Carnivore,Piscivores,Aquatic,Precocial,Natator...
# 4    Diurnal,Carnivore,Aquatic,Precocial,Cosmopolit...
# ..                                                 ...
# 106  Diurnal,Herbivore,Folivore,Lignivore,Terrestri...
# 107  Diurnal,Herbivore,Folivore,Graminivore,Terrest...
# 109  Crepuscular,Nocturnal,Carnivore,Terrestrial,Te...
# 110  Diurnal,Herbivore,Folivore,Graminivore,Terrest...
# 114  Diurnal,Omnivore,Scavenger,Terrestrial,Altrici...
#
#                                             Continents  \
# 0                  Asia, Europe, North America, Africa
# 1                                                 Asia
# 2                          Asia, Europe, North America
# 3    Africa, South America, Oceania, North America,...
# 4    Africa, Oceania, Antarctica, North America, So...
# ..                                                 ...
# 106                                             Africa
# 107                                               Asia
# 109                                       Asia, Europe
# 110                                       Africa, Asia
# 114                                             Africa
#
#                                          Subcontinents  \
# 0    South Asia, Western Asia, Southeast Asia, East...
# 1                South Asia, Southeast Asia, East Asia
# 2    South Asia, Western Asia, East Asia, Central A...
# 3    Sub-Saharan Africa, Caribbean Islands, South A...
# 4    North Africa, Caribbean Islands, South Asia, C...
# ..                                                 ...
# 106                                 Sub-Saharan Africa
# 107                           Central Asia, South Asia
# 109  South Asia, Western Asia, East Asia, Central Asia
# 110  North Africa, Sub-Saharan Africa, Western Asia...
# 114                                 Sub-Saharan Africa
#
#                                              Countries  \
# 0    Albania, Armenia, Azerbaijan, Belarus, Bhutan,...
# 1    Bangladesh, Bhutan, China,   India, Indonesia,...
# 2    Albania, Armenia, Austria, Azerbaijan, Belarus...
# 3    Angola, Argentina, Australia, Bahamas, Banglad...
# 4    Algeria, Antigua and Barbuda, Argentina, Austr...
# ..                                                 ...
# 106  Angola, Kenya, Mozambique, Namibia, South Afri...
# 107  Afghanistan, India, Pakistan, Tajikistan, Turk...
# 109  Albania, Armenia, Austria, Azerbaijan, Belarus...
# 110                                                NaN
# 114  Angola, Benin, Botswana, Burkina Faso, Burundi...
#
#                                                Regions  \
# 0    Czech Republic, Estonia, Finland, France, Geor...
# 1                                             Thailand
# 2                                                  NaN
# 3    Chile, China, Colombia, Comoros, Costa Rica, C...
# 4    Brunei, Cambodia, Cameroon, Canada, Cape Verde...
# ..                                                 ...
# 106                                                NaN
# 107                                                NaN
# 109                                                NaN
# 110  New South Wales, South Australia,  Western Aus...
# 114                                                NaN
#
#                                 Biogeographical realms  \
# 0                                            Greenland
# 1                                        Tibet, Yunnan
# 2    Estonia, Finland, France, Georgia, Greece, Ind...
# 3                        Atlantic Ocean, Pacific Ocean
# 4          Arctic Ocean, Atlantic Ocean, Pacific Ocean
# ..                                                 ...
# 106                                  Swaziland, Zambia
# 107                            Palearctic, Indomalayan
# 109  Estonia, Finland, France, Georgia, Germany, Hu...
# 110             Australasian, Afrotropical, Palearctic
# 114  Djibouti, Eritrea, Ethiopia, Gabon, Gambia, Gh...
#
#                                             Wwf biomes  \
# 0      Nearctic, Palearctic, Indomalayan, Afrotropical
# 1                              Palearctic, Indomalayan
# 2                    Nearctic, Palearctic, Indomalayan
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 106                                       Afrotropical
# 107  Temperate broadleaf and mixed forest, Temperat...
# 109                            Palearctic, Indomalayan
# 110      Desert and Xeric Shrublands, Tropical savanna
# 114                                       Afrotropical
#
#                               Oceans Introduced countries Seas Islands  \
# 0                                NaN                  NaN  NaN     NaN
# 1                                NaN                  NaN  NaN     NaN
# 2                                NaN                  NaN  NaN     NaN
# 3               Greenland, Kamchatka                  NaN  NaN     NaN
# 4    Newfoundland, Hawaii, Greenland                  NaN  NaN     NaN
# ..                               ...                  ...  ...     ...
# 106                              NaN                  NaN  NaN     NaN
# 107                              NaN                  NaN  NaN     NaN
# 109                              NaN                  NaN  NaN     NaN
# 110                              NaN                  NaN  NaN     NaN
# 114                              NaN                  NaN  NaN     NaN
#
#                                                  Biome  \
# 0    [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1    [Forest, Rainforest, Montane forest, Riparian,...
# 2                                   [Forest, Woodland]
# 3         [Oceanic pelagic zone, Marine, Neritic zone]
# 4    [Oceanic pelagic zone, Marine, Neritic zone, E...
# ..                                                 ...
# 106                     [Shrubland, Savanna, Woodland]
# 107  [Rocky areas , Forest, Mountains, Shrubland, W...
# 109  [Forest, Mountains, Shrubland, Grassland, Rock...
# 110  [Grassland, Anthropogenic biome, Agricultural,...
# 114  [Agricultural, Anthropogenic biome, Grassland,...
#
#                                 Climate  \
# 0    [Temperate, Cold, Polar, Tropical]
# 1                 [Tropical, Temperate]
# 2              [Temperate, Cold, Polar]
# 3    [Tropical, Temperate, Cold, Polar]
# 4    [Tropical, Temperate, Cold, Polar]
# ..                                  ...
# 106         [Tropical, Arid, Temperate]
# 107               [Tropical, Temperate]
# 109                   [Cold, Temperate]
# 110         [Arid, Tropical, Temperate]
# 114                          [Tropical]
#
#                                             Group name  \
# 0                                    pack, route, rout
# 1                                                  NaN
# 2                                        sloth, sleuth
# 3                          pod, gam, herd, school, mod
# 4                          pod, gam, herd, school, mod
# ..                                                 ...
# 106                                crash, stubbornness
# 107            tribe, trip, drove, herd, flock, trippe
# 109  destruction (wild cats), clowder, clutter, pounce
# 110                        caravan, train, herd, flock
# 114                  drift, drove, sounder, team, herd
#
#                                              Lifestyle  \
# 0    Terrestrial, Cursorial, Altricial, Pack hunter...
# 1    Cursorial, Terrestrial, Ambush predator, Altri...
# 2    Terrestrial, Altricial, Nomadic, Territorial, ...
# 3    Aquatic, Precocial, Natatorial, Viviparous, Co...
# 4    Aquatic, Precocial, Cosmopolitan, Natatorial, ...
# ..                                                 ...
# 106  Terrestrial, Precocial, Browsing, Zoochory, Te...
# 107  Terrestrial, Precocial, Grazing, Browsing, Zoo...
# 109  Terrestrial, Territorial, Viviparous, Ambush p...
# 110  Terrestrial, Precocial, Cursorial, Grazing, Br...
# 114  Terrestrial, Altricial, Burrowing, Grazing, Vi...
#
#           Seasonal behavior Predators Bird's call  \
# 0             Not a migrant       NaN         NaN
# 1             Not a migrant       NaN         NaN
# 2    Hibernating, Migrating       NaN         NaN
# 3                 Migrating       NaN         NaN
# 4           Partial Migrant       NaN         NaN
# ..                      ...       ...         ...
# 106           Not a migrant       NaN         NaN
# 107     Altitudinal Migrant       NaN         NaN
# 109           Not a migrant       NaN         NaN
# 110           Not a migrant       NaN         NaN
# 114           Not a migrant       NaN         NaN
#
#                                  Diet Mating behavior  \
# 0                Carnivore,,Scavenger        Monogamy
# 1                           Carnivore        Polygyny
# 2                            Omnivore   Polygynandry,
# 3               Carnivore,,Piscivores        Monogamy
# 4                           Carnivore    Polygynandry
# ..                                ...             ...
# 106    Herbivore,,Folivore,,Lignivore        Polygyny
# 107  Herbivore,,Folivore,,Graminivore        Polygyny
# 109                         Carnivore        Polygyny
# 110  Herbivore,,Folivore,,Graminivore        Polygyny
# 114               Omnivore,,Scavenger    Polygynandry
#
#                           Reproduction season Pregnancy duration  \
# 0                               January-April         60-63 days
# 1                              November-April           103 days
# 2                                    May-July            8 weeks
# 3                      winter or early spring             1 year
# 4               year-round, usually in summer       15-18 months
# ..                                        ...                ...
# 106                                year-round          15 months
# 107                                    winter       135-170 days
# 109                            February-April           2 months
# 110                            November-March          13 months
# 114  starts in late rainy or early dry season         5-6 months
#
#     Baby carrying Independent age Female name    Male name      Baby name  \
# 0       1-14 pups         45 days       bitch          dog     pup, whelp
# 1        1-7 cubs    18 mos-3 yrs         NaN          NaN            cub
# 2        1-4 cubs       2-4 years         sow         boar            cub
# 3          1 calf        8 months         cow         bull           calf
# 4          1 calf         2 years         cow         bull           calf
# ..            ...             ...         ...          ...            ...
# 106        1 calf         4 years         cow         bull           calf
# 107      1-2 kids        6 months  doe, nanny  buck, billy     kid, billy
# 109   2-3 kittens       10 months         NaN          NaN         kitten
# 110    1-2 calves       1-2 years         cow         bull           calf
# 114   2-8 piglets        6 months         sow         boar  piglet, shoat
#
#     Incubation period Population trend           Population status
# 0                 NaN           Stable          Least concern (LC)
# 1                 NaN       Decreasing             Endangered (EN)
# 2                 NaN           Stable          Least concern (LC)
# 3                 NaN       Increasing             Endangered (EN)
# 4                 NaN              NaN         Data deficient (DD)
# ..                ...              ...                         ...
# 106               NaN       Increasing  Critically endangered (CR)
# 107               NaN       Increasing        Near Threatened (NT)
# 109               NaN           Stable          Least concern (LC)
# 110               NaN              NaN          Not evaluated (NE)
# 114               NaN       Decreasing          Least concern (LC)
#
# [100 rows x 46 columns]

# %% [markdown]
# Sau khi split dữ liệu tăng thêm 9 cột
#
# Lúc này ta tính lại missing_ratio xem các cột sau khi split như thế nào nhé

# %%
cat_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in df_split_animals_info.columns:
    if df_split_animals_info[i].dtype not in [float, int]:
        cat_col_info_df[i] = col_info(i, df_split_animals_info)

cat_col_info_df
# Out:
#                                                             Name  \
# missing_ratio                                                0.0
# num_values                                                 28525
# value          ? Nycticebus linglom      1
# AEECL's sportive l...
#
#                                       Kingdom  \
# missing_ratio                             0.0
# num_values                                  1
# value          Animalia    28525
# dtype: int64
#
#                                                          Phylum  \
# missing_ratio                                               0.0
# num_values                                                    2
# value          Chordata    23659
# Mollusca     4866
# dtype: int64
#
#                                       Subphylum  \
# missing_ratio                              64.4
# num_values                                    1
# value          Vertebrata    10152
# dtype: int64
#
#                                                            Class  \
# missing_ratio                                                0.0
# num_values                                                    10
# value          Amphibia           3393
# Aves              1011...
#
#                                                            Order  \
# missing_ratio                                                1.5
# num_values                                                   118
# value          Accipitriformes    255
# Adapedonta          10
# ...
#
#                                                         Suborder  \
# missing_ratio                                               91.0
# num_values                                                    13
# value          Alcedini            109
# Caniformia          19...
#
#                                                           Family  \
# missing_ratio                                                0.0
# num_values                                                   840
# value          Abrocomidae           10
# Abronicidae          ...
#
#                                                            Genus  \
# missing_ratio                                                0.0
# num_values                                                  6127
# value          Aaadonta        6
# Abditomys       1
# Abeillia  ...
#
#                                                          Species  \
# missing_ratio                                                0.0
# num_values                                                 28523
# value          "Calamita" melanorabdotus          1
# "Calamita...
#
#                                                  Population size  \
# missing_ratio                                               93.7
# num_values                                                   638
# value          0.45-1 M        1
# 1 Mln           2
# 1,000     ...
#
#                                                        Life span  \
# missing_ratio                                               93.6
# num_values                                                   581
# value          1 yr            2
# 1-10 yrs        2
# 1-12.5 yrs...
#
#                                                        Top speed  \
# missing_ratio                                               98.0
# num_values                                                   124
# value          0.24 km/h    1
# 0.26 km/h    1
# 0.27 km/h    1
# 0...
#
#                                                           Weight  \
# missing_ratio                                               90.0
# num_values                                                  2232
# value          0-0 kg            3
# 0.010-0.796 g     1
# 0.02-2...
#
#                                                           Height  \
# missing_ratio                                               98.9
# num_values                                                   245
# value          0.5 m          1
# 0.7-1.3 m      1
# 0.75-1 m    ...
#
#                                                           Length  \
# missing_ratio                                               89.7
# num_values                                                  2101
# value          0.5 m          2
# 0.5-1.8 m      1
# 0.6-2.43 m  ...
#
#                                                       Attributes  \
# missing_ratio                                                0.0
# num_values                                                  3078
# value          Algivore,Detritivore,Herbivore,Fossorial,Polyg...
#
#                                                       Continents  \
# missing_ratio                                               26.2
# num_values                                                   269
# value                                                        ...
#
#                                                    Subcontinents  \
# missing_ratio                                               95.8
# num_values                                                   245
# value          Angola, Benin, Botswana, Burkina Faso, Burundi...
#
#                                                        Countries  \
# missing_ratio                                               52.4
# num_values                                                  3361
# value                                                        ...
#
#                                                          Regions  \
# missing_ratio                                               90.4
# num_values                                                  1020
# value                                                        ...
#
#                                           Biogeographical realms  \
# missing_ratio                                               66.9
# num_values                                                  1243
# value                                                        ...
#
#                                                       Wwf biomes  \
# missing_ratio                                               92.4
# num_values                                                   435
# value                                                        ...
#
#                                                           Oceans  \
# missing_ratio                                               99.4
# num_values                                                    82
# value                                                        ...
#
#                                             Introduced countries  \
# missing_ratio                                               99.1
# num_values                                                   214
# value                                                        ...
#
#                                                             Seas  \
# missing_ratio                                               99.9
# num_values                                                    11
# value          Arctic Ocean, Atlantic Ocean, Pacific Ocean   ...
#
#                                                          Islands  \
# missing_ratio                                               98.7
# num_values                                                   147
# value                                                        ...
#
#                                                            Biome  \
# missing_ratio                                                0.0
# num_values                                                  2606
# value          []                                            ...
#
#                                                          Climate  \
# missing_ratio                                                0.0
# num_values                                                    50
# value          []                                          25...
#
#                                                       Group name  \
# missing_ratio                                               94.7
# num_values                                                   238
# value          "bind", contradiction, fling, hill, "time-step...
#
#                                                        Lifestyle  \
# missing_ratio                                               64.0
# num_values                                                  1508
# value                                                        ...
#
#                                                Seasonal behavior  \
# missing_ratio                                               71.6
# num_values                                                    49
# value                                                        ...
#
#                                                        Predators  \
# missing_ratio                                              100.0
# num_values                                                     2
# value          Arctic Wolf               1
# Common Ringtail Po...
#
#                                                      Bird's call  \
# missing_ratio                                               81.5
# num_values                                                     2
# value                                                        ...
#
#                                                             Diet  \
# missing_ratio                                               90.9
# num_values                                                   308
# value          Algivore,,Detritivore,,Herbivore              ...
#
#                                                  Mating behavior  \
# missing_ratio                                               92.6
# num_values                                                    27
# value          1                         1
# 1.8               ...
#
#                                              Reproduction season  \
# missing_ratio                                               94.4
# num_values                                                   655
# value          26-35 days                                    ...
#
#                                               Pregnancy duration  \
# missing_ratio                                               94.5
# num_values                                                   758
# value          0 to 0.01 months           1
# 1                ...
#
#                                                    Baby carrying  \
# missing_ratio                                               90.8
# num_values                                                   715
# value          0 to 1                    2
# 0 to 2            ...
#
#                                                  Independent age  \
# missing_ratio                                               93.6
# num_values                                                   582
# value          &gt;2 weeks            1
# 0 days               ...
#
#                                                      Female name  \
# missing_ratio                                               96.1
# num_values                                                    34
# value          angeline              1
# bitch                 ...
#
#                                                        Male name  \
# missing_ratio                                               96.1
# num_values                                                    39
# value          billy                 2
# boar                 8...
#
#                                                        Baby name  \
# missing_ratio                                               93.6
# num_values                                                    85
# value          Fawn, twins         1
# Hatchling           1
# In...
#
#                                                Incubation period  \
# missing_ratio                                               97.4
# num_values                                                   340
# value          1 month        13
# 1-3 months      1
# 1.5 months...
#
#                                                 Population trend  \
# missing_ratio                                               21.7
# num_values                                                     4
# value          Decreasing    8381
# Increasing     782
# Stable  ...
#
#                                                Population status
# missing_ratio                                               18.8
# num_values                                                     9
# value          Critically endangered (CR)      931
# Data defic...

# %% [markdown]
# ## Tiếp tục tiền xử lý dữ liệu nhé

# %% [markdown]
# ### Loại bỏ một số cột không cần thiết
#
# Sau khi tách các cột thành dictionary, đã xuất hiện một số cột không cần thiết mà tỷ lệ miss lại khá cao, ta cần vứt bỏ những cột này cho dễ xử lý về sau.

# %%
cols = ['Oceans', 'Introduced countries', 'Seas', 'Islands', 'Predators', "Bird's call"]
for col in cols:
    df_split_animals_info  = df_split_animals_info.drop(columns  = col)
df_split_animals_info
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0                        Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                            Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                       Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                       Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                     Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                            ...       ...       ...         ...       ...
# 29350            Córdoba cinclodes  Animalia  Chordata         NaN      Aves
# 29351          Western hemispingus  Animalia  Chordata         NaN      Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata         NaN      Aves
# 29355        McConnell's spinetail  Animalia  Chordata         NaN      Aves
# 29356              Junín canastero  Animalia  Chordata         NaN      Aves
#
#                Order    Suborder           Family         Genus  \
# 0          Carnivora  Caniformia          Canidae         Canis
# 1          Carnivora  Feliformia          Felidae      Panthera
# 2          Carnivora  Caniformia          Ursidae         Ursus
# 3       Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4       Artiodactyla         NaN      Delphinidae       Orcinus
# ...              ...         ...              ...           ...
# 29350  Passeriformes         NaN      Furnariidae     Cinclodes
# 29351  Passeriformes         NaN       Thraupidae    Sphenopsis
# 29352  Passeriformes         NaN      Furnariidae   Cranioleuca
# 29355  Passeriformes         NaN      Furnariidae    Synallaxis
# 29356  Passeriformes         NaN      Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0                    Canis lupus         400,000   10-20 yrs   75 km/h
# 1                Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                   Ursus arctos         200,000   20-50 yrs   56 km/h
# 3          Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                   Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                          ...             ...         ...       ...
# 29350    Cinclodes comechingonus             NaN         NaN       NaN
# 29351        Sphenopsis ochracea             NaN         NaN       NaN
# 29352  Limnoctites sulphuriferus             NaN         NaN       NaN
# 29355     Synallaxis macconnelli             NaN         NaN       NaN
# 29356           Asthenes virgata             NaN         NaN       NaN
#
#            Weight     Height      Length  \
# 0        16-60 kg   80-85 cm  105-160 cm
# 1       65-306 kg        NaN  200-390 cm
# 2      100-635 kg  70-153 cm   1.4-2.8 m
# 3       100-160 t        NaN     25-30 m
# 4           3-6 t        NaN       6-9 m
# ...           ...        ...         ...
# 29350         NaN        NaN         NaN
# 29351         NaN        NaN         NaN
# 29352         NaN        NaN         NaN
# 29355         NaN        NaN         NaN
# 29356         NaN        NaN         NaN
#
#                                               Attributes  \
# 0      Nocturnal,Carnivore,Scavenger,Terrestrial,Curs...
# 1      Nocturnal,Carnivore,Cursorial,Terrestrial,Ambu...
# 2      Crepuscular,Omnivore,Terrestrial,Altricial,Nom...
# 3      Carnivore,Piscivores,Aquatic,Precocial,Natator...
# 4      Diurnal,Carnivore,Aquatic,Precocial,Cosmopolit...
# ...                                                  ...
# 29350                  Terrestrial,Migrating,starts with
# 29351              Terrestrial,Not a migrant,starts with
# 29352                  Terrestrial,Migrating,starts with
# 29355              Terrestrial,Not a migrant,starts with
# 29356              Terrestrial,Not a migrant,starts with
#
#                                               Continents  \
# 0                    Asia, Europe, North America, Africa
# 1                                                   Asia
# 2                            Asia, Europe, North America
# 3      Africa, South America, Oceania, North America,...
# 4      Africa, Oceania, Antarctica, North America, So...
# ...                                                  ...
# 29350                                      South America
# 29351                                      South America
# 29352                                      South America
# 29355                                      South America
# 29356                                      South America
#
#                                            Subcontinents  \
# 0      South Asia, Western Asia, Southeast Asia, East...
# 1                  South Asia, Southeast Asia, East Asia
# 2      South Asia, Western Asia, East Asia, Central A...
# 3      Sub-Saharan Africa, Caribbean Islands, South A...
# 4      North Africa, Caribbean Islands, South Asia, C...
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                                NaN
# 29356                                                NaN
#
#                                                Countries  \
# 0      Albania, Armenia, Azerbaijan, Belarus, Bhutan,...
# 1      Bangladesh, Bhutan, China,   India, Indonesia,...
# 2      Albania, Armenia, Austria, Azerbaijan, Belarus...
# 3      Angola, Argentina, Australia, Bahamas, Banglad...
# 4      Algeria, Antigua and Barbuda, Argentina, Austr...
# ...                                                  ...
# 29350                                          Argentina
# 29351                                  Ecuador, Colombia
# 29352                         Argentina, Brazil, Uruguay
# 29355                Brazil, Guyana, Suriname, Venezuela
# 29356                                               Peru
#
#                                                  Regions  \
# 0      Czech Republic, Estonia, Finland, France, Geor...
# 1                                               Thailand
# 2                                                    NaN
# 3      Chile, China, Colombia, Comoros, Costa Rica, C...
# 4      Brunei, Cambodia, Cameroon, Canada, Cape Verde...
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                      French Guiana
# 29356                                                NaN
#
#                                   Biogeographical realms  \
# 0                                              Greenland
# 1                                          Tibet, Yunnan
# 2      Estonia, Finland, France, Georgia, Greece, Ind...
# 3                          Atlantic Ocean, Pacific Ocean
# 4            Arctic Ocean, Atlantic Ocean, Pacific Ocean
# ...                                                  ...
# 29350                                        Neotropical
# 29351                                        Neotropical
# 29352                                        Neotropical
# 29355                                        Neotropical
# 29356                                        Neotropical
#
#                                             Wwf biomes  \
# 0      Nearctic, Palearctic, Indomalayan, Afrotropical
# 1                              Palearctic, Indomalayan
# 2                    Nearctic, Palearctic, Indomalayan
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 29350                                              NaN
# 29351                                              NaN
# 29352                                              NaN
# 29355                                              NaN
# 29356                                              NaN
#
#                                                    Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1      [Forest, Rainforest, Montane forest, Riparian,...
# 2                                     [Forest, Woodland]
# 3           [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                  ...
# 29350                          [Grassland, Rocky areas ]
# 29351                                           [Forest]
# 29352                 [Freshwater, Shrubland, Wetlands ]
# 29355                      [Anthropogenic biome, Forest]
# 29356                             [Grassland, Shrubland]
#
#                                   Climate                   Group name  \
# 0      [Temperate, Cold, Polar, Tropical]            pack, route, rout
# 1                   [Tropical, Temperate]                          NaN
# 2                [Temperate, Cold, Polar]                sloth, sleuth
# 3      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# 4      [Tropical, Temperate, Cold, Polar]  pod, gam, herd, school, mod
# ...                                   ...                          ...
# 29350                                  []                          NaN
# 29351                                  []                          NaN
# 29352                                  []                          NaN
# 29355                                  []                          NaN
# 29356                                  []                          NaN
#
#                                                Lifestyle  \
# 0      Terrestrial, Cursorial, Altricial, Pack hunter...
# 1      Cursorial, Terrestrial, Ambush predator, Altri...
# 2      Terrestrial, Altricial, Nomadic, Territorial, ...
# 3      Aquatic, Precocial, Natatorial, Viviparous, Co...
# 4      Aquatic, Precocial, Cosmopolitan, Natatorial, ...
# ...                                                  ...
# 29350                                                NaN
# 29351                                       Terrestrial,
# 29352                                       Terrestrial,
# 29355                                                NaN
# 29356                                       Terrestrial,
#
#             Seasonal behavior                   Diet Mating behavior  \
# 0               Not a migrant   Carnivore,,Scavenger        Monogamy
# 1               Not a migrant              Carnivore        Polygyny
# 2      Hibernating, Migrating               Omnivore   Polygynandry,
# 3                   Migrating  Carnivore,,Piscivores        Monogamy
# 4             Partial Migrant              Carnivore    Polygynandry
# ...                       ...                    ...             ...
# 29350                     NaN                    NaN             NaN
# 29351           Not a migrant                    NaN             NaN
# 29352               Migrating                    NaN             NaN
# 29355                     NaN                    NaN             NaN
# 29356           Not a migrant                    NaN             NaN
#
#                  Reproduction season Pregnancy duration Baby carrying  \
# 0                      January-April         60-63 days     1-14 pups
# 1                     November-April           103 days      1-7 cubs
# 2                           May-July            8 weeks      1-4 cubs
# 3             winter or early spring             1 year        1 calf
# 4      year-round, usually in summer       15-18 months        1 calf
# ...                              ...                ...           ...
# 29350                            NaN                NaN           NaN
# 29351                            NaN                NaN           NaN
# 29352                            NaN                NaN           NaN
# 29355                            NaN                NaN           NaN
# 29356                            NaN                NaN           NaN
#
#       Independent age Female name Male name   Baby name Incubation period  \
# 0             45 days       bitch       dog  pup, whelp               NaN
# 1        18 mos-3 yrs         NaN       NaN         cub               NaN
# 2           2-4 years         sow      boar         cub               NaN
# 3            8 months         cow      bull        calf               NaN
# 4             2 years         cow      bull        calf               NaN
# ...               ...         ...       ...         ...               ...
# 29350             NaN         NaN       NaN         NaN               NaN
# 29351             NaN         NaN       NaN         NaN               NaN
# 29352             NaN         NaN       NaN         NaN               NaN
# 29355             NaN         NaN       NaN         NaN               NaN
# 29356             NaN         NaN       NaN         NaN               NaN
#
#       Population trend    Population status
# 0               Stable   Least concern (LC)
# 1           Decreasing      Endangered (EN)
# 2               Stable   Least concern (LC)
# 3           Increasing      Endangered (EN)
# 4                  NaN  Data deficient (DD)
# ...                ...                  ...
# 29350       Decreasing   Least concern (LC)
# 29351           Stable   Least concern (LC)
# 29352       Decreasing   Least concern (LC)
# 29355           Stable   Least concern (LC)
# 29356          Unknown   Least concern (LC)
#
# [28525 rows x 40 columns]

# %% [markdown]
# Tại đây ta sẽ tách các cột có thuộc tính cách nhau bằng dấu phẩy thành 1 list
#
# Luu vào "element" là tên các cột có các thuộc tính phân tách bằng dấu phẩy
#
# Các cột sau khi xử lý sẽ được lưu vào biến "splits"

# %%
element = np.array(['Attributes', 'Continents', 'Subcontinents', 'Countries', 'Regions', 'Wwf biomes', 'Group name', 'Diet', 'Biogeographical realms', 'Lifestyle',  'Seasonal behavior'])

splits = [df_split_animals_info[col].str.split(pat = ',| and |  ', expand = False) for col in element]
splits = pd.DataFrame(splits).T
# print(splits.shape)
# print(splits.head())

# %% [markdown]
# Sau khi tách xong ta tiến hành ghép 2 dataframe lại thành "data_df"

# %%
df_split_animals_info.drop(element, axis=1, inplace=True)
data_df = pd.concat([df_split_animals_info, splits], axis = 1)
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df
# df_split_animals_info
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0                        Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                            Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                       Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                       Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                     Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                            ...       ...       ...         ...       ...
# 29350            Córdoba cinclodes  Animalia  Chordata         NaN      Aves
# 29351          Western hemispingus  Animalia  Chordata         NaN      Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata         NaN      Aves
# 29355        McConnell's spinetail  Animalia  Chordata         NaN      Aves
# 29356              Junín canastero  Animalia  Chordata         NaN      Aves
#
#                Order    Suborder           Family         Genus  \
# 0          Carnivora  Caniformia          Canidae         Canis
# 1          Carnivora  Feliformia          Felidae      Panthera
# 2          Carnivora  Caniformia          Ursidae         Ursus
# 3       Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4       Artiodactyla         NaN      Delphinidae       Orcinus
# ...              ...         ...              ...           ...
# 29350  Passeriformes         NaN      Furnariidae     Cinclodes
# 29351  Passeriformes         NaN       Thraupidae    Sphenopsis
# 29352  Passeriformes         NaN      Furnariidae   Cranioleuca
# 29355  Passeriformes         NaN      Furnariidae    Synallaxis
# 29356  Passeriformes         NaN      Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0                    Canis lupus         400,000   10-20 yrs   75 km/h
# 1                Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                   Ursus arctos         200,000   20-50 yrs   56 km/h
# 3          Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                   Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                          ...             ...         ...       ...
# 29350    Cinclodes comechingonus             NaN         NaN       NaN
# 29351        Sphenopsis ochracea             NaN         NaN       NaN
# 29352  Limnoctites sulphuriferus             NaN         NaN       NaN
# 29355     Synallaxis macconnelli             NaN         NaN       NaN
# 29356           Asthenes virgata             NaN         NaN       NaN
#
#            Weight     Height      Length  \
# 0        16-60 kg   80-85 cm  105-160 cm
# 1       65-306 kg        NaN  200-390 cm
# 2      100-635 kg  70-153 cm   1.4-2.8 m
# 3       100-160 t        NaN     25-30 m
# 4           3-6 t        NaN       6-9 m
# ...           ...        ...         ...
# 29350         NaN        NaN         NaN
# 29351         NaN        NaN         NaN
# 29352         NaN        NaN         NaN
# 29355         NaN        NaN         NaN
# 29356         NaN        NaN         NaN
#
#                                                    Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1      [Forest, Rainforest, Montane forest, Riparian,...
# 2                                     [Forest, Woodland]
# 3           [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                  ...
# 29350                          [Grassland, Rocky areas ]
# 29351                                           [Forest]
# 29352                 [Freshwater, Shrubland, Wetlands ]
# 29355                      [Anthropogenic biome, Forest]
# 29356                             [Grassland, Shrubland]
#
#                                   Climate Mating behavior  \
# 0      [Temperate, Cold, Polar, Tropical]        Monogamy
# 1                   [Tropical, Temperate]        Polygyny
# 2                [Temperate, Cold, Polar]   Polygynandry,
# 3      [Tropical, Temperate, Cold, Polar]        Monogamy
# 4      [Tropical, Temperate, Cold, Polar]    Polygynandry
# ...                                   ...             ...
# 29350                                  []             NaN
# 29351                                  []             NaN
# 29352                                  []             NaN
# 29355                                  []             NaN
# 29356                                  []             NaN
#
#                  Reproduction season Pregnancy duration Baby carrying  \
# 0                      January-April         60-63 days     1-14 pups
# 1                     November-April           103 days      1-7 cubs
# 2                           May-July            8 weeks      1-4 cubs
# 3             winter or early spring             1 year        1 calf
# 4      year-round, usually in summer       15-18 months        1 calf
# ...                              ...                ...           ...
# 29350                            NaN                NaN           NaN
# 29351                            NaN                NaN           NaN
# 29352                            NaN                NaN           NaN
# 29355                            NaN                NaN           NaN
# 29356                            NaN                NaN           NaN
#
#       Independent age Female name Male name   Baby name Incubation period  \
# 0             45 days       bitch       dog  pup, whelp               NaN
# 1        18 mos-3 yrs         NaN       NaN         cub               NaN
# 2           2-4 years         sow      boar         cub               NaN
# 3            8 months         cow      bull        calf               NaN
# 4             2 years         cow      bull        calf               NaN
# ...               ...         ...       ...         ...               ...
# 29350             NaN         NaN       NaN         NaN               NaN
# 29351             NaN         NaN       NaN         NaN               NaN
# 29352             NaN         NaN       NaN         NaN               NaN
# 29355             NaN         NaN       NaN         NaN               NaN
# 29356             NaN         NaN       NaN         NaN               NaN
#
#       Population trend    Population status  \
# 0               Stable   Least concern (LC)
# 1           Decreasing      Endangered (EN)
# 2               Stable   Least concern (LC)
# 3           Increasing      Endangered (EN)
# 4                  NaN  Data deficient (DD)
# ...                ...                  ...
# 29350       Decreasing   Least concern (LC)
# 29351           Stable   Least concern (LC)
# 29352       Decreasing   Least concern (LC)
# 29355           Stable   Least concern (LC)
# 29356          Unknown   Least concern (LC)
#
#                                               Attributes  \
# 0      [Nocturnal, Carnivore, Scavenger, Terrestrial,...
# 1      [Nocturnal, Carnivore, Cursorial, Terrestrial,...
# 2      [Crepuscular, Omnivore, Terrestrial, Altricial...
# 3      [Carnivore, Piscivores, Aquatic, Precocial, Na...
# 4      [Diurnal, Carnivore, Aquatic, Precocial, Cosmo...
# ...                                                  ...
# 29350              [Terrestrial, Migrating, starts with]
# 29351          [Terrestrial, Not a migrant, starts with]
# 29352              [Terrestrial, Migrating, starts with]
# 29355          [Terrestrial, Not a migrant, starts with]
# 29356          [Terrestrial, Not a migrant, starts with]
#
#                                               Continents  \
# 0               [Asia,  Europe,  North America,  Africa]
# 1                                                 [Asia]
# 2                        [Asia,  Europe,  North America]
# 3      [Africa,  South America,  Oceania,  North Amer...
# 4      [Africa,  Oceania,  Antarctica,  North America...
# ...                                                  ...
# 29350                                    [South America]
# 29351                                    [South America]
# 29352                                    [South America]
# 29355                                    [South America]
# 29356                                    [South America]
#
#                                            Subcontinents  \
# 0      [South Asia,  Western Asia,  Southeast Asia,  ...
# 1              [South Asia,  Southeast Asia,  East Asia]
# 2      [South Asia,  Western Asia,  East Asia,  Centr...
# 3      [Sub-Saharan Africa,  Caribbean Islands,  Sout...
# 4      [North Africa,  Caribbean Islands,  South Asia...
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                                NaN
# 29356                                                NaN
#
#                                                Countries  \
# 0      [Albania,  Armenia,  Azerbaijan,  Belarus,  Bh...
# 1      [Bangladesh,  Bhutan,  China, ,  India,  Indon...
# 2      [Albania,  Armenia,  Austria,  Azerbaijan,  Be...
# 3      [Angola,  Argentina,  Australia,  Bahamas,  Ba...
# 4      [Algeria,  Antigua, Barbuda,  Argentina,  Aust...
# ...                                                  ...
# 29350                                        [Argentina]
# 29351                               [Ecuador,  Colombia]
# 29352                     [Argentina,  Brazil,  Uruguay]
# 29355           [Brazil,  Guyana,  Suriname,  Venezuela]
# 29356                                             [Peru]
#
#                                                  Regions  \
# 0      [Czech Republic,  Estonia,  Finland,  France, ...
# 1                                             [Thailand]
# 2                                                    NaN
# 3      [Chile,  China,  Colombia,  Comoros,  Costa Ri...
# 4      [Brunei,  Cambodia,  Cameroon,  Canada,  Cape ...
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                    [French Guiana]
# 29356                                                NaN
#
#                                               Wwf biomes  \
# 0      [Nearctic,  Palearctic,  Indomalayan,  Afrotro...
# 1                             [Palearctic,  Indomalayan]
# 2                  [Nearctic,  Palearctic,  Indomalayan]
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29350                                                NaN
# 29351                                                NaN
# 29352                                                NaN
# 29355                                                NaN
# 29356                                                NaN
#
#                               Group name                       Diet  \
# 0                  [pack,  route,  rout]   [Carnivore, , Scavenger]
# 1                                    NaN                [Carnivore]
# 2                       [sloth,  sleuth]                 [Omnivore]
# 3      [pod,  gam,  herd,  school,  mod]  [Carnivore, , Piscivores]
# 4      [pod,  gam,  herd,  school,  mod]                [Carnivore]
# ...                                  ...                        ...
# 29350                                NaN                        NaN
# 29351                                NaN                        NaN
# 29352                                NaN                        NaN
# 29355                                NaN                        NaN
# 29356                                NaN                        NaN
#
#                                   Biogeographical realms  \
# 0                                            [Greenland]
# 1                                       [Tibet,  Yunnan]
# 2      [Estonia,  Finland,  France,  Georgia,  Greece...
# 3                       [Atlantic Ocean,  Pacific Ocean]
# 4        [Arctic Ocean,  Atlantic Ocean,  Pacific Ocean]
# ...                                                  ...
# 29350                                      [Neotropical]
# 29351                                      [Neotropical]
# 29352                                      [Neotropical]
# 29355                                      [Neotropical]
# 29356                                      [Neotropical]
#
#                                                Lifestyle  \
# 0      [Terrestrial,  Cursorial,  Altricial,  Pack hu...
# 1      [Cursorial,  Terrestrial,  Ambush predator,  A...
# 2      [Terrestrial,  Altricial,  Nomadic,  Territori...
# 3      [Aquatic,  Precocial,  Natatorial,  Viviparous...
# 4      [Aquatic,  Precocial,  Cosmopolitan,  Natatori...
# ...                                                  ...
# 29350                                                NaN
# 29351                                    [Terrestrial, ]
# 29352                                    [Terrestrial, ]
# 29355                                                NaN
# 29356                                    [Terrestrial, ]
#
#                Seasonal behavior
# 0                [Not a migrant]
# 1                [Not a migrant]
# 2      [Hibernating,  Migrating]
# 3                    [Migrating]
# 4              [Partial Migrant]
# ...                          ...
# 29350                        NaN
# 29351            [Not a migrant]
# 29352                [Migrating]
# 29355                        NaN
# 29356            [Not a migrant]
#
# [28525 rows x 40 columns]

# %% [markdown]
# Xử lý tại các cột list, những giá trị nan sẽ được thay thế thành một list rỗng []

# %%
data_df[element] = data_df[element].fillna(data_df.notna().applymap(lambda x: x or []))
# data_df = data_df.drop(columns = data_df.columns[0], axis = 1)
data_df
# Out:
#                               Name   Kingdom    Phylum   Subphylum     Class  \
# 0                        Grey Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1                            Tiger  Animalia  Chordata  Vertebrata  Mammalia
# 2                       Brown Bear  Animalia  Chordata  Vertebrata  Mammalia
# 3                       Blue Whale  Animalia  Chordata  Vertebrata  Mammalia
# 4                     Killer Whale  Animalia  Chordata  Vertebrata  Mammalia
# ...                            ...       ...       ...         ...       ...
# 29350            Córdoba cinclodes  Animalia  Chordata         NaN      Aves
# 29351          Western hemispingus  Animalia  Chordata         NaN      Aves
# 29352  Sulphur-bearded reedhaunter  Animalia  Chordata         NaN      Aves
# 29355        McConnell's spinetail  Animalia  Chordata         NaN      Aves
# 29356              Junín canastero  Animalia  Chordata         NaN      Aves
#
#                Order    Suborder           Family         Genus  \
# 0          Carnivora  Caniformia          Canidae         Canis
# 1          Carnivora  Feliformia          Felidae      Panthera
# 2          Carnivora  Caniformia          Ursidae         Ursus
# 3       Artiodactyla         NaN  Balaenopteridae  Balaenoptera
# 4       Artiodactyla         NaN      Delphinidae       Orcinus
# ...              ...         ...              ...           ...
# 29350  Passeriformes         NaN      Furnariidae     Cinclodes
# 29351  Passeriformes         NaN       Thraupidae    Sphenopsis
# 29352  Passeriformes         NaN      Furnariidae   Cranioleuca
# 29355  Passeriformes         NaN      Furnariidae    Synallaxis
# 29356  Passeriformes         NaN      Furnariidae      Asthenes
#
#                          Species Population size   Life span Top speed  \
# 0                    Canis lupus         400,000   10-20 yrs   75 km/h
# 1                Panthera tigris     2,154-3,159   10-15 yrs   96 km/h
# 2                   Ursus arctos         200,000   20-50 yrs   56 km/h
# 3          Balaenoptera musculus      10-25 Thou   80-90 yrs   20 km/h
# 4                   Orcinus orca          50,000  30-100 yrs   45 km/h
# ...                          ...             ...         ...       ...
# 29350    Cinclodes comechingonus             NaN         NaN       NaN
# 29351        Sphenopsis ochracea             NaN         NaN       NaN
# 29352  Limnoctites sulphuriferus             NaN         NaN       NaN
# 29355     Synallaxis macconnelli             NaN         NaN       NaN
# 29356           Asthenes virgata             NaN         NaN       NaN
#
#            Weight     Height      Length  \
# 0        16-60 kg   80-85 cm  105-160 cm
# 1       65-306 kg        NaN  200-390 cm
# 2      100-635 kg  70-153 cm   1.4-2.8 m
# 3       100-160 t        NaN     25-30 m
# 4           3-6 t        NaN       6-9 m
# ...           ...        ...         ...
# 29350         NaN        NaN         NaN
# 29351         NaN        NaN         NaN
# 29352         NaN        NaN         NaN
# 29355         NaN        NaN         NaN
# 29356         NaN        NaN         NaN
#
#                                                    Biome  \
# 0      [Wetlands , Shrubland, Forest, Mountains, Anth...
# 1      [Forest, Rainforest, Montane forest, Riparian,...
# 2                                     [Forest, Woodland]
# 3           [Oceanic pelagic zone, Marine, Neritic zone]
# 4      [Oceanic pelagic zone, Marine, Neritic zone, E...
# ...                                                  ...
# 29350                          [Grassland, Rocky areas ]
# 29351                                           [Forest]
# 29352                 [Freshwater, Shrubland, Wetlands ]
# 29355                      [Anthropogenic biome, Forest]
# 29356                             [Grassland, Shrubland]
#
#                                   Climate Mating behavior  \
# 0      [Temperate, Cold, Polar, Tropical]        Monogamy
# 1                   [Tropical, Temperate]        Polygyny
# 2                [Temperate, Cold, Polar]   Polygynandry,
# 3      [Tropical, Temperate, Cold, Polar]        Monogamy
# 4      [Tropical, Temperate, Cold, Polar]    Polygynandry
# ...                                   ...             ...
# 29350                                  []             NaN
# 29351                                  []             NaN
# 29352                                  []             NaN
# 29355                                  []             NaN
# 29356                                  []             NaN
#
#                  Reproduction season Pregnancy duration Baby carrying  \
# 0                      January-April         60-63 days     1-14 pups
# 1                     November-April           103 days      1-7 cubs
# 2                           May-July            8 weeks      1-4 cubs
# 3             winter or early spring             1 year        1 calf
# 4      year-round, usually in summer       15-18 months        1 calf
# ...                              ...                ...           ...
# 29350                            NaN                NaN           NaN
# 29351                            NaN                NaN           NaN
# 29352                            NaN                NaN           NaN
# 29355                            NaN                NaN           NaN
# 29356                            NaN                NaN           NaN
#
#       Independent age Female name Male name   Baby name Incubation period  \
# 0             45 days       bitch       dog  pup, whelp               NaN
# 1        18 mos-3 yrs         NaN       NaN         cub               NaN
# 2           2-4 years         sow      boar         cub               NaN
# 3            8 months         cow      bull        calf               NaN
# 4             2 years         cow      bull        calf               NaN
# ...               ...         ...       ...         ...               ...
# 29350             NaN         NaN       NaN         NaN               NaN
# 29351             NaN         NaN       NaN         NaN               NaN
# 29352             NaN         NaN       NaN         NaN               NaN
# 29355             NaN         NaN       NaN         NaN               NaN
# 29356             NaN         NaN       NaN         NaN               NaN
#
#       Population trend    Population status  \
# 0               Stable   Least concern (LC)
# 1           Decreasing      Endangered (EN)
# 2               Stable   Least concern (LC)
# 3           Increasing      Endangered (EN)
# 4                  NaN  Data deficient (DD)
# ...                ...                  ...
# 29350       Decreasing   Least concern (LC)
# 29351           Stable   Least concern (LC)
# 29352       Decreasing   Least concern (LC)
# 29355           Stable   Least concern (LC)
# 29356          Unknown   Least concern (LC)
#
#                                               Attributes  \
# 0      [Nocturnal, Carnivore, Scavenger, Terrestrial,...
# 1      [Nocturnal, Carnivore, Cursorial, Terrestrial,...
# 2      [Crepuscular, Omnivore, Terrestrial, Altricial...
# 3      [Carnivore, Piscivores, Aquatic, Precocial, Na...
# 4      [Diurnal, Carnivore, Aquatic, Precocial, Cosmo...
# ...                                                  ...
# 29350              [Terrestrial, Migrating, starts with]
# 29351          [Terrestrial, Not a migrant, starts with]
# 29352              [Terrestrial, Migrating, starts with]
# 29355          [Terrestrial, Not a migrant, starts with]
# 29356          [Terrestrial, Not a migrant, starts with]
#
#                                               Continents  \
# 0               [Asia,  Europe,  North America,  Africa]
# 1                                                 [Asia]
# 2                        [Asia,  Europe,  North America]
# 3      [Africa,  South America,  Oceania,  North Amer...
# 4      [Africa,  Oceania,  Antarctica,  North America...
# ...                                                  ...
# 29350                                    [South America]
# 29351                                    [South America]
# 29352                                    [South America]
# 29355                                    [South America]
# 29356                                    [South America]
#
#                                            Subcontinents  \
# 0      [South Asia,  Western Asia,  Southeast Asia,  ...
# 1              [South Asia,  Southeast Asia,  East Asia]
# 2      [South Asia,  Western Asia,  East Asia,  Centr...
# 3      [Sub-Saharan Africa,  Caribbean Islands,  Sout...
# 4      [North Africa,  Caribbean Islands,  South Asia...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                                                Countries  \
# 0      [Albania,  Armenia,  Azerbaijan,  Belarus,  Bh...
# 1      [Bangladesh,  Bhutan,  China, ,  India,  Indon...
# 2      [Albania,  Armenia,  Austria,  Azerbaijan,  Be...
# 3      [Angola,  Argentina,  Australia,  Bahamas,  Ba...
# 4      [Algeria,  Antigua, Barbuda,  Argentina,  Aust...
# ...                                                  ...
# 29350                                        [Argentina]
# 29351                               [Ecuador,  Colombia]
# 29352                     [Argentina,  Brazil,  Uruguay]
# 29355           [Brazil,  Guyana,  Suriname,  Venezuela]
# 29356                                             [Peru]
#
#                                                  Regions  \
# 0      [Czech Republic,  Estonia,  Finland,  France, ...
# 1                                             [Thailand]
# 2                                                     []
# 3      [Chile,  China,  Colombia,  Comoros,  Costa Ri...
# 4      [Brunei,  Cambodia,  Cameroon,  Canada,  Cape ...
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                    [French Guiana]
# 29356                                                 []
#
#                                               Wwf biomes  \
# 0      [Nearctic,  Palearctic,  Indomalayan,  Afrotro...
# 1                             [Palearctic,  Indomalayan]
# 2                  [Nearctic,  Palearctic,  Indomalayan]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 29350                                                 []
# 29351                                                 []
# 29352                                                 []
# 29355                                                 []
# 29356                                                 []
#
#                               Group name                       Diet  \
# 0                  [pack,  route,  rout]   [Carnivore, , Scavenger]
# 1                                     []                [Carnivore]
# 2                       [sloth,  sleuth]                 [Omnivore]
# 3      [pod,  gam,  herd,  school,  mod]  [Carnivore, , Piscivores]
# 4      [pod,  gam,  herd,  school,  mod]                [Carnivore]
# ...                                  ...                        ...
# 29350                                 []                         []
# 29351                                 []                         []
# 29352                                 []                         []
# 29355                                 []                         []
# 29356                                 []                         []
#
#                                   Biogeographical realms  \
# 0                                            [Greenland]
# 1                                       [Tibet,  Yunnan]
# 2      [Estonia,  Finland,  France,  Georgia,  Greece...
# 3                       [Atlantic Ocean,  Pacific Ocean]
# 4        [Arctic Ocean,  Atlantic Ocean,  Pacific Ocean]
# ...                                                  ...
# 29350                                      [Neotropical]
# 29351                                      [Neotropical]
# 29352                                      [Neotropical]
# 29355                                      [Neotropical]
# 29356                                      [Neotropical]
#
#                                                Lifestyle  \
# 0      [Terrestrial,  Cursorial,  Altricial,  Pack hu...
# 1      [Cursorial,  Terrestrial,  Ambush predator,  A...
# 2      [Terrestrial,  Altricial,  Nomadic,  Territori...
# 3      [Aquatic,  Precocial,  Natatorial,  Viviparous...
# 4      [Aquatic,  Precocial,  Cosmopolitan,  Natatori...
# ...                                                  ...
# 29350                                                 []
# 29351                                    [Terrestrial, ]
# 29352                                    [Terrestrial, ]
# 29355                                                 []
# 29356                                    [Terrestrial, ]
#
#                Seasonal behavior
# 0                [Not a migrant]
# 1                [Not a migrant]
# 2      [Hibernating,  Migrating]
# 3                    [Migrating]
# 4              [Partial Migrant]
# ...                          ...
# 29350                         []
# 29351            [Not a migrant]
# 29352                [Migrating]
# 29355                         []
# 29356            [Not a migrant]
#
# [28525 rows x 40 columns]

# %% [markdown]
# ### Chuyển cột Top speed sang kiểu số

# %%
def to_float(element):
    try:
        return float(element)
    except ValueError:
        return np.nan

# %%
def trans_speed(speed):
    if pd.isna(speed): return np.nan
    speed = [speed[:-4].strip(), speed[-4:].strip()]
    if speed[1] == 'km/h':
        x = 1
    elif speed[1] == 'mph':
        x = 1.61
    sp = speed[0].split('-')
    if len(sp) == 1:
        return float(sp[0]) * x
    else:
        return (float(sp[0]) + float(sp[1])) / 2 * x

# %%
data_df['Top speed'] = data_df['Top speed'].apply(trans_speed)

# %% [markdown]
# ### Chuyển cột life_span sang float

# %%
def trans_life_span(life):
    if pd.isna(life): return np.nan
    life = str(life)
    life = life.upper()
    life = life.replace('UPPER', '')
    life = life.replace('ABOVE', '')
    life = life.replace('OVER','')
    life = life.replace('mos', ' MONTHS ')
    life = life.replace('yr', ' YEARS ')
    life = life.replace('YRS', ' YEARS ')
    life = life.replace('YEARS', ' YEARS ')
    life = life.split('-')
    low = to_float(life[0])
    high = to_float(life[-1].split()[0].strip())
    x = life[-1].split()[-1].strip()
    if np.isnan(low):
        low = high
    t = 1.0
    if x == 'MONTHS':
        t = 1 / 12
    elif x == 'YEARS':
        t = 1.0
    low = low * t
    high = high * t
    return (low, high)

# %%
data_df['Life span'] = data_df['Life span'].apply(trans_life_span)
#data_df['Life span'].dropna()

# %% [markdown]
# ## Thống kê các chỉ số cho các cột có kiểu dữ liệu là list

# %%
def stat_list_col(col, array):
    temp = pd.DataFrame(array[col])
    temp = temp.dropna()
    temp = np.array(temp[col])
    data = []
    # missing_ratio
    data.append(round((100 - (len(temp) / len(array[col]) * 100)), 1))
    # num_values
    temp = np.hstack(temp)
    temp = list(map(str.strip, temp)) # Xử lý các dấu cách đầu và cuối mỗi chuỗi
    temp = np.unique(temp, return_counts=True)
    data.append(len(temp[0]))
    # value
    temp = pd.Series(data = temp[1], index = temp[0])
    data.append(temp)
    # num_values
    return data

#     total = data_df[col].tolist()
#     total = np.hstack(total)
#     value, times = np.unique(total, return_counts = True)

# %%
list_col_info_df = pd.DataFrame(index = ['missing_ratio', 'num_values', 'value'])
for i in data_df:
    if type(data_df[i][0]) == list:
        list_col_info_df[i] = stat_list_col(i, data_df)
    pd.set_option('display.max_columns', None)

list_col_info_df
# Out:
#                                                            Biome  \
# missing_ratio                                                0.0
# num_values                                                    43
# value          Abyssal zone                4
# Agricultural    ...
#
#                                                          Climate  \
# missing_ratio                                                0.0
# num_values                                                     6
# value          Arid          299
# Cold          305
# Libya     ...
#
#                                                       Attributes  \
# missing_ratio                                                0.0
# num_values                                                   139
# value          Aestivation               71
# Algivore         ...
#
#                                                       Continents  \
# missing_ratio                                                0.0
# num_values                                                   132
# value                            11908
# Africa             191...
#
#                                                    Subcontinents  \
# missing_ratio                                                0.0
# num_values                                                    80
# value                            40
# Afghanistan        1
# Afro...
#
#                                                        Countries  \
# missing_ratio                                                0.0
# num_values                                                   258
# value                            6611
# Afghanistan         95
# ...
#
#                                                          Regions  \
# missing_ratio                                                0.0
# num_values                                                   423
# value                            1120
# Acre                 6
# ...
#
#                                                       Wwf biomes  \
# missing_ratio                                                0.0
# num_values                                                   266
# value                                        179
# Afghanistan ...
#
#                                                       Group name  \
# missing_ratio                                                0.0
# num_values                                                   400
# value                            1
# "bind"            1
# "littl...
#
#                                                             Diet  \
# missing_ratio                                                0.0
# num_values                                                    30
# value                            2972
# Algivore            18
# ...
#
#                                           Biogeographical realms  \
# missing_ratio                                                0.0
# num_values                                                   419
# value                                               600
# Afgha...
#
#                                                        Lifestyle  \
# missing_ratio                                                0.0
# num_values                                                    47
# value                                 9659
# Aestivation       ...
#
#                                                Seasonal behavior
# missing_ratio                                                0.0
# num_values                                                     8
# value                                                        ...

# %% [markdown]
# ### Lưu dữ liệu đã tiền xử lý vào file 'animals_split_info.csv' để tiếp tục sử dụng trong các phần sau

# %%
data_df.to_csv('animals_split_info.csv')
